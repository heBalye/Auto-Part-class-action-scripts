# %%
import pandas as pd
import glob

# %%
QC_table = pd.read_excel('C:\\Users\\FFR0103\\Desktop\\My files\\WORK\\Auto part\\Mattress Firm\\Output\\123.xlsx', index_col = [0,1])
QC_table
# Out:
#                                                                                               File Name  \
# 01-17-2013 - Mattress Firm - Adhoc #50358.xlsx     0     01-17-2013 - Mattress Firm - Adhoc #50358.xlsx
#                                                    0     01-17-2013 - Mattress Firm - Adhoc #50358.xlsx
# 01-17-2013 - Mattress Firm - Adhoc.xlsx            0            01-17-2013 - Mattress Firm - Adhoc.xlsx
#                                                    0            01-17-2013 - Mattress Firm - Adhoc.xlsx
# 2.4.29 2.4.10_Debt Schedules_MLI (No APC Data).... 0  2.4.29 2.4.10_Debt Schedules_MLI (No APC Data)...
#                                                    0  2.4.29 2.4.10_Debt Schedules_MLI (No APC Data)...
#                                                    0  2.4.29 2.4.10_Debt Schedules_MLI (No APC Data)...
#                                                    0  2.4.29 2.4.10_Debt Schedules_MLI (No APC Data)...
# ...

# %%
# Out:
# '3'

# %%
for a, b,c in zip(test['File Name'],test['SheetName'], test["index of row contains 'V/S'"]):
    print(a,b,c)
# Out:
# 01-17-2013 - Mattress Firm - Adhoc #50358.xlsx CC 15
# 01-17-2013 - Mattress Firm - Adhoc #50358.xlsx Output 1
# 01-17-2013 - Mattress Firm - Adhoc.xlsx CC 15
# 01-17-2013 - Mattress Firm - Adhoc.xlsx Output 1
# 2.4.29 2.4.10_Debt Schedules_MLI (No APC Data).xlsx PPEC NO VIN or State
# 2.4.29 2.4.10_Debt Schedules_MLI (No APC Data).xlsx PY NO VIN or State
# 2.4.29 2.4.10_Debt Schedules_MLI (No APC Data).xlsx Sheet1 NO VIN or State
# 2.4.29 2.4.10_Debt Schedules_MLI (No APC Data).xlsx 1 - Capital Lease RF NO VIN or State
# 2.4.29 2.4.10_Debt Schedules_MLI (No APC Data).xlsx 2 - Note Payable RF NO VIN or State
# 2014-15 Auto Schedule.xlsx Update Form 17
# 2014-15 Auto Schedule.xlsx Summary 08.01.14 3
# 2014-15 Auto Schedule.xlsx Sheet2 Empty Sheet
# 2014Q2 Truck Inventory Update 2014-07-28.xlsx Update Form 17
# 2014Q2 Truck Inventory Update 2014-07-28.xlsx Summary 08.01.14 3
# 2014Q2 Truck Inventory Update 2014-07-28.xlsx Sheet2 Empty Sheet
# ...

# %%
test = QC_table[['File Name','SheetName',"index of row contains 'V/S'"]].to_dict(orient='list')
header_dict = {}
sheet_dict = {}
for a, b,c in zip(test['File Name'],test['SheetName'], test["index of row contains 'V/S'"]):
#     print(a,b,c)
    temp = {}
    temp[b] = c
    if a not in header_dict:
        header_dict[a] = temp
    else:
        header_dict[a].update(temp)
header_dict
# Out:
# {'01-17-2013 - Mattress Firm - Adhoc #50358.xlsx': {'CC': '15', 'Output': '1'},
#  '01-17-2013 - Mattress Firm - Adhoc.xlsx': {'CC': '15', 'Output': '1'},
#  '2.4.29 2.4.10_Debt Schedules_MLI (No APC Data).xlsx': {'PPEC': 'NO VIN or State',
#   'PY': 'NO VIN or State',
#   'Sheet1': 'NO VIN or State',
#   '1 - Capital Lease RF': 'NO VIN or State',
#   '2 - Note Payable RF': 'NO VIN or State'},
#  '2014-15 Auto Schedule.xlsx': {'Update Form': '17',
#   'Summary 08.01.14': '3',
#   'Sheet2': 'Empty Sheet'},
#  '2014Q2 Truck Inventory Update 2014-07-28.xlsx': {'Update Form': '17',
#   'Summary 08.01.14': '3',
#   'Sheet2': 'Empty Sheet'},
#  'Auto Schedule as of 10.10.12.xls': {'Auto Schedule 11-12': '1',
#   'Sheet2': '1'},
#  'Auto Schedule as of 11.5.13. sent for renewal.xls': {'Update Form': '17',
#   'P7 Update': '1'},
#  'CHECKLIST FOR VEHICLE TRANSFERS.xlsx': {'Sheet1': '3',
#   'Sheet2': 'Empty Sheet',
#   'Sheet3': 'Empty Sheet'},
# ...

# %%
header_dict
# Out:
# {'01-17-2013 - Mattress Firm - Adhoc #50358.xlsx': {'CC': '15', 'Output': '1'},
#  '01-17-2013 - Mattress Firm - Adhoc.xlsx': {'CC': '15', 'Output': '1'},
#  '2.4.29 2.4.10_Debt Schedules_MLI (No APC Data).xlsx': {'PPEC': 'NO VIN or State',
#   'PY': 'NO VIN or State',
#   'Sheet1': 'NO VIN or State',
#   '1 - Capital Lease RF': 'NO VIN or State',
#   '2 - Note Payable RF': 'NO VIN or State'},
#  '2014-15 Auto Schedule.xlsx': {'Update Form': '17',
#   'Summary 08.01.14': '3',
#   'Sheet2': 'Empty Sheet'},
#  '2014Q2 Truck Inventory Update 2014-07-28.xlsx': {'Update Form': '17',
#   'Summary 08.01.14': '3',
#   'Sheet2': 'Empty Sheet'},
#  'Auto Schedule as of 10.10.12.xls': {'Auto Schedule 11-12': '1',
#   'Sheet2': '1'},
#  'Auto Schedule as of 11.5.13. sent for renewal.xls': {'Update Form': '17',
#   'P7 Update': '1'},
#  'CHECKLIST FOR VEHICLE TRANSFERS.xlsx': {'Sheet1': '3',
#   'Sheet2': 'Empty Sheet',
#   'Sheet3': 'Empty Sheet'},
# ...
