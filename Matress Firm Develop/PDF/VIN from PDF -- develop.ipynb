# %%
import glob
import pandas as pd
import re
import textract
import PyPDF2

# %%
Files = glob.glob(r'C:\Users\FFR0103\Desktop\My files\WORK\Auto part\Mattress Firm\PDF_OCR\*.pdf')
for i, file in enumerate(Files):
    print(i, file)
# Out:
# 0 C:\Users\FFR0103\Desktop\My files\WORK\Auto part\Mattress Firm\PDF_OCR\2.4.10 2.4.3 2013 Mattress King BNA Report Updated_OCR.pdf
# 1 C:\Users\FFR0103\Desktop\My files\WORK\Auto part\Mattress Firm\PDF_OCR\2.4.27 2.4.10_Hino Trucks_CoBiz Loan_March 2013_OCR.pdf
# 2 C:\Users\FFR0103\Desktop\My files\WORK\Auto part\Mattress Firm\PDF_OCR\2.4.28 2.4.10_Hino Truck Purchase Documentation_OCR.pdf
# 3 C:\Users\FFR0103\Desktop\My files\WORK\Auto part\Mattress Firm\PDF_OCR\2.4.37 2.4.10_2011 Toyota Truck Purchases_OCR.pdf
# 4 C:\Users\FFR0103\Desktop\My files\WORK\Auto part\Mattress Firm\PDF_OCR\2.9.1.7 2.4.10 Toyota Note Payable Acct 2036 & 2037_OCR.pdf
# 5 C:\Users\FFR0103\Desktop\My files\WORK\Auto part\Mattress Firm\PDF_OCR\2.9.2.1 2.9.1 COBIZ TRUCK PURCHASE LOAN DOCUMENTATION_OCR.pdf
# 6 C:\Users\FFR0103\Desktop\My files\WORK\Auto part\Mattress Firm\PDF_OCR\2.9.2.4 2.9.1 TRUCK 10 TOYOTA FINANCE_OCR.pdf
# ...

# %%
pdfFileObj = open(Files[0],'rb')
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
pdfReader.getNumPages()
# Out:
# 15

# %%
pdfFileObj = open(Files[37],'rb')
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
text = pdfReader.getPage(0).extractText()
re.findall('(?=([A-Za-z0-9]*| )[A-z])(?=([A-Za-z0-9]*| )[0-9])[14523jJkKsSvVtTwWyYzZ][A-Za-z0-9 ]{10,20}',text)
# Out:
# [('14P', '1'), ('16T', '1')]

# %%
for file in Files:
    print(file.split('\\')[-1])
# Out:
# 2.4.10 2.4.3 2013 Mattress King BNA Report Updated_OCR.pdf
# 2.4.27 2.4.10_Hino Trucks_CoBiz Loan_March 2013_OCR.pdf
# 2.4.28 2.4.10_Hino Truck Purchase Documentation_OCR.pdf
# 2.4.37 2.4.10_2011 Toyota Truck Purchases_OCR.pdf
# 2.9.1.7 2.4.10 Toyota Note Payable Acct 2036 & 2037_OCR.pdf
# 2.9.2.1 2.9.1 COBIZ TRUCK PURCHASE LOAN DOCUMENTATION_OCR.pdf
# 2.9.2.4 2.9.1 TRUCK 10 TOYOTA FINANCE_OCR.pdf
# 2.9.2.5 2.9.1 TRUCK 11 TOYOTA FINANCE_OCR.pdf
# 2012 Tax Bill. VIN#1186 and 2378_OCR.pdf
# 2012 Veh Tax Bill. VIN#1186 and 2378_OCR.pdf
# 20140109154406115_OCR.pdf
# 20140109154437503_OCR.pdf
# 20140123113558664_OCR.pdf
# 20140606115234642_OCR.pdf
# 20141205095115685_OCR.pdf
# 20151105084108731_OCR.pdf
# 7.5.14 Titles with Signed Releases_2008 HINO 1313 & 1285_OCR.pdf
# April 25, 2014_OCR.pdf
# AR Renewal JNAMB80H05AN50271 011314_OCR.pdf
# Atlanta GA 7000 -1995 Ford TK_OCR.pdf
# Boise ID 82000 Insp_OCR.pdf
# Boise truck[1]_OCR.pdf
# Central ID 89000 Insp_OCR.pdf
# ...

# %%
for file in Files:
    pdfFileObj = open(file,'rb')
    pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
    for i in range(pdfReader.getNumPages()):
        a = file.split('\\')[-1]
        text = pdfReader.getPage(i).extractText()
        print(f"File Name : {a},\nPagenum: {i+1},\nPossibel VINs: {re.findall('(?=[A-Za-z0-9]{0,20}?[A-z])(?=[A-Za-z0-9]{0,10}?[0-9])[14523jJkKsSvVtTwWyYzZ][a-zA-Z][A-Za-z0-9 ]{10,20}',text)}\n\n\n")
    
              
# (?=[A-Za-z0-9 ]{13,20}[A-z])(?=[A-Za-z0-9 ]{13,20}[0-9])[14523jJkKsSvVtTwWyYzZ][A-Za-z0-9 ]{10,20}
# (?=[0-9A-Za-z ]{13,20}[A-Za-z])(?=[0-9A-Za-z ]{13,20}[0-9])[A-Za-z0-9]{10,20}
# Out:
# File Name : 2.4.10 2.4.3 2013 Mattress King BNA Report Updated_OCR.pdf,
# Pagenum: 1,
# Possibel VINs: ['3SL100FM5 0159', '5SL100FM5 0818', '4SL100FM5 0899', 'SL100FM5 0706', '4SL100FM5 0548', 'SL100FM5 0807', 'SL100FM5 0462', '5SL100FM5 0662', 'SL100FM5 0870', '2SL100FM5 0678', '1SL100FM5 0896', '2SL100FM5 0555', '5SL100FM5 0926', 'SL100FM5 0721', '3SL100FM5 02', '2SL100FM5 0628', '2SL100FM5 0441', '2SL100FM5 0560', 'SL100FM5 0499', 'SL100FM5 0518', '1SL100FM5 0560', '2SL100FM5 0470', '1SL100FM5 0553']
#
#
#
# File Name : 2.4.10 2.4.3 2013 Mattress King BNA Report Updated_OCR.pdf,
# Pagenum: 2,
# ...

# %%
for file in Files:
    pdfFileObj = open(file,'rb')
    pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
    for i in range(pdfReader.getNumPages()):
        a = file.split('\\')[-1]
        text = pdfReader.getPage(i).extractText()
        print(re.findall('((?!.*/|=|!|:|@|\*)(?=.*\d)(?=.*[A-Z])(?=.*[a-z]).{17,20})',text))
# Out:
# ['For the Period Janua', 'ry 1, 2013 to Decemb', '2009 Computers (TR A']
# ['Computer Store 44 P9', 'Computer Store 6 Del', 'Computer Store 4 HP ', 'Computer Store 36 HP', 'HP Computer S5-111 O', 'Computer Store 12 Ch', 'Insignia ND-D150A13 ', 'Store 45 computer', 'Subtotal:  Computer ']
# ['Fireplace at Bannock', 'Nutting Mover #10', 'Subtotal:  Furniture']
# []
# []
# []
# []
# []
# []
# ['2009 Leasehold Impro']
# ['51.46Carpet at CO01', 'Remodel of Store 30', '73Fireplace Store 30', 'INVOICE 11-0138-1 Da', 'Balance of Invoice 1', '2 Down-Per Revised E', 'Replace first 24 Sky', 'Replace first 24 Sky', 'Down Payment on 2nd ', '7LHI - Westminster M', 'LHI - Lone Tree - 7', 'LHI - Northglenn - 1', 'LHI - C. Colorado Sp', 'LHI - N. Colorado Sp', 'LHI - Greeley - 18', 'LHI - Dillon - 20', '2LHI - Denver West A']
# ['sLHI - Tamarac - 35', 'LHI - Fort Collins -', 'LHI - Loveland - 37', 'LHI - Englewood - 39', 'LHI - Highlands Ranc', 'LHI - Powers Colo Sp', 'LHI - Cornerstar - 4']
# ...
