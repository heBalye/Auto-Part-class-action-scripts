# %%
from CleanVIN import ValidationProcess, df_to_str
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\FFR0103\Desktop\My files\WORK\Auto part\Mattress Firm\VIN API\MattressFirm01162020 Vin to Validate.xlsx')
df
# Out:
#                    VIN   RowId
# 0    11VACWDT6CHBP3084  361135
# 1        123456XY12YYY  361136
# 2    1B01A4522ES113364  361137
# 3    1BK10VA24EE210702  361138
# 4    1C4NJPBB3DD169681  361139
# 5    1C4NJPBB3ED715297  361140
# 6    1C4NJPBB5ED503324  361141
# 7    1C4NJPBB9CD570926  361142
# 8    1C4NJPBBXCD634925  361143
# 9           1CGFG15X57  361144
# 10   1CGFG15X571137781  361145
# 11          1CGFG15X96  361146
# 12   1CGFG15X961266587  361147
# 13    1FAFP34N17W94406  361148
# 14   1FDKE3756VHB24815  361149
# 15   1FDKE37S6VHB24815  361150
# 16   1FDKF3756VHB24815  361151
# 17   1FDKF37G4SNB14709  361152
# 18   1FDKF37G4VEB50131  361153
# 19   1FDKF37G7TEB15323  361154
# 20   1FDUF4GY0CEC58444  361155
# 21   1FDWE35L03HBA3045  361156
# 22   1FDXE45F33HB85697  361157
# 23   1FDXE45P44HA69404  361158
# 24   1FTDF15Y6RNA32665  361159
# 25   1FTRE14W44HA03827  361160
# 26   1FTRE14W45HA21150  361161
# 27   1FTRE14W56HA57088  361162
# 28   1FTRE14W66DA97431  361163
# ...

# %%
Data = df_to_str(df,'VIN',';')
# Out:
# True

# %%
pd.Series(process.split_to_Chunk(4)['Chunk93'].split(';'))

# %%
process = ValidationProcess(Data,4)

# %%
process.split_to_Chunk(4)['Chunk93']

# %%
result = process.getAll()

# %%
result.to_excel(r'C:\Users\FFR0103\Desktop\My files\WORK\Auto part\Mattress Firm\VIN API\ValidatedVIN_01162020.xlsx',index = False)
