# %%
import pandas as pd
import glob

# %%
FileName = glob.glob('C:\\Users\\FFR0103\\Desktop\\My files\\WORK\\Auto part\\Mattress Firm\\Source\\*.*')

# %%
Dict = {}
for i,file in enumerate(FileName):
    print('#of file',i)
    DF = pd.read_excel(file,sheet_name=None, header=None, dtype=str)
    Dict[file.split('\\')[-1]] =pd.DataFrame()
    for i,sheet in enumerate(DF):
        if len(DF[sheet]) > 0:
            for row in range(len(DF[sheet])):                
                if DF[sheet].iloc[row, :].str.contains('state|vin',regex = True, case = False,na=False).sum() > 0:
                    df = pd.DataFrame({'File Name' :file.split('\\')[-1], 'Index of Sheet':i+1,'SheetName': [str(sheet)],'Row number contains \'V/S\'':[str(row + 1 )]})
                    break
                df = pd.DataFrame({'File Name' :file.split('\\')[-1], 'Index of Sheet':i+1,'SheetName': [str(sheet)],'Row number contains \'V/S\'':['NO VIN or State']})
        else:
            df = pd.DataFrame({'File Name' :file.split('\\')[-1],'Index of Sheet':i+1,'SheetName': [str(sheet)],'Row number contains \'V/S\'':['Empty Sheet']})
        Dict[file.split('\\')[-1]] = pd.concat([Dict[file.split('\\')[-1]],df],sort=False)
QC_table = pd.concat(Dict,sort = False)
QC_table
# Out:
# #of file 0
# #of file 1
# #of file 2
# #of file 3
# #of file 4
# #of file 5
# #of file 6
# #of file 7
# #of file 8
# #of file 9
# #of file 10
# #of file 11
# #of file 12
# #of file 13
# #of file 14
# #of file 15
# #of file 16
# #of file 17
# #of file 18
# #of file 19
# #of file 20
# #of file 21
# #of file 22
# #of file 23
# #of file 24
# #of file 25
# #of file 26
# #of file 27
# #of file 28
# #of file 29
# #of file 30
# #of file 31
# #of file 32
# #of file 33
# #of file 34
# #of file 35
# #of file 36
# #of file 37
# #of file 38
# #of file 39
# #of file 40
# #of file 41
# #of file 42
# #of file 43
#                                                                                               File Name  \
# 01-17-2013 - Mattress Firm - Adhoc #50358.xlsx     0     01-17-2013 - Mattress Firm - Adhoc #50358.xlsx
#                                                    0     01-17-2013 - Mattress Firm - Adhoc #50358.xlsx
# ...

# %%
QC_table.to_excel('C:\\Users\\FFR0103\\Desktop\\My files\\WORK\\Auto part\\Mattress Firm\\Output\\123.xlsx')
