# %%
import httplib2
import json
import sys
import codecs
import pandas as pd
from fuzzywuzzy import process
from fuzzywuzzy import fuzz
import numpy as np

# %%
def getMake():
    url = ('https://vpic.nhtsa.dot.gov/api/vehicles/GetAllMakes?format=json')
    h = httplib2.Http()
    response, content = h.request(url, 'GET')
    result = json.loads(content)
    return pd.DataFrame(result['Results'])

def getMakeID(Make):
    url = ('https://vpic.nhtsa.dot.gov/api/vehicles/GetAllMakes?format=json')
    h = httplib2.Http()
    response, content = h.request(url, 'GET')
    result = json.loads(content)
    MK_df = pd.DataFrame(result['Results'])
    result_df = MK_df[MK_df['Make_Name'].str.contains(Make)]
    return result_df

def getModel(Make):
    url = ('https://vpic.nhtsa.dot.gov/api/vehicles/GetModelsForMake/%s?format=json' %Make)
    h = httplib2.Http()
    response, content = h.request(url, 'GET')
    result = json.loads(content)
    return pd.DataFrame(result['Results'])

def getModel_Year(Make,Year):
    url = ('https://vpic.nhtsa.dot.gov/api/vehicles/GetModelsForMakeYear/make/%s/modelyear/%s?format=json' %(Make,Year))
    h = httplib2.Http()
    response, content = h.request(url, 'GET')
    result = json.loads(content)
    return pd.DataFrame(result['Results'])

def getModel_Year_MakeID(MakeID,Year):
    url = ('https://vpic.nhtsa.dot.gov/api//vehicles/GetModelsForMakeIdYear/makeId/%s/modelyear/%s?format=json' %(MakeID,Year))
    h = httplib2.Http()
    response, content = h.request(url, 'GET')
    result = json.loads(content)
    return pd.DataFrame(result['Results'])

def getMatch(Make_id,Year):
    Rlist = []
    try:
        Valid_df = getModel_Year_MakeID(Make_id,Year)

    except:
        QC_Make_year = ME_df[(ME_df.Make.str.lower() == dictionary[Make_id]) & (ME_df.Year == Year)].sort_values(by=['Make','Year','Model'])
        Rlist=['No Such year in the Database'] *len(QC_Make_year)
    else:
        QC_Make_year = ME_df[(ME_df.Make.str.lower() == dictionary[Make_id]) & (ME_df.Year == Year)].sort_values(by=['Make','Year','Model'])
        for i in range(len(QC_Make_year.Model)):
            str2Match = str(QC_Make_year.Model.values[i])
            strOptions = [z for z in Valid_df.Model_Name]
            Ratios = process.extract(str2Match,strOptions)
            Rlist.append([a + ': ' +str(dict(Ratios)[a]) for a in dict(Ratios)])
    return Rlist
# With score
# def getExactMatch(Make_id,Year):
#     Rlist = []
#     try:
#         Valid_df = getModel_Year_MakeID(Make_id,Year)
        
#     except:
#         QC_Make_year = ME_df[(ME_df.Make.str.lower() == dictionary[Make_id]) & (ME_df.Year == Year)].sort_values(by=['Make','Year','Model'])
#         Rlist=['No Such year in the Database'] *len(QC_Make_year)
#     else:
#         QC_Make_year = ME_df[(ME_df.Make.str.lower() == dictionary[Make_id]) & (ME_df.Year == Year)].sort_values(by=['Make','Year','Model'])
#         for i in range(len(QC_Make_year.Model)):
#             str2Match = str(QC_Make_year.Model.values[i])
#             strOptions = [z for z in Valid_df.Model_Name]
#             Ratios= process.extractOne(str2Match,strOptions, scorer=fuzz.ratio)
#             Rlist.append((':'.join([ str(a) for a in list(Ratios)])))
#     return Rlist

def getTopMatch(Make_id,Year):
    Rlist = []
    try:
        Valid_df = getModel_Year_MakeID(Make_id,Year)
        
    except:
        QC_Make_year = ME_df[(ME_df.Make.str.lower() == dictionary[Make_id]) & (ME_df.Year == Year)].sort_values(by=['Make','Year','Model'])
        Rlist=['No Such year in the Database'] *len(QC_Make_year)
    else:
        QC_Make_year = ME_df[(ME_df.Make.str.lower() == dictionary[Make_id]) & (ME_df.Year == Year)].sort_values(by=['Make','Year','Model'])
        for i in range(len(QC_Make_year.Model)):
            str2Match = str(QC_Make_year.Model.values[i])
            strOptions = [z for z in Valid_df.Model_Name]
            Ratios= process.extractOne(str2Match,strOptions)
            Rlist.append(( list(Ratios)[0]))
    return Rlist

def getQCtable_OneYear(Make_id,Year):    
    QC_Make_Year = ME_df[(ME_df.Make.str.lower() == dictionary[Make_id]) & (ME_df.Year == Year)].sort_values(by=['Make','Year','Model'])
    QC_Make_Year['TopMatch'] = getTopMatch(Make_id,Year)
    QC_Make_Year['MatchOptions'] = getMatch(Make_id,Year)        
    QC_Make_Year['Match'] = np.where(QC_Make_Year.Model.str.lower() == QC_Make_Year.TopMatch.str.lower(), 'Yes', 'No')
    QC_Make_Year['HighestScore'] = [int(rec[0].split(': ')[1]) if type(rec) != str else 'N/A' for rec in QC_Make_Year['MatchOptions']]
    QC_Make_Year['TopMaTchExsting'] = [np.where(QC_Make_Year['TopMatch'].values[i].lower() in QC_Make_Year.Model.str.lower().unique(),'Yes','No') for i in range(len(QC_Make_Year['TopMatch']))]
    QC_Make = pd.concat([QC_Make,QC_Make_Year])
    return QC_Make_Year

def getQCtable_Allyear(Make_id):    
    QC_Make = pd.DataFrame()
    Years = list(ME_df[ME_df.Make.str.lower() == dictionary[Make_id]].Year.unique())
    for Year in Years:
        QC_Make_Year = ME_df[(ME_df.Make.str.lower() == dictionary[Make_id]) & (ME_df.Year == Year)].sort_values(by=['Make','Year','Model'])
        QC_Make_Year['TopMatch'] = getTopMatch(Make_id,Year)
        QC_Make_Year['MatchOptions'] = getMatch(Make_id,Year)        
        QC_Make_Year['Match'] = np.where(QC_Make_Year.Model.str.lower() == QC_Make_Year.TopMatch.str.lower(), 'Yes', 'No')
        QC_Make_Year['HighestScore'] = [int(rec[0].split(': ')[1]) if type(rec) != str else 'N/A' for rec in QC_Make_Year['MatchOptions']]
        QC_Make_Year['TopMaTchExsting'] = [np.where(QC_Make_Year['TopMatch'].values[i].lower() in QC_Make_Year.Model.str.lower().unique(),'Yes','No') if QC_Make_Year['HighestScore'].values[i] >= 80 else 'No' for i in range(len(QC_Make_Year['TopMatch']))]
        QC_Make = pd.concat([QC_Make,QC_Make_Year])
    return QC_Make

# def getHightestScores(Make_id,Year):
#     Scores = []
#     if type(getMatch(Make_id,Year)[0]) !=str:
#         for rec in getMatch(Make_id,Year):
#             Scores.append(int(rec[0].split(': ')[1]))
#     else:
#         Scores='N/A'
#     return Scores

# %%
getMakeID('Isuzu')
# Out:
#       Make_ID      Make_Name
# 4082      542          Isuzu
# 7323     3760  Spartan/Isuzu

# %%
# def getMake():
#     url = ('https://vpic.nhtsa.dot.gov/api/vehicles/GetAllMakes?format=json')
#     h = httplib2.Http()
#     response, content = h.request(url, 'GET')
#     result = json.loads(content)
#     return pd.DataFrame(result['Results'])

# def getMakeID(Make):
#     url = ('https://vpic.nhtsa.dot.gov/api/vehicles/GetAllMakes?format=json')
#     h = httplib2.Http()
#     response, content = h.request(url, 'GET')
#     result = json.loads(content)
#     MK_df = pd.DataFrame(result['Results'])
#     result_df = MK_df[MK_df['Make_Name'].str.contains(Make)]
#     return result_df

# def getModel(Make):
#     url = ('https://vpic.nhtsa.dot.gov/api/vehicles/GetModelsForMake/%s?format=json' %Make)
#     h = httplib2.Http()
#     response, content = h.request(url, 'GET')
#     result = json.loads(content)
#     return pd.DataFrame(result['Results'])

# def getModel_Year(Make,Year):
#     url = ('https://vpic.nhtsa.dot.gov/api/vehicles/GetModelsForMakeYear/make/%s/modelyear/%s?format=json' %(Make,Year))
#     h = httplib2.Http()
#     response, content = h.request(url, 'GET')
#     result = json.loads(content)
#     return pd.DataFrame(result['Results'])

# def getModel_Year_MakeID(MakeID,Year):
#     url = ('https://vpic.nhtsa.dot.gov/api//vehicles/GetModelsForMakeIdYear/makeId/%s/modelyear/%s?format=json' %(MakeID,Year))
#     h = httplib2.Http()
#     response, content = h.request(url, 'GET')
#     result = json.loads(content)
#     return pd.DataFrame(result['Results'])

# def getMatch(Make_id,Year):
#     Rlist = []
#     try:
#         Valid_df = getModel_Year_MakeID(Make_id,Year)

#     except:
#         Rlist.append('No Such year in the Database')
#     else:
#         QC_ford_year = ME_df[(ME_df.Make.str.lower() == 'ford') & (ME_df.Year == Year)].sort_values(by=['Make','Year','Model'])
#         for i in range(len(QC_ford_year.Model)):
#             str2Match = str(QC_ford_year.Model.values[i])
#             strOptions = [z for z in Valid_df.Model_Name]
#             Ratios = process.extract(str2Match,strOptions)
#             Rlist.append([a + ': ' +str(dict(Ratios)[a]) for a in dict(Ratios)])
#     return Rlist
# def getQCtable_Allyear(Make_id):    
#     QC_Make = pd.DataFrame()
#     Years = list(ME_df[ME_df.Make.str.lower() == 'ford'].Year.unique())
#     for Year in Years:
#         QC_Make_Year = ME_df[(ME_df.Make.str.lower() == 'ford') & (ME_df.Year == Year)].sort_values(by=['Make','Year','Model'])
#         QC_Make_Year['Match'] = getMatch(Make_id,Year)
#         QC_Make = pd.concat([QC_Make,QC_Make_Year])
#     return QC_Make
# def getQCtable_OneYear(Make_id,Year):
#     QC_Make_Year = ME_df[(ME_df.Make.str.lower() == 'ford') & (ME_df.Year == Year)].sort_values(by=['Make','Year','Model'])
#     QC_Make_Year['Match'] = getMatch(Make_id,Year)
#     return QC_Make_Year

# %%
dictionary = {460:'ford',452:'bmw',467 :'chevrolet', 448:'toyota'}
ME_df = pd.read_excel('C:\\Users\\FFR0103\\Desktop\\My files\\WORK\\Auto part\\QC process\\F and E Series update 12020219.xlsx', sheet_name = 'MasterEligible', dtype=str)
ME_df
# Out:
#         Make  Model  Year           RyanAddRemoveDate RyanEligibleFlag  \
# 0      Acura     CL  1997  2018-05-17 16:53:40.733000                Y
# 1      Acura     CL  2000         2017-11-30 00:00:00                Y
# 2      Acura     CL  2001         2017-11-30 00:00:00                Y
# 3      Acura     CL  2002         2017-11-30 00:00:00                Y
# 4      Acura     CL  2003         2017-11-30 00:00:00                Y
# 5      Acura     CL  2004         2017-11-30 00:00:00                Y
# 6      Acura     CL  2004  2019-09-25 16:03:15.593000                Y
# 7      Acura    CSX  2005         2017-11-30 00:00:00                Y
# 8      Acura    CSX  2006         2017-11-30 00:00:00                Y
# 9      Acura    CSX  2007         2017-11-30 00:00:00                Y
# 10     Acura    CSX  2008         2017-11-30 00:00:00                Y
# 11     Acura    CSX  2009         2017-11-30 00:00:00                Y
# 12     Acura    CSX  2010         2017-11-30 00:00:00                Y
# 13     Acura    CSX  2011         2017-11-30 00:00:00                Y
# 14     Acura    CYR  2005         2017-11-30 00:00:00                Y
# 15     Acura    CYR  2006         2017-11-30 00:00:00                Y
# 16     Acura    CYR  2007         2017-11-30 00:00:00                Y
# 17     Acura    CYR  2008         2017-11-30 00:00:00                Y
# 18     Acura     EL  1997  2018-05-17 16:53:40.733000                Y
# 19     Acura     EL  1998         2017-11-30 00:00:00                Y
# 20     Acura     EL  1999         2017-11-30 00:00:00                Y
# 21     Acura     EL  2000         2017-11-30 00:00:00                Y
# 22     Acura     EL  2001         2017-11-30 00:00:00                Y
# 23     Acura     EL  2002         2017-11-30 00:00:00                Y
# 24     Acura     EL  2003         2017-11-30 00:00:00                Y
# 25     Acura     EL  2004         2017-11-30 00:00:00                Y
# 26     Acura     EL  2005         2017-11-30 00:00:00                Y
# 27     Acura    ILX  2000  2018-05-17 16:53:40.733000                Y
# 28     Acura    ILX  2001  2018-05-17 16:53:40.733000                Y
# 29     Acura    ILX  2002  2018-05-17 16:53:40.733000                Y
# ...      ...    ...   ...                         ...              ...
# 11076  Volvo  XC-60  2018  2019-09-25 16:03:15.593000                Y
# 11077  Volvo   XC70  2000  2018-05-17 16:53:40.733000                Y
# 11078  Volvo   XC70  2001  2018-05-17 16:53:40.733000                Y
# 11079  Volvo   XC70  2002  2018-05-17 16:53:40.733000                Y
# 11080  Volvo   XC70  2003  2018-05-17 16:53:40.733000                Y
# 11081  Volvo   XC70  2004  2018-05-17 16:53:40.733000                Y
# 11082  Volvo   XC70  2005  2018-05-17 16:53:40.733000                Y
# 11083  Volvo   XC70  2006  2018-05-17 16:53:40.733000                Y
# 11084  Volvo   XC70  2007  2018-05-17 16:53:40.733000                Y
# 11085  Volvo   XC70  2008         2017-11-30 00:00:00                Y
# 11086  Volvo   XC70  2009         2017-11-30 00:00:00                Y
# 11087  Volvo   XC70  2010         2017-11-30 00:00:00                Y
# 11088  Volvo   XC70  2011         2017-11-30 00:00:00                Y
# 11089  Volvo   XC90  2002         2017-11-30 00:00:00                Y
# 11090  Volvo   XC90  2003         2017-11-30 00:00:00                Y
# 11091  Volvo   XC90  2004         2017-11-30 00:00:00                Y
# 11092  Volvo   XC90  2005         2017-11-30 00:00:00                Y
# 11093  Volvo   XC90  2006  2018-05-17 16:53:40.733000                Y
# 11094  Volvo   XC90  2007  2018-05-17 16:53:40.733000                Y
# 11095  Volvo   XC90  2008  2018-05-17 16:53:40.733000                Y
# 11096  Volvo   XC90  2009  2018-05-17 16:53:40.733000                Y
# 11097  Volvo   XC90  2010  2018-05-17 16:53:40.733000                Y
# 11098  Volvo   XC90  2011  2018-05-17 16:53:40.733000                Y
# 11099  Volvo   XC90  2012  2018-05-17 16:53:40.733000                Y
# 11100  Volvo   XC90  2013  2018-05-17 16:53:40.733000                Y
# 11101  Volvo   XC90  2014  2018-05-17 16:53:40.733000                Y
# 11102  Volvo   XC90  2015         2017-11-30 00:00:00                Y
# 11103  Volvo   XC90  2016         2017-11-30 00:00:00                Y
# 11104  Volvo   XC90  2017  2018-05-17 16:53:40.733000                Y
# 11105  Volvo   XC90  2018  2018-05-17 16:53:40.733000                Y
#
#                                               RyanSource RyanDescription
# 0                                round 3 list per Denise         Round 3
# 1                                autopartsclass.com List     Round 1 & 2
# 2                                autopartsclass.com List     Round 1 & 2
# 3                                autopartsclass.com List     Round 1 & 2
# 4                                autopartsclass.com List     Round 1 & 2
# 5                                autopartsclass.com List     Round 1 & 2
# 6      Round 4 Eligible Vehicle List 09-18-2019.XLSX ...         Round 4
# 7                                autopartsclass.com List     Round 1 & 2
# 8                                autopartsclass.com List     Round 1 & 2
# 9                                autopartsclass.com List     Round 1 & 2
# 10                               autopartsclass.com List     Round 1 & 2
# 11                               autopartsclass.com List     Round 1 & 2
# 12                               autopartsclass.com List     Round 1 & 2
# 13                               autopartsclass.com List     Round 1 & 2
# 14                               autopartsclass.com List     Round 1 & 2
# 15                               autopartsclass.com List     Round 1 & 2
# 16                               autopartsclass.com List     Round 1 & 2
# 17                               autopartsclass.com List     Round 1 & 2
# 18                               round 3 list per Denise         Round 3
# 19                               autopartsclass.com List     Round 1 & 2
# 20                               autopartsclass.com List     Round 1 & 2
# 21                               autopartsclass.com List     Round 1 & 2
# 22                               autopartsclass.com List     Round 1 & 2
# 23                               autopartsclass.com List     Round 1 & 2
# 24                               autopartsclass.com List     Round 1 & 2
# 25                               autopartsclass.com List     Round 1 & 2
# 26                               autopartsclass.com List     Round 1 & 2
# 27                               round 3 list per Denise         Round 3
# 28                               round 3 list per Denise         Round 3
# 29                               round 3 list per Denise         Round 3
# ...                                                  ...             ...
# 11076  Round 4 Eligible Vehicle List 09-18-2019.XLSX ...         Round 4
# 11077                            round 3 list per Denise         Round 3
# 11078                            round 3 list per Denise         Round 3
# 11079                            round 3 list per Denise         Round 3
# 11080                            round 3 list per Denise         Round 3
# 11081                            round 3 list per Denise         Round 3
# 11082                            round 3 list per Denise         Round 3
# 11083                            round 3 list per Denise         Round 3
# 11084                            round 3 list per Denise         Round 3
# 11085                            autopartsclass.com List     Round 1 & 2
# 11086                            autopartsclass.com List     Round 1 & 2
# 11087                            autopartsclass.com List     Round 1 & 2
# 11088                            autopartsclass.com List     Round 1 & 2
# 11089                            autopartsclass.com List     Round 1 & 2
# 11090                            autopartsclass.com List     Round 1 & 2
# 11091                            autopartsclass.com List     Round 1 & 2
# 11092                            autopartsclass.com List     Round 1 & 2
# 11093                            round 3 list per Denise         Round 3
# 11094                            round 3 list per Denise         Round 3
# 11095                            round 3 list per Denise         Round 3
# 11096                            round 3 list per Denise         Round 3
# 11097                            round 3 list per Denise         Round 3
# 11098                            round 3 list per Denise         Round 3
# 11099                            round 3 list per Denise         Round 3
# 11100                            round 3 list per Denise         Round 3
# 11101                            round 3 list per Denise         Round 3
# 11102                            autopartsclass.com List     Round 1 & 2
# 11103                            autopartsclass.com List     Round 1 & 2
# 11104                            round 3 list per Denise         Round 3
# 11105                            round 3 list per Denise         Round 3
#
# [11106 rows x 7 columns]

# %% [markdown]
# ## Use FORD 1992 as an example

# %%
ME_df[ME_df.Make == 'Ford'].sort_values(by=['Make','Year','Model'])

# %%
getMakeID('Ford')

# %%
Ford_id = 460
Vali_df = getModel_Year_MakeID(Ford_id,'1992')
ME_ford_1992 = ME_df[(ME_df.Make == 'Ford') & (ME_df.Year == '2002')].sort_values(by=['Make','Year','Model'])
display(Vali_df)
ME_ford_1992

# %%
str2Match = ME_ford_1992.Model.values[8]
strOptions = [i for i in Vali_df.Model_Name]
print(str2Match)
Ratios = process.extract(str2Match,strOptions,limit =5)
print(dict(Ratios))
list(dict(Ratios))
[a + ': ' +str(dict(Ratios)[a]) for a in dict(Ratios)]
ME_ford_1992.Model.values[0]
len(ME_ford_1992.Model)

# %%
Make_id = 460

QC_Ford = getQCtable_Allyear(Make_id)

# %%
QC_Ford

# %%
QC_Ford_sorted = QC_Ford.sort_values(by=['Make','Model','Year'])
QC_Ford_sorted.to_excel('C:\\Users\\FFR0103\\Desktop\\My files\\WORK\\Auto part\\QC process\\QC_ford.xlsx',index = False)

# %%
display(getModel('Chevrolet')[getModel('Chevrolet').Model_Name.str.contains('')])
getModel_Year_MakeID(467,'2003')[getModel_Year_MakeID(467,'2003').Model_Name.str.lower().str.contains('')]

# %% [markdown]
# ## Test Different Scorer

# %%
Rlist = []
Rlist1 = []
Valid_df = getModel_Year_MakeID(460,'2000')
QC_Make_year = ME_df[(ME_df.Make.str.lower() == 'ford') & (ME_df.Year == '2000')].sort_values(by=['Make','Year','Model'])
for i in range(len(QC_Make_year.Model)):
    str2Match = str(QC_Make_year.Model.values[i])
    strOptions = [z for z in Valid_df.Model_Name]
    Ratios = process.extract(str2Match,strOptions)
    Ratios1= process.extractOne(str2Match,strOptions, scorer=fuzz.ratio)
    Rlist.append([a + ': ' +str(dict(Ratios)[a]) for a in dict(Ratios)])
    Rlist1.append((':'.join([ str(a) for a in list(Ratios1)])))
Rlist1

# %%
getExactMatch(460,'2000')

# %%
len(getMatch(460,'2000')) ==len(getExactMatch(460,'2000'))

# %%
 len(getMatch(460,'1999'))== len(getExactMatch(460,'1999'))

# %%
def getMatch(Make_id,Year):
    Rlist = []
    try:
        Valid_df = getModel_Year_MakeID(Make_id,Year)

    except:
        QC_Make_year = ME_df[(ME_df.Make.str.lower() == dictionary[Make_id]) & (ME_df.Year == Year)].sort_values(by=['Make','Year','Model'])
        Rlist=['No Such year in the Database'] *len(QC_Make_year)
    else:
        QC_Make_year = ME_df[(ME_df.Make.str.lower() == dictionary[Make_id]) & (ME_df.Year == Year)].sort_values(by=['Make','Year','Model'])
        for i in range(len(QC_Make_year.Model)):
            str2Match = str(QC_Make_year.Model.values[i])
            strOptions = [z for z in Valid_df.Model_Name]
            Ratios = process.extract(str2Match,strOptions)
            Rlist.append([a + ': ' +str(dict(Ratios)[a]) for a in dict(Ratios)])
    return Rlist
def getHightestScores(Make_id,Year):
    Scores = []
    for rec in getMatch(460,'2000'):
        Scores.append(int(rec[0].split(': ')[1]))
    return Scores
len(getHightestScores(460,'2000')) == len(getMatch(460,'2000'))

# %% [markdown]
# ##  ADD feartures to test

# %%
def getQCtable_Allyear(Make_id):    
    QC_Make = pd.DataFrame()
    Years = ['2017']
    for Year in Years:
        QC_Make_Year = ME_df[(ME_df.Make.str.lower() == dictionary[Make_id]) & (ME_df.Year == Year)].sort_values(by=['Make','Year','Model'])
        QC_Make_Year['TOPexcatMatch'] = getExactMatch(Make_id,Year)
        QC_Make_Year['MatchOptions'] = getMatch(Make_id,Year)        
        QC_Make_Year['Match'] = np.where(QC_Make_Year.Model.str.lower() == QC_Make_Year.TOPexcatMatch.str.lower(), 'Yes', 'No')
        QC_Make_Year['HighestScore'] = [int(rec[0].split(': ')[1]) if type(rec) != str else 'N/A' for rec in QC_Make_Year['MatchOptions']]
        QC_Make_Year['TopMaTchExsting'] = [np.where(QC_Make_Year['TOPexcatMatch'].values[i].lower() in QC_Make_Year.Model.str.lower().unique(),'Yes','No') for i in range(len(QC_Make_Year['TOPexcatMatch']))]
        QC_Make = pd.concat([QC_Make,QC_Make_Year])
    return QC_Make
getQCtable_Allyear(448)
# Out:
#          Make         Model  Year           RyanAddRemoveDate  \
# 9862   TOYOTA          Aqua  2017  2018-05-17 16:53:40.733000
# 9974   TOYOTA          C-HR  2017  2018-05-17 16:53:40.733000
# 10001  TOYOTA       Corolla  2017  2018-05-17 16:53:40.733000
# 10055  TOYOTA    FJ Cruiser  2017  2018-05-17 16:53:40.733000
# 10080  TOYOTA    Highlander  2017  2018-05-17 16:53:40.733000
# 10109  TOYOTA  Land Cruiser  2017  2018-05-17 16:53:40.733000
# 10148  TOYOTA         MIRAI  2017  2018-05-17 16:53:40.733000
# 10229  TOYOTA       Prius C  2017  2018-05-17 16:53:40.733000
# 10358  TOYOTA       Sequoia  2017  2018-05-17 16:53:40.733000
# 9854   Toyota      4-Runner  2017         2019-11-05 00:00:00
# 9831   Toyota       4Runner  2017  2018-05-17 16:53:40.733000
# 9803   Toyota            86  2017  2018-05-17 16:53:40.733000
# 9883   Toyota        Avalon  2017  2018-05-17 16:53:40.733000
# 9919   Toyota         Camry  2017  2018-05-17 16:53:40.733000
# 9920   Toyota         Camry  2017  2019-09-25 16:03:15.593000
# 9938   Toyota  Camry Hybrid  2017  2019-09-25 16:03:15.593000
# 10126  Toyota        Legacy  2017  2019-09-25 16:03:15.593000
# 10144  Toyota        Matrix  2017  2018-05-17 16:53:40.733000
# 10219  Toyota         Prius  2017  2018-05-17 16:53:40.733000
# 10220  Toyota         Prius  2017  2019-09-25 16:03:15.593000
# 10235  Toyota   Prius Prime  2017  2019-09-25 16:03:15.593000
# 10243  Toyota       Prius V  2017  2018-05-17 16:53:40.733000
# 10269  Toyota         RAV 4  2017         2018-08-09 00:00:00
# 10329  Toyota         RAV-4  2017  2018-05-17 16:53:40.733000
# 10306  Toyota          RAV4  2017  2018-05-17 16:53:40.733000
# 10339  Toyota            RX  2017  2019-09-25 16:03:15.593000
# 10381  Toyota        Sienna  2017  2018-05-17 16:53:40.733000
# 10437  Toyota        Tacoma  2017  2018-05-17 16:53:40.733000
# 10510  Toyota        Tundra  2017  2018-05-17 16:53:40.733000
# 10583  Toyota         Venza  2017  2018-05-17 16:53:40.733000
# 10628  Toyota         Yaris  2017  2018-05-17 16:53:40.733000
#
#       RyanEligibleFlag                                         RyanSource  \
# 9862                 Y                            round 3 list per Denise
# 9974                 Y                            round 3 list per Denise
# 10001                Y                            round 3 list per Denise
# 10055                Y                            round 3 list per Denise
# 10080                Y                            round 3 list per Denise
# 10109                Y                            round 3 list per Denise
# 10148                Y                            round 3 list per Denise
# 10229                Y                            round 3 list per Denise
# 10358                Y                            round 3 list per Denise
# 9854                 Y                            round 3 list per Denise
# 9831                 Y                            round 3 list per Denise
# 9803                 Y                            round 3 list per Denise
# 9883                 Y                            round 3 list per Denise
# 9919                 Y                            round 3 list per Denise
# 9920                 Y  Round 4 Eligible Vehicle List 09-18-2019.XLSX ...
# 9938                 Y  Round 4 Eligible Vehicle List 09-18-2019.XLSX ...
# 10126                Y  Round 4 Eligible Vehicle List 09-18-2019.XLSX ...
# 10144                Y                            round 3 list per Denise
# 10219                Y                            round 3 list per Denise
# 10220                Y  Round 4 Eligible Vehicle List 09-18-2019.XLSX ...
# 10235                Y  Round 4 Eligible Vehicle List 09-18-2019.XLSX ...
# 10243                Y                            round 3 list per Denise
# 10269                Y                     correction to list per Denise3
# 10329                Y                            round 3 list per Denise
# 10306                Y                            round 3 list per Denise
# 10339                Y  Round 4 Eligible Vehicle List 09-18-2019.XLSX ...
# 10381                Y                            round 3 list per Denise
# 10437                Y                            round 3 list per Denise
# 10510                Y                            round 3 list per Denise
# 10583                Y                            round 3 list per Denise
# 10628                Y                            round 3 list per Denise
#
#       RyanDescription   TOPexcatMatch  \
# 9862          Round 3         Sequoia
# 9974          Round 3           Camry
# 10001         Round 3         Corolla
# 10055         Round 3    LAND CRUISER
# 10080         Round 3      Highlander
# 10109         Round 3    LAND CRUISER
# 10148         Round 3           Mirai
# 10229         Round 3         Prius C
# 10358         Round 3         Sequoia
# 9854          Round 3        4-Runner
# 9831          Round 3        4-Runner
# 9803          Round 3              86
# 9883          Round 3          Avalon
# 9919          Round 3           Camry
# 9920          Round 4           Camry
# 9938          Round 4           Camry
# 10126         Round 4           Camry
# 10144         Round 3  Corolla Matrix
# 10219         Round 3           PRIUS
# 10220         Round 4           PRIUS
# 10235         Round 4     Prius Prime
# 10243         Round 3         Prius V
# 10269         Round 3            RAV4
# 10329         Round 3            RAV4
# 10306         Round 3            RAV4
# 10339         Round 4            RAV4
# 10381         Round 3          Sienna
# 10437         Round 3          Tacoma
# 10510         Round 3          Tundra
# 10583         Round 3           Venza
# 10628         Round 3           Yaris
#
#                                             MatchOptions Match  HighestScore  \
# 9862   [Sequoia: 55, Avalon: 45, Corolla Matrix: 45, ...    No            55
# 9974   [Prius C: 86, Corolla: 45, LAND CRUISER: 45, 4...    No            86
# 10001  [Corolla: 100, COROLLA iM: 95, Corolla Matrix:...   Yes           100
# 10055  [LAND CRUISER: 78, 4-Runner: 56, PRIUS: 54, Ya...    No            78
# 10080  [Highlander: 100, LAND CRUISER: 55, Tundra: 45...   Yes           100
# 10109  [LAND CRUISER: 100, 4-Runner: 56, Highlander: ...   Yes           100
# 10148  [Mirai: 100, Corolla Matrix: 54, RAV4: 44, PRI...   Yes           100
# 10229  [Prius C: 100, PRIUS: 95, Prius V: 86, Prius P...   Yes           100
# 10358  [Sequoia: 100, Scion iA: 53, Paseo: 50, Sienna...   Yes           100
# 9854   [4-Runner: 100, LAND CRUISER: 56, Tundra: 43, ...   Yes           100
# 9831   [4-Runner: 93, LAND CRUISER: 51, Tundra: 46, P...    No            93
# 9803   [86: 100, SCION tC: 0, Corolla: 0, PRIUS: 0, S...   Yes           100
# 9883   [Avalon: 100, Scion iA: 41, RAV4: 40, Venza: 3...   Yes           100
# 9919   [Camry: 100, Corolla Matrix: 42, Yaris: 40, Mi...   Yes           100
# 9920   [Camry: 100, Corolla Matrix: 42, Yaris: 40, Mi...   Yes           100
# 9938   [Camry: 90, Yaris: 54, Yaris iA: 43, Corolla M...    No            90
# 10126  [LAND CRUISER: 45, Camry: 36, Venza: 36, Tacom...    No            45
# 10144  [Corolla Matrix: 90, Yaris: 55, Mirai: 55, Pri...    No            90
# 10219  [PRIUS: 100, Prius V: 95, Prius C: 95, Prius P...   Yes           100
# 10220  [PRIUS: 100, Prius V: 95, Prius C: 95, Prius P...   Yes           100
# 10235  [Prius Prime: 100, PRIUS: 90, Prius V: 86, Pri...   Yes           100
# 10243  [Prius V: 100, PRIUS: 95, Prius C: 86, Prius P...   Yes           100
# 10269  [RAV4: 89, 4-Runner: 86, Mirai: 40, COROLLA iM...    No            89
# 10329  [RAV4: 89, 4-Runner: 86, Mirai: 40, COROLLA iM...    No            89
# 10306  [RAV4: 100, Tundra: 45, Solara: 45, FCHV-adv: ...   Yes           100
# 10339  [Corolla: 45, PRIUS: 45, SCION xB: 45, LAND CR...    No            45
# 10381  [Sienna: 100, Scion iA: 57, Venza: 55, Sequoia...   Yes           100
# 10437  [Tacoma: 100, Corolla: 46, Corolla Matrix: 45,...   Yes           100
# 10510  [Tundra: 100, LAND CRUISER: 45, Highlander: 45...   Yes           100
# 10583  [Venza: 100, Sienna: 55, Avalon: 36, Tundra: 3...   Yes           100
# 10628  [Yaris: 100, Yaris iA: 90, PRIUS: 60, LAND CRU...   Yes           100
#
#       TopMaTchExsting
# 9862              Yes
# 9974              Yes
# 10001             Yes
# 10055             Yes
# 10080             Yes
# 10109             Yes
# 10148             Yes
# 10229             Yes
# 10358             Yes
# 9854              Yes
# 9831              Yes
# 9803              Yes
# 9883              Yes
# 9919              Yes
# 9920              Yes
# 9938              Yes
# 10126             Yes
# 10144              No
# 10219             Yes
# 10220             Yes
# 10235             Yes
# 10243             Yes
# 10269             Yes
# 10329             Yes
# 10306             Yes
# 10339             Yes
# 10381             Yes
# 10437             Yes
# 10510             Yes
# 10583             Yes
# 10628             Yes

# %%
fuzz.ratio("F 150", "F-150")
# Out:
# 80

# %%
str2Match = 'this is a test.'
strOptions = ['this is a test!','E-150','F-250']
Ratios = process.extractOne(str2Match,strOptions, scorer=fuzz.ratio)
Ratios
# Out:
# ('this is a test!', 100)

# %%
import Levenshtein as lev
lev.ratio('F-150','F 150')
fuzz.ratio('F-150','F 150')
# Out:
# 80

# %%
def getExactMatch(Make_id,Year):
    Rlist = []
    try:
        Valid_df = getModel_Year_MakeID(Make_id,Year)
        
    except:
        QC_Make_year = ME_df[(ME_df.Make.str.lower() == dictionary[Make_id]) & (ME_df.Year == Year)].sort_values(by=['Make','Year','Model'])
        Rlist=['No Such year in the Database'] *len(QC_Make_year)
    else:
        QC_Make_year = ME_df[(ME_df.Make.str.lower() == dictionary[Make_id]) & (ME_df.Year == Year)].sort_values(by=['Make','Year','Model'])
        for i in range(len(QC_Make_year.Model)):
            str2Match = str(QC_Make_year.Model.values[i])
            strOptions = [z for z in Valid_df.Model_Name]
            Ratios= process.extractOne(str2Match,strOptions, scorer=fuzz.ratio)
            Rlist.append((':'.join([ str(a) for a in list(Ratios)])))
    return Rlist

getExactMatch(460,'2005')

# %%
ALL_make = getMake()
ALL_make[ALL_make.Make_ID.astype(str) == '479']
# Out:
#       Make_ID            Make_Name
# 6407      479  Quest Manufacturing

# %%
ALL_make
# Out:
#       Make_ID                                          Make_Name
# 0        7756                            Bill’s Welding & Repair
# 1        6473                                         Blackwater
# 2        7827                              Car Twin Trailers Inc
# 3        7208                                             CRUZER
# 4        7145                       Custom Mobile Food Equipment
# 5        5518                    Drake Truck & Trailer Equipment
# 6        6199                                            Esterel
# 7        5527                             Gerling and Associates
# 8        7640                          Indiana Custom Cargo, Inc
# 9        5794                                       Kountry Aire
# 10       6625                           McCOY Manufacturing, LLC
# 11       5520                                    Miller RV MFG.
# 12       7912                      R & D Design and Fabrication
# 13       5765                                             SAM'S
# 14       8156                                  Trailer Tech, Inc
# 15       4877                                 1/OFF KUSTOMS, LLC
# 16       8678               1469466 Ontario Limited Cycle Hauler
# 17       6387                               17 Creek Enterprises
# 18       9172                     1M Custom Car Transports, Inc.
# 19       6124                       1ST CHOICE MANUFACTURING INC
# 20       6488                                 2-G Trailer Co LLC
# 21        612                                    2231545 Ontario
# 22        608                                       280 Trailers
# 23      10123                                 3 Custom Solutions
# 24       8792           3&1 Enterprises, LLC dba Impact Trailers
# 25       7388                            33 East Maintenance Inc
# 26      10005                                     357 Golf Carts
# 27       9857                             3C Cattle Feeders Inc.
# 28        675                                 3D Custom Aluminum
# 29       4800                         3M Dynamic Message Systems
# ...       ...                                                ...
# 9128     3972                        ZHEJIANG RIYA MOTORCYCLE CO
# 9129     9783  Zhejiang Shanqi Tianying Vehicle Industry Co.,...
# 9130     4452                 Zhejiang Summit Huawin Motorcycle
# 9131     3956                   ZHEJIANG TAIZHOU WANGYE POWER CO
# 9132     3973                        ZHEJIANG TAOTAO INDUSTRY CO
# 9133     3955                        ZHEJIANG XINGYUE VEHICLE CO
# 9134     4643  Zhejiang Yule New Energy Automobile Technology...
# 9135     4648                        Zhengzhou East Industry Co.
# 9136     2004                                           Zhongmao
# 9137     3974                              ZHONGMO TECHNOLOGY CO
# 9138     7837  Zhumadian Dali Tianjun Special Vehicle Manufac...
# 9139     3975                      ZHUZHOU NANFANG MOTORCYCLE CO
# 9140     7151                                             ZHWEKI
# 9141     3886                         ZIERKE BUILT MANUFACTURING
# 9142     8172                               Ziffel Manufacturing
# 9143     9999                                              ZIGGY
# 9144     3885                                ZIMCO MANUFACTURING
# 9145     5926                                             Zimmer
# 9146     5045                      Zimmerman Manufacturing Corp.
# 9147     3884                                 ZIMMERMAN TRAILER
# 9148     9518                                  Zion's Tiny Homes
# 9149     3395                                               ZNEN
# 9150     6057                                         Zoe Motors
# 9151     3883                                 ZONE ELECTRIC CAR
# 9152     3882                       ZONGSHEN INDUSTRIAL GROUP CO
# 9153     9848                Zongshen Industrial Group Co., LTD.
# 9154     7829                                    Zook's Welding
# 9155     3881                                     ZTPOWERSTATION
# 9156     3880                                         ZZ TRAILER
# 9157     8416                                        ZZ Trailers
#
# [9158 rows x 2 columns]
