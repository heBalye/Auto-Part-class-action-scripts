# %%
from CleanVIN import ValidationProcess, Col_to_str
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\FFR0103\Desktop\My files\WORK\Auto part\Secure Link\Source\API\VINs to validate.xlsx')
df
# Out:
#                         VIN  RowID
# 0         1FDSE37F6WHB46480      1
# 1         1HVBBAAN9TH295537      2
# 2         1GNFG154X81173240      3
# 3         1HVBBABN2WH568336      4
# 4         1GBJG31K491142168      5
# 5         1HVBBAAN44H673734      6
# 6         1GB3GRBG0G1305627      7
# 7         1BAKGCSA8JF345393      8
# 8         1GBJG31F821189664      9
# 9         4UZABRFC1JCJT6587     10
# 10        1FTNS24263HA11260     11
# 11        1BAKDCKH05F226071     12
# 12        4DRBVAAP25A986852     13
# 13        1GB6G5BL9F1278784     14
# 14        1FD2E35L18DB33252     15
# 15        2C7WDGBG4JR303729     16
# 16             SSL000273000     17
# 17        1GBHG31Y8SF226554     18
# 18        1BAKGCKA69F257650     19
# 19        4DRBUSKN0AB236232     20
# 20        4UZABRDT6CCBP2493     21
# 21        1FTWF3BR1AEA75252     22
# 22        4DRBRAAN74B968133     23
# 23        4UZABRFC5JCJT6656     24
# 24             HF0000063000     25
# 25        1FDWE35F13HB13869     26
# 26        1GDHG31Y3SF552818     27
# 27        4UZABRDU5BCAU5032     28
# 28        1HVBBABP4XH201540     29
# 29        1T75L3B2XS1139050     30
# ...                     ...    ...
# 46867     4UZABRDT08CZ63901  46869
# 46868     4DRBUAFP16A988220  46870
# 46869     1GB6GUBGXH1194747  46871
# 46870     4UZABRDT8HCHS4924  46872
# 46871               L3BNR0N  46873
# 46872     1BAAHCPA02F205065  46874
# 46873            CAC84301S7  46875
# 46874     1T88P4E22B1138568  46876
# 46875  4UZABRDT0ACAR2149ADJ  46877
# 46876     1T7YU4E27B1135713  46878
# 46877     JTDZN3EU3HJ072126  46879
# 46878     4UZABRDT5DCBZ7449  46880
# 46879     1D4GP25R57B187511  46881
# 46880     2C4RDGBG2GR139996  46882
# 46881     1GBHG31C191155175  46883
# 46882     1T88N3B27X1068772  46884
# 46883     4DRBUAAP5AB142313  46885
# 46884     4DRBUC8P2GB221657  46886
# 46885     4UZAAXAK82CJ43236  46887
# 46886     1GB6G5BL8D1172162  46888
# 46887     1BAKFCKH75F228863  46889
# 46888     1FDSE37F3WHA40620  46890
# 46889     4DRBUSKN6AB229026  46891
# 46890     4UZAAXDG06CV69693  46892
# 46891     1N9MLACL7AC084161  46893
# 46892     4UZABRDU6BCAU5007  46894
# 46893     4UZABRDU1BCAU5058  46895
# 46894  1BABHCKA75F219447ADJ  46896
# 46895     4DRBUC8N2KB685538  46897
# 46896     1GDL7T1B7YJ525553  46898
#
# [46897 rows x 2 columns]

# %%
df[df.VIN.str.contains(";")]
# Out:
# Empty DataFrame
# Columns: [VIN, RowID]
# Index: []

# %%
df_1 = df.iloc[:10000,:]
df_2 = df.iloc[10000:20000,:]
df_3 = df.iloc[20000:30000,:]
df_4 = df.iloc[30000:40000,:]
df_5 = df.iloc[40000:,:]

# %%
QC = pd.concat([df_1,df_2,df_3,df_4,df_5]) == df
QC[(QC['VIN'] == False)|(QC['RowID'] == False)]
# Out:
# Empty DataFrame
# Columns: [VIN, RowID]
# Index: []

# %% [markdown]
# ## 3rd Batch

# %%
data_3 = Col_to_str(df_3,'VIN',';')
data_3.count(';')
# Out:
# 9999

# %%
process_3 = ValidationProcess(data_3,4)
result_3 = process_3.getAll()
filename = 'result_3'
result_3.to_excel(rf'C:\Users\FFR0103\Desktop\My files\WORK\Auto part\Secure Link\Output\{filename}.xlsx')
# Out:
# Chunk3 is done!
# Chunk0 is done!
# Chunk1 is done!
# Chunk12 is done!
# Chunk2 is done!
# Chunk16 is done!
# Chunk9 is done!
# Chunk15 is done!
# Chunk17 is done!
# Chunk18 is done!
# Chunk5 is done!
# Chunk4 is done!
# Chunk10 is done!
# Chunk7 is done!
# Chunk8 is done!
# Chunk6 is done!
# Chunk14 is done!
# Chunk13 is done!
# Chunk19 is done!
# Chunk11 is done!
# Chunk27 is done!
# Chunk22 is done!
# Chunk28 is done!
# Chunk29 is done!
# Chunk23 is done!
# Chunk26 is done!
# Chunk24 is done!
# Chunk21 is done!
# Chunk30 is done!
# Chunk31 is done!
# Chunk25 is done!
# Chunk33 is done!
# Chunk20 is done!
# Chunk32 is done!
# Chunk34 is done!
# Chunk35 is done!
# Chunk36 is done!
# Chunk38 is done!
# Chunk37 is done!
# Chunk39 is done!
# Chunk41 is done!
# Chunk40 is done!
# Chunk43 is done!
# Chunk42 is done!
# Chunk45 is done!
# Chunk46 is done!
# Chunk48 is done!
# Chunk44 is done!
# Chunk53 is done!
# Chunk51 is done!
# Chunk47 is done!
# Chunk54 is done!
# Chunk49 is done!
# Chunk56 is done!
# Chunk55 is done!
# Chunk57 is done!
# Chunk50 is done!
# Chunk58 is done!
# Chunk52 is done!
# Chunk59 is done!
# Chunk64 is done!
# Chunk65 is done!
# Chunk60 is done!
# Chunk62 is done!
# Chunk66 is done!
# Chunk63 is done!
# Chunk67 is done!
# Chunk61 is done!
# Chunk70 is done!
# Chunk73 is done!
# Chunk72 is done!
# Chunk69 is done!
# Chunk71 is done!
# Chunk77 is done!
# Chunk79 is done!
# Chunk74 is done!
# Chunk68 is done!
# Chunk75 is done!
# Chunk76 is done!
# Chunk78 is done!
# Chunk80 is done!
# Chunk82 is done!
# Chunk81 is done!
# Chunk83 is done!
# Chunk85 is done!
# Chunk84 is done!
# Chunk86 is done!
# Chunk96 is done!
# Chunk87 is done!
# Chunk92 is done!
# Chunk93 is done!
# Chunk94 is done!
# Chunk88 is done!
# Chunk90 is done!
# Chunk95 is done!
# Chunk91 is done!
# Chunk101 is done!
# Chunk89 is done!
# Chunk99 is done!
# Chunk97 is done!
# Chunk100 is done!
# Chunk98 is done!
# Chunk104 is done!
# Chunk102 is done!
# Chunk111 is done!
# Chunk106 is done!
# Chunk105 is done!
# Chunk103 is done!
# Chunk118 is done!
# Chunk112 is done!
# Chunk107 is done!
# Chunk108 is done!
# Chunk109 is done!
# Chunk113 is done!
# Chunk110 is done!
# Chunk116 is done!
# Chunk114 is done!
# Chunk117 is done!
# Chunk119 is done!
# Chunk115 is done!
# Chunk120 is done!
# Chunk121 is done!
# Chunk122 is done!
# Chunk123 is done!
# Chunk127 is done!
# Chunk129 is done!
# Chunk128 is done!
# Chunk124 is done!
# Chunk126 is done!Chunk130 is done!
#
# Chunk131 is done!
# Chunk125 is done!
# Chunk132 is done!
# Chunk134 is done!
# Chunk133 is done!
# Chunk137 is done!
# Chunk135 is done!
# Chunk139 is done!
# Chunk138 is done!
# Chunk140 is done!
# Chunk136 is done!
# Chunk141 is done!
# Chunk144 is done!
# Chunk143 is done!
# Chunk142 is done!
# Chunk146 is done!
# Chunk145 is done!
# Chunk151 is done!
# Chunk147 is done!
# Chunk148 is done!
# Chunk153 is done!
# Chunk149 is done!
# Chunk150 is done!
# Chunk154 is done!
# Chunk152 is done!
# Chunk155 is done!
# Chunk157 is done!Chunk158 is done!
#
# Chunk160 is done!
# Chunk156 is done!
# Chunk161 is done!Chunk159 is done!
#
# Chunk162 is done!
# Chunk163 is done!
# Chunk164 is done!
# Chunk165 is done!
# Chunk167 is done!
# Chunk166 is done!
# Chunk169 is done!
# Chunk170 is done!
# Chunk172 is done!
# Chunk171 is done!
# Chunk168 is done!
# Chunk173 is done!
# Chunk174 is done!
# Chunk177 is done!
# Chunk175 is done!
# Chunk179 is done!
# Chunk178 is done!
# Chunk181 is done!
# Chunk180 is done!
# Chunk176 is done!
# Chunk182 is done!
# Chunk183 is done!
# Chunk185 is done!
# Chunk184 is done!
# Chunk186 is done!
# Chunk187 is done!
# Chunk192 is done!
# Chunk189 is done!
# Chunk188 is done!
# Chunk190 is done!
# Chunk191 is done!
# Chunk196 is done!
# Chunk194 is done!
# Chunk193 is done!
# Chunk198 is done!
# Chunk195 is done!
# Chunk197 is done!
# Chunk200 is done!
# Chunk199 is done!
# Chunk201 is done!
# Chunk203 is done!
# Chunk202 is done!
# Chunk205 is done!
# Chunk204 is done!
# Chunk206 is done!
# Chunk207 is done!
# Chunk208 is done!
# Chunk209 is done!
# Chunk212 is done!
# Chunk211 is done!
# Chunk210 is done!
# Chunk214 is done!
# Chunk215 is done!
# Chunk213 is done!
# Chunk217 is done!
# Chunk216 is done!
# Chunk218 is done!
# Chunk220 is done!
# Chunk219 is done!
# Chunk222 is done!
# Chunk221 is done!
# Chunk224 is done!
# Chunk225 is done!
# Chunk226 is done!
# Chunk223 is done!
# Chunk227 is done!
# Chunk229 is done!
# Chunk230 is done!
# Chunk228 is done!
# Chunk231 is done!
# Chunk232 is done!
# Chunk233 is done!
# Chunk234 is done!
# Chunk235 is done!
# Chunk237 is done!
# Chunk236 is done!
# Chunk238 is done!
# Chunk239 is done!
# Chunk241 is done!
# Chunk243 is done!
# Chunk240 is done!
# Chunk242 is done!
# Chunk245 is done!
# Chunk244 is done!
# Chunk246 is done!
# Chunk250 is done!
# Chunk248 is done!
# Chunk249 is done!
# Chunk247 is done!
# Chunk251 is done!
# Chunk254 is done!
# Chunk253 is done!
# Chunk255 is done!
# Chunk252 is done!
# Chunk256 is done!
# Chunk257 is done!
# Chunk260 is done!
# Chunk258 is done!
# Chunk259 is done!
# Chunk261 is done!
# Chunk264 is done!
# Chunk262 is done!
# Chunk263 is done!
# Chunk265 is done!
# Chunk266 is done!
# Chunk267 is done!
# Chunk268 is done!
# Chunk271 is done!
# Chunk269 is done!
# Chunk270 is done!
# Chunk272 is done!
# Chunk273 is done!
# Chunk274 is done!
# Chunk276 is done!
# Chunk275 is done!
# Chunk278 is done!
# Chunk277 is done!
# Chunk280 is done!
# Chunk282 is done!
# Chunk281 is done!
# Chunk279 is done!
# Chunk283 is done!
# Chunk284 is done!
# Chunk287 is done!
# Chunk285 is done!
# Chunk289 is done!
# Chunk286 is done!
# Chunk288 is done!
# Chunk290 is done!
# Chunk291 is done!
# Chunk292 is done!
# Chunk293 is done!
# Chunk295 is done!
# Chunk294 is done!
# Chunk296 is done!
# Chunk297 is done!
# Chunk298 is done!
# Chunk299 is done!
# Chunk301 is done!
# Chunk300 is done!
# Chunk302 is done!
# Chunk303 is done!
# Chunk309 is done!
# Chunk304 is done!
# Chunk306 is done!
# Chunk307 is done!
# Chunk305 is done!
# Chunk310 is done!
# Chunk308 is done!
# Chunk311 is done!
# Chunk313 is done!
# Chunk312 is done!
# Chunk314 is done!
# Chunk315 is done!
# Chunk317 is done!
# Chunk316 is done!
# Chunk318 is done!
# Chunk321 is done!
# Chunk319 is done!
# Chunk320 is done!
# Chunk322 is done!
# Chunk325 is done!
# Chunk326 is done!
# Chunk323 is done!
# Chunk324 is done!
# Chunk330 is done!
# Chunk327 is done!
# Chunk328 is done!
# Chunk329 is done!
# Chunk331 is done!
# Chunk333 is done!
# Chunk332 is done!
# Chunk334 is done!
# Chunk335 is done!
# Chunk336 is done!
# Chunk337 is done!
# Chunk338 is done!
# Chunk339 is done!
# Chunk340 is done!
# Chunk341 is done!
# Chunk342 is done!
# Chunk347 is done!
# Chunk343 is done!
# Chunk344 is done!
# Chunk346 is done!
# Chunk345 is done!
# Chunk350 is done!
# Chunk349 is done!
# Chunk348 is done!
# Chunk351 is done!
# Chunk352 is done!
# Chunk353 is done!
# Chunk354 is done!
# Chunk355 is done!
# Chunk359 is done!
# Chunk356 is done!
# Chunk360 is done!
# Chunk358 is done!
# Chunk357 is done!
# Chunk361 is done!
# Chunk362 is done!
# Chunk365 is done!
# Chunk364 is done!
# Chunk363 is done!
# Chunk367 is done!
# Chunk368 is done!
# Chunk366 is done!
# Chunk371 is done!
# Chunk370 is done!
# Chunk369 is done!
# Chunk372 is done!
# Chunk373 is done!
# Chunk374 is done!
# Chunk377 is done!Chunk378 is done!
#
# Chunk375 is done!
# Chunk376 is done!
# Chunk379 is done!
# Chunk380 is done!
# Chunk381 is done!
# Chunk382 is done!
# Chunk383 is done!
# Chunk387 is done!
# Chunk384 is done!
# Chunk385 is done!
# Chunk386 is done!
# Chunk388 is done!
# Chunk391 is done!
# Chunk390 is done!
# Chunk389 is done!
# Chunk393 is done!
# Chunk392 is done!
# Chunk394 is done!
# Chunk398 is done!
# Chunk397 is done!
# Chunk395 is done!
# Chunk396 is done!
# Chunk400 is done!
# Chunk399 is done!
# Chunk401 is done!
# Chunk403 is done!
# Chunk402 is done!
# Chunk404 is done!
# Chunk405 is done!
# Chunk407 is done!
# Chunk406 is done!
# Chunk408 is done!
# Chunk410 is done!
# Chunk411 is done!
# Chunk412 is done!
# Chunk409 is done!
# Chunk413 is done!
# Chunk414 is done!
# Chunk415 is done!
# Chunk417 is done!
# Chunk416 is done!
# Chunk420 is done!
# Chunk418 is done!
# Chunk419 is done!
# Chunk421 is done!
# Chunk424 is done!
# Chunk422 is done!
# Chunk427 is done!
# Chunk423 is done!
# Chunk426 is done!
# Chunk425 is done!
# Chunk428 is done!
# Chunk429 is done!
# Chunk431 is done!
# Chunk430 is done!
# Chunk432 is done!
# Chunk433 is done!
# Chunk434 is done!
# Chunk435 is done!
# Chunk436 is done!
# Chunk438 is done!
# Chunk439 is done!
# Chunk440 is done!
# Chunk437 is done!
# Chunk441 is done!
# Chunk442 is done!
# Chunk444 is done!
# Chunk445 is done!
# Chunk443 is done!
# Chunk449 is done!
# Chunk447 is done!
# Chunk446 is done!
# Chunk448 is done!
# Chunk452 is done!
# Chunk450 is done!
# Chunk451 is done!
# Chunk453 is done!
# Chunk455 is done!
# Chunk454 is done!
# Chunk456 is done!
# Chunk457 is done!
# Chunk458 is done!
# Chunk460 is done!
# Chunk459 is done!
# Chunk461 is done!
# Chunk463 is done!
# Chunk464 is done!
# Chunk462 is done!
# Chunk465 is done!
# Chunk469 is done!
# Chunk466 is done!
# Chunk470 is done!
# Chunk468 is done!
# Chunk467 is done!
# Chunk472 is done!
# Chunk471 is done!
# Chunk473 is done!
# Chunk478 is done!
# Chunk477 is done!
# Chunk480 is done!
# Chunk474 is done!
# Chunk479 is done!
# Chunk475 is done!
# Chunk476 is done!
# Chunk483 is done!
# Chunk482 is done!
# Chunk481 is done!
# Chunk485 is done!
# Chunk486 is done!
# Chunk484 is done!
# Chunk487 is done!
# Chunk490 is done!
# Chunk489 is done!
# Chunk488 is done!
# Chunk492 is done!
# Chunk491 is done!
# Chunk493 is done!
# Chunk496 is done!
# Chunk494 is done!
# Chunk497 is done!
# Chunk495 is done!
# Chunk498 is done!
# Chunk499 is done!
# Chunk500 is done!
# Chunk503 is done!
# Chunk506 is done!
# Chunk502 is done!
# Chunk504 is done!
# Chunk505 is done!
# Chunk501 is done!
# Chunk507 is done!
# Chunk508 is done!
# Chunk509 is done!
# Chunk510 is done!
# Chunk511 is done!
# Chunk512 is done!
# Chunk515 is done!
# Chunk513 is done!
# Chunk514 is done!
# Chunk516 is done!
# Chunk517 is done!
# Chunk519 is done!
# Chunk518 is done!
# Chunk521 is done!
# Chunk520 is done!
# Chunk523 is done!
# Chunk522 is done!
# Chunk524 is done!
# Chunk526 is done!
# Chunk525 is done!
# Chunk527 is done!
# Chunk529 is done!
# Chunk528 is done!
# Chunk530 is done!
# Chunk531 is done!
# Chunk532 is done!
# Chunk533 is done!
# Chunk534 is done!
# Chunk535 is done!
# Chunk536 is done!
# Chunk538 is done!
# Chunk537 is done!
# Chunk539 is done!
# Chunk540 is done!
# Chunk541 is done!
# Chunk542 is done!
# Chunk544 is done!
# Chunk547 is done!
# Chunk546 is done!
# Chunk545 is done!
# Chunk543 is done!
# Chunk548 is done!
# Chunk549 is done!
# Chunk551 is done!
# Chunk552 is done!
# Chunk550 is done!
# Chunk553 is done!
# Chunk554 is done!
# Chunk555 is done!
# Chunk556 is done!
# Chunk557 is done!
# Chunk558 is done!
# Chunk559 is done!
# Chunk560 is done!
# Chunk561 is done!
# Chunk565 is done!
# Chunk563 is done!
# Chunk562 is done!
# Chunk564 is done!
# Chunk566 is done!
# Chunk568 is done!
# Chunk569 is done!
# Chunk567 is done!
# Chunk572 is done!
# Chunk570 is done!
# Chunk571 is done!
# Chunk575 is done!
# Chunk573 is done!
# Chunk574 is done!
# Chunk576 is done!
# Chunk578 is done!
# Chunk577 is done!
# Chunk581 is done!
# Chunk579 is done!
# Chunk583 is done!
# Chunk580 is done!
# Chunk582 is done!
# Chunk584 is done!
# Chunk586 is done!
# Chunk585 is done!
# Chunk587 is done!
# Chunk588 is done!
# Chunk589 is done!
# Chunk590 is done!
# Chunk592 is done!
# Chunk591 is done!
# Chunk594 is done!
# Chunk595 is done!
# Chunk596 is done!
# Chunk593 is done!
# Chunk598 is done!
# Chunk597 is done!
# Chunk599 is done!
# Chunk601 is done!
# Chunk600 is done!
# Chunk602 is done!
# Chunk603 is done!
# Chunk604 is done!
# Chunk606 is done!
# Chunk605 is done!
# Chunk607 is done!
# Chunk608 is done!
# Chunk609 is done!
# Chunk610 is done!
# Chunk612 is done!
# Chunk611 is done!
# Chunk613 is done!
# Chunk614 is done!
# Chunk618 is done!
# Chunk619 is done!
# Chunk617 is done!
# Chunk615 is done!
# Chunk622 is done!
# Chunk620 is done!
# Chunk621 is done!
# Chunk623 is done!
# Chunk625 is done!
# Chunk626 is done!
# Chunk624 is done!
# Chunk627 is done!
# Chunk628 is done!
# Chunk629 is done!
# Chunk630 is done!
# Chunk631 is done!
# Chunk633 is done!
# Chunk632 is done!
# Chunk635 is done!
# Chunk636 is done!Chunk634 is done!
#
# Chunk639 is done!
# Chunk637 is done!
# Chunk638 is done!
# Chunk641 is done!
# Chunk640 is done!
# Chunk643 is done!
# Chunk642 is done!
# Chunk644 is done!
# Chunk645 is done!
# Chunk646 is done!
# Chunk647 is done!
# Chunk648 is done!
# Chunk651 is done!
# Chunk649 is done!
# Chunk650 is done!
# Chunk652 is done!
# Chunk653 is done!
# Chunk654 is done!
# Chunk656 is done!
# Chunk655 is done!
# Chunk657 is done!
# Chunk659 is done!
# Chunk658 is done!
# Chunk660 is done!
# Chunk661 is done!
# Chunk662 is done!
# Chunk663 is done!
# Chunk664 is done!
# Chunk667 is done!
# Chunk665 is done!
# Chunk668 is done!
# Chunk666 is done!
# Chunk671 is done!
# Chunk670 is done!
# Chunk669 is done!
# Chunk672 is done!
# Chunk674 is done!
# Chunk673 is done!
# Chunk675 is done!
# Chunk677 is done!
# Chunk676 is done!
# Chunk678 is done!
# Chunk679 is done!
# Chunk680 is done!
# Chunk683 is done!
# Chunk681 is done!
# Chunk682 is done!
# Chunk684 is done!
# Chunk688 is done!
# Chunk685 is done!
# Chunk686 is done!
# Chunk687 is done!
# Chunk689 is done!
# Chunk690 is done!
# Chunk691 is done!
# Chunk692 is done!
# Chunk693 is done!
# Chunk694 is done!
# Chunk696 is done!
# Chunk695 is done!
# Chunk697 is done!
# Chunk699 is done!
# Chunk698 is done!
# Chunk700 is done!
# Chunk701 is done!
# Chunk702 is done!
# Chunk703 is done!
# Chunk704 is done!
# Chunk705 is done!
# Chunk706 is done!
# Chunk707 is done!
# Chunk708 is done!
# Chunk709 is done!
# Chunk711 is done!
# Chunk710 is done!
# Chunk713 is done!
# Chunk712 is done!
# Chunk714 is done!
# Chunk716 is done!
# Chunk717 is done!
# Chunk715 is done!
# Chunk718 is done!
# Chunk719 is done!
# Chunk723 is done!
# Chunk720 is done!
# Chunk722 is done!
# Chunk721 is done!
# Chunk724 is done!
# Chunk725 is done!
# Chunk727 is done!
# Chunk726 is done!
# Chunk728 is done!
# Chunk729 is done!
# Chunk730 is done!
# Chunk731 is done!
# Chunk732 is done!
# Chunk733 is done!
# Chunk734 is done!
# Chunk736 is done!
# Chunk737 is done!
# Chunk735 is done!
# Chunk738 is done!
# Chunk739 is done!
# Chunk741 is done!
# Chunk740 is done!
# Chunk742 is done!
# Chunk743 is done!
# Chunk744 is done!
# Chunk745 is done!
# Chunk746 is done!
# Chunk749 is done!
# Chunk747 is done!
# Chunk748 is done!
# Chunk751 is done!
# Chunk750 is done!
# Chunk752 is done!
# Chunk753 is done!
# Chunk756 is done!
# Chunk754 is done!
# Chunk755 is done!
# Chunk757 is done!
# Chunk759 is done!
# Chunk758 is done!
# Chunk761 is done!
# Chunk760 is done!
# Chunk763 is done!
# Chunk762 is done!
# Chunk764 is done!
# Chunk765 is done!
# Chunk767 is done!
# Chunk766 is done!
# Chunk768 is done!
# Chunk769 is done!
# Chunk770 is done!
# Chunk772 is done!
# Chunk771 is done!
# Chunk775 is done!
# Chunk773 is done!
# Chunk774 is done!
# Chunk776 is done!
# Chunk777 is done!
# Chunk778 is done!
# Chunk779 is done!
# Chunk781 is done!
# Chunk780 is done!
# Chunk782 is done!
# Chunk783 is done!
# Chunk784 is done!
# Chunk785 is done!
# Chunk787 is done!
# Chunk786 is done!
# Chunk789 is done!
# Chunk788 is done!
# Chunk790 is done!
# Chunk791 is done!
# Chunk792 is done!
# Chunk793 is done!
# Chunk794 is done!
# Chunk795 is done!
# Chunk796 is done!
# Chunk797 is done!
# Chunk798 is done!
# Chunk799 is done!
# Chunk800 is done!
# Chunk801 is done!
# Chunk802 is done!
# Chunk803 is done!
# Chunk804 is done!
# Chunk805 is done!
# Chunk806 is done!
# Chunk807 is done!
# Chunk808 is done!
# Chunk809 is done!
# Chunk811 is done!
# Chunk815 is done!
# Chunk810 is done!
# Chunk813 is done!
# Chunk812 is done!
# Chunk814 is done!
# Chunk816 is done!
# Chunk817 is done!
# Chunk818 is done!
# Chunk819 is done!
# Chunk820 is done!
# Chunk822 is done!
# Chunk821 is done!
# Chunk823 is done!
# Chunk824 is done!
# Chunk825 is done!
# Chunk826 is done!
# Chunk827 is done!
# Chunk829 is done!
# Chunk828 is done!
# Chunk831 is done!
# Chunk830 is done!
# Chunk832 is done!
# Chunk834 is done!
# Chunk833 is done!
# Chunk835 is done!
# Chunk837 is done!
# Chunk836 is done!
# Chunk838 is done!
# Chunk839 is done!
# Chunk840 is done!
# Chunk842 is done!
# Chunk841 is done!
# Chunk845 is done!
# Chunk844 is done!
# Chunk843 is done!
# Chunk846 is done!
# Chunk848 is done!
# Chunk847 is done!
# Chunk849 is done!
# Chunk850 is done!
# Chunk851 is done!
# Chunk855 is done!
# Chunk853 is done!
# Chunk852 is done!
# Chunk854 is done!
# Chunk857 is done!
# Chunk856 is done!
# Chunk858 is done!
# Chunk859 is done!
# Chunk860 is done!
# Chunk861 is done!
# Chunk862 is done!
# Chunk863 is done!
# Chunk866 is done!
# Chunk864 is done!
# Chunk865 is done!
# Chunk867 is done!
# Chunk868 is done!
# Chunk869 is done!
# Chunk870 is done!
# Chunk873 is done!
# Chunk871 is done!
# Chunk872 is done!
# Chunk875 is done!
# Chunk877 is done!
# Chunk876 is done!
# Chunk874 is done!
# Chunk878 is done!
# Chunk880 is done!
# Chunk879 is done!
# Chunk881 is done!
# Chunk882 is done!
# Chunk884 is done!
# Chunk883 is done!
# Chunk886 is done!
# Chunk885 is done!
# Chunk888 is done!
# Chunk887 is done!
# Chunk889 is done!
# Chunk890 is done!
# Chunk891 is done!
# Chunk893 is done!
# Chunk892 is done!
# Chunk894 is done!
# Chunk895 is done!
# Chunk897 is done!
# Chunk896 is done!
# Chunk898 is done!
# Chunk899 is done!
# Chunk900 is done!
# Chunk901 is done!
# Chunk909 is done!
# Chunk910 is done!
# Chunk908 is done!
# Chunk915 is done!
# Chunk907 is done!
# Chunk912 is done!
# Chunk913 is done!
# Chunk911 is done!
# Chunk914 is done!
# Chunk916 is done!
# Chunk921 is done!
# Chunk917 is done!Chunk920 is done!
#
# Chunk918 is done!
# Chunk919 is done!
# Chunk922 is done!
# Chunk923 is done!
# Chunk925 is done!
# Chunk924 is done!
# Chunk926 is done!
# Chunk927 is done!
# Chunk934 is done!
# Chunk928 is done!
# Chunk930 is done!
# Chunk929 is done!
# Chunk932 is done!
# Chunk931 is done!
# Chunk935 is done!
# Chunk933 is done!
# Chunk938 is done!
# Chunk936 is done!
# Chunk937 is done!
# Chunk939 is done!
# Chunk941 is done!
# Chunk943 is done!
# Chunk940 is done!
# Chunk942 is done!
# Chunk944 is done!
# Chunk945 is done!
# Chunk946 is done!
# Chunk947 is done!
# Chunk950 is done!
# Chunk952 is done!
# Chunk949 is done!
# Chunk948 is done!
# Chunk951 is done!
# Chunk953 is done!
# Chunk954 is done!
# Chunk955 is done!Chunk956 is done!
#
# Chunk957 is done!
# Chunk958 is done!
# Chunk959 is done!
# Chunk962 is done!
# Chunk961 is done!
# Chunk960 is done!
# Chunk963 is done!
# Chunk964 is done!
# Chunk965 is done!
# Chunk966 is done!
# Chunk969 is done!
# Chunk968 is done!
# Chunk973 is done!
# Chunk967 is done!
# Chunk970 is done!
# Chunk971 is done!
# Chunk972 is done!
# Chunk974 is done!
# Chunk976 is done!
# Chunk975 is done!
# Chunk979 is done!
# Chunk977 is done!
# Chunk978 is done!
# Chunk980 is done!
# Chunk981 is done!
# Chunk983 is done!
# Chunk982 is done!
# Chunk985 is done!
# Chunk984 is done!
# Chunk986 is done!
# Chunk987 is done!
# Chunk990 is done!
# Chunk988 is done!
# Chunk989 is done!
# Chunk991 is done!
# Chunk992 is done!
# Chunk994 is done!
# Chunk993 is done!
# Chunk996 is done!
# Chunk997 is done!
# Chunk995 is done!
# Chunk999 is done!
# Chunk998 is done!
# Chunk1002 is done!
# Chunk1000 is done!
# Chunk1001 is done!
# Chunk1003 is done!
# Chunk1004 is done!
# Chunk1005 is done!
# Chunk1006 is done!
# Chunk1007 is done!
# Chunk1008 is done!
# Chunk1009 is done!
# Chunk1010 is done!
# Chunk1011 is done!
# Chunk1012 is done!
# Chunk1013 is done!
# Chunk1015 is done!
# Chunk1016 is done!
# Chunk1014 is done!
# Chunk1018 is done!
# Chunk1017 is done!Chunk1019 is done!
#
# Chunk1020 is done!
# Chunk1021 is done!
# Chunk1022 is done!
# Chunk1023 is done!
# Chunk1024 is done!
# Chunk1025 is done!
# Chunk1026 is done!
# Chunk1027 is done!
# Chunk1028 is done!
# Chunk1030 is done!
# Chunk1029 is done!
# Chunk1031 is done!
# Chunk1032 is done!
# Chunk1034 is done!
# Chunk1035 is done!
# Chunk1033 is done!
# Chunk1036 is done!
# Chunk1037 is done!
# Chunk1038 is done!
# Chunk1039 is done!
# Chunk1040 is done!
# Chunk1041 is done!
# Chunk1042 is done!
# Chunk1044 is done!
# Chunk1043 is done!
# Chunk1045 is done!
# Chunk1046 is done!
# Chunk1047 is done!
# Chunk1048 is done!
# Chunk1050 is done!
# Chunk1051 is done!
# Chunk1049 is done!
# Chunk1052 is done!
# Chunk1053 is done!
# Chunk1055 is done!
# Chunk1054 is done!
# Chunk1058 is done!
# Chunk1057 is done!
# Chunk1056 is done!
# Chunk1059 is done!
# Chunk1060 is done!
# Chunk1061 is done!
# Chunk1062 is done!
# Chunk1063 is done!
# Chunk1065 is done!
# Chunk1064 is done!
# Chunk1066 is done!
# Chunk1067 is done!
# Chunk1068 is done!
# Chunk1069 is done!
# Chunk1071 is done!
# Chunk1070 is done!
# Chunk1073 is done!
# Chunk1072 is done!
# Chunk1075 is done!
# Chunk1076 is done!
# Chunk1074 is done!
# Chunk1078 is done!
# Chunk1077 is done!
# Chunk1079 is done!
# Chunk1080 is done!
# Chunk1082 is done!
# Chunk1081 is done!
# Chunk1083 is done!
# Chunk1085 is done!
# Chunk1084 is done!
# Chunk1086 is done!
# Chunk1087 is done!
# Chunk1088 is done!
# Chunk1090 is done!
# Chunk1089 is done!
# Chunk1091 is done!
# Chunk1092 is done!
# Chunk1094 is done!
# Chunk1096 is done!
# Chunk1093 is done!
# Chunk1098 is done!
# Chunk1095 is done!
# Chunk1100 is done!
# Chunk1097 is done!
# Chunk1099 is done!
# Chunk1101 is done!
# Chunk1102 is done!
# Chunk1104 is done!
# Chunk1103 is done!
# Chunk1106 is done!
# Chunk1105 is done!
# Chunk1107 is done!
# Chunk1108 is done!
# Chunk1111 is done!
# Chunk1109 is done!
# Chunk1110 is done!
# Chunk1114 is done!
# Chunk1113 is done!
# Chunk1112 is done!
# Chunk1115 is done!
# Chunk1116 is done!
# Chunk1119 is done!
# Chunk1118 is done!
# Chunk1117 is done!
# Chunk1121 is done!
# Chunk1120 is done!
# Chunk1122 is done!
# Chunk1124 is done!
# Chunk1123 is done!
# Chunk1125 is done!
# Chunk1126 is done!
# Chunk1127 is done!
# Chunk1129 is done!
# Chunk1131 is done!
# Chunk1128 is done!
# Chunk1130 is done!
# Chunk1133 is done!
# Chunk1132 is done!
# Chunk1135 is done!
# Chunk1134 is done!
# Chunk1136 is done!
# Chunk1138 is done!
# Chunk1141 is done!
# Chunk1137 is done!
# Chunk1140 is done!
# Chunk1142 is done!
# Chunk1139 is done!
# Chunk1143 is done!
# Chunk1144 is done!
# Chunk1145 is done!
# Chunk1146 is done!
# Chunk1147 is done!
# Chunk1150 is done!
# Chunk1149 is done!
# Chunk1148 is done!
# Chunk1151 is done!
# Chunk1152 is done!
# Chunk1153 is done!
# Chunk1156 is done!
# Chunk1154 is done!
# Chunk1155 is done!
# Chunk1158 is done!
# Chunk1159 is done!
# Chunk1157 is done!
# Chunk1160 is done!
# Chunk1161 is done!
# Chunk1162 is done!
# Chunk1163 is done!
# Chunk1164 is done!
# Chunk1165 is done!
# Chunk1167 is done!
# Chunk1166 is done!
# Chunk1168 is done!
# Chunk1170 is done!
# Chunk1169 is done!
# Chunk1171 is done!
# Chunk1173 is done!
# Chunk1172 is done!
# Chunk1174 is done!
# Chunk1175 is done!
# Chunk1176 is done!
# Chunk1177 is done!
# Chunk1179 is done!
# Chunk1178 is done!
# Chunk1180 is done!
# Chunk1181 is done!
# Chunk1182 is done!
# Chunk1183 is done!
# Chunk1184 is done!
# Chunk1185 is done!
# Chunk1186 is done!
# Chunk1187 is done!
# Chunk1188 is done!
# Chunk1190 is done!
# Chunk1189 is done!
# Chunk1191 is done!
# Chunk1192 is done!
# Chunk1194 is done!
# Chunk1195 is done!
# Chunk1193 is done!
# Chunk1197 is done!
# Chunk1196 is done!
# Chunk1198 is done!
# Chunk1199 is done!
# Chunk1201 is done!
# Chunk1200 is done!
# Chunk1202 is done!
# Chunk1203 is done!
# Chunk1205 is done!
# Chunk1204 is done!
# Chunk1206 is done!
# Chunk1207 is done!
# Chunk1208 is done!
# Chunk1212 is done!
# Chunk1209 is done!
# Chunk1210 is done!
# Chunk1211 is done!
# Chunk1213 is done!
# Chunk1214 is done!
# Chunk1215 is done!
# Chunk1216 is done!
# Chunk1218 is done!
# Chunk1217 is done!
# Chunk1219 is done!
# Chunk1220 is done!
# Chunk1225 is done!
# Chunk1221 is done!
# Chunk1224 is done!
# Chunk1222 is done!
# Chunk1223 is done!
# Chunk1226 is done!
# Chunk1227 is done!
# Chunk1228 is done!
# Chunk1229 is done!
# Chunk1230 is done!
# Chunk1231 is done!
# Chunk1233 is done!
# Chunk1232 is done!
# Chunk1234 is done!
# Chunk1235 is done!
# Chunk1236 is done!
# Chunk1238 is done!
# Chunk1237 is done!
# Chunk1239 is done!
# Chunk1240 is done!
# Chunk1243 is done!
# Chunk1242 is done!
# Chunk1244 is done!
# Chunk1241 is done!
# Chunk1245 is done!
# Chunk1246 is done!
# Chunk1247 is done!
# Chunk1248 is done!
# Chunk1250 is done!
# Chunk1251 is done!
# Chunk1249 is done!
# Chunk1253 is done!
# Chunk1252 is done!
# Chunk1254 is done!
# Chunk1255 is done!
# Chunk1256 is done!
# Chunk1259 is done!
# Chunk1257 is done!
# Chunk1258 is done!
# Chunk1260 is done!
# Chunk1262 is done!
# Chunk1261 is done!
# Chunk1264 is done!
# Chunk1266 is done!
# Chunk1265 is done!
# Chunk1263 is done!
# Chunk1267 is done!
# Chunk1268 is done!
# Chunk1269 is done!
# Chunk1271 is done!
# Chunk1270 is done!
# Chunk1273 is done!
# Chunk1272 is done!
# Chunk1274 is done!
# Chunk1275 is done!
# Chunk1279 is done!
# Chunk1276 is done!
# Chunk1278 is done!
# Chunk1277 is done!
# Chunk1280 is done!
# Chunk1283 is done!
# Chunk1281 is done!
# Chunk1282 is done!
# Chunk1284 is done!
# Chunk1286 is done!
# Chunk1285 is done!
# Chunk1289 is done!
# Chunk1287 is done!
# Chunk1288 is done!
# Chunk1290 is done!
# Chunk1291 is done!
# Chunk1292 is done!
# Chunk1293 is done!
# Chunk1294 is done!
# Chunk1295 is done!
# Chunk1296 is done!
# Chunk1297 is done!
# Chunk1298 is done!
# Chunk1299 is done!
# Chunk1300 is done!
# Chunk1301 is done!
# Chunk1302 is done!
# Chunk1303 is done!
# Chunk1305 is done!
# Chunk1304 is done!
# Chunk1306 is done!
# Chunk1307 is done!
# Chunk1309 is done!
# Chunk1308 is done!
# Chunk1311 is done!
# Chunk1310 is done!
# Chunk1312 is done!
# Chunk1313 is done!
# Chunk1314 is done!
# Chunk1316 is done!
# Chunk1315 is done!
# Chunk1317 is done!
# Chunk1318 is done!
# Chunk1320 is done!
# Chunk1319 is done!
# Chunk1321 is done!
# Chunk1322 is done!
# Chunk1323 is done!
# Chunk1324 is done!
# Chunk1325 is done!
# Chunk1326 is done!
# Chunk1327 is done!
# Chunk1328 is done!
# Chunk1329 is done!
# Chunk1332 is done!
# Chunk1331 is done!
# Chunk1330 is done!
# Chunk1333 is done!
# Chunk1334 is done!
# Chunk1335 is done!
# Chunk1336 is done!
# Chunk1338 is done!
# Chunk1337 is done!
# Chunk1339 is done!
# Chunk1340 is done!
# Chunk1341 is done!
# Chunk1342 is done!
# Chunk1343 is done!
# Chunk1344 is done!
# Chunk1345 is done!
# Chunk1347 is done!
# Chunk1346 is done!
# Chunk1348 is done!
# Chunk1349 is done!
# Chunk1350 is done!
# Chunk1351 is done!
# Chunk1352 is done!
# Chunk1353 is done!
# Chunk1354 is done!
# Chunk1355 is done!
# Chunk1356 is done!
# Chunk1357 is done!
# Chunk1358 is done!
# Chunk1359 is done!
# Chunk1360 is done!
# Chunk1362 is done!
# Chunk1361 is done!
# Chunk1364 is done!
# Chunk1365 is done!
# Chunk1363 is done!
# Chunk1366 is done!
# Chunk1367 is done!
# Chunk1369 is done!
# Chunk1368 is done!
# Chunk1370 is done!
# Chunk1371 is done!
# Chunk1372 is done!
# Chunk1373 is done!
# Chunk1374 is done!
# Chunk1377 is done!
# Chunk1375 is done!
# Chunk1376 is done!
# Chunk1378 is done!
# Chunk1379 is done!
# Chunk1380 is done!
# Chunk1381 is done!
# Chunk1382 is done!
# Chunk1383 is done!
# Chunk1384 is done!
# Chunk1385 is done!
# Chunk1386 is done!
# Chunk1387 is done!
# Chunk1388 is done!
# Chunk1389 is done!
# Chunk1390 is done!
# Chunk1391 is done!
# Chunk1392 is done!
# Chunk1393 is done!
# Chunk1394 is done!
# Chunk1395 is done!
# Chunk1396 is done!
# Chunk1397 is done!
# Chunk1400 is done!
# Chunk1398 is done!
# Chunk1399 is done!
# Chunk1401 is done!
# Chunk1404 is done!
# Chunk1402 is done!
# Chunk1403 is done!
# Chunk1405 is done!
# Chunk1407 is done!
# Chunk1406 is done!
# Chunk1409 is done!
# Chunk1408 is done!
# Chunk1411 is done!
# Chunk1410 is done!
# Chunk1412 is done!
# Chunk1413 is done!
# Chunk1414 is done!
# Chunk1415 is done!
# Chunk1417 is done!
# Chunk1419 is done!
# Chunk1416 is done!
# Chunk1418 is done!
# Chunk1420 is done!
# Chunk1423 is done!
# Chunk1422 is done!
# Chunk1421 is done!
# Chunk1424 is done!
# Chunk1425 is done!
# Chunk1426 is done!
# Chunk1427 is done!
# Chunk1428 is done!
# Chunk1429 is done!
# Chunk1430 is done!
# Chunk1431 is done!
# Chunk1433 is done!
# Chunk1432 is done!
# Chunk1434 is done!
# Chunk1435 is done!
# Chunk1438 is done!
# Chunk1436 is done!
# Chunk1437 is done!
# Chunk1439 is done!
# Chunk1440 is done!
# Chunk1442 is done!
# Chunk1441 is done!
# Chunk1443 is done!
# Chunk1444 is done!
# Chunk1445 is done!
# Chunk1446 is done!
# Chunk1447 is done!
# Chunk1448 is done!
# Chunk1449 is done!
# Chunk1451 is done!
# Chunk1450 is done!
# Chunk1452 is done!
# Chunk1454 is done!
# Chunk1453 is done!
# Chunk1455 is done!
# Chunk1456 is done!
# Chunk1458 is done!
# Chunk1457 is done!
# Chunk1460 is done!
# Chunk1459 is done!
# Chunk1461 is done!
# Chunk1462 is done!
# Chunk1463 is done!
# Chunk1465 is done!
# Chunk1464 is done!
# Chunk1466 is done!
# Chunk1467 is done!
# Chunk1468 is done!
# Chunk1469 is done!
# Chunk1472 is done!
# Chunk1471 is done!
# Chunk1473 is done!
# Chunk1474 is done!
# Chunk1470 is done!
# Chunk1475 is done!
# Chunk1476 is done!
# Chunk1477 is done!
# Chunk1478 is done!
# Chunk1480 is done!
# Chunk1479 is done!
# Chunk1481 is done!
# Chunk1482 is done!
# Chunk1483 is done!
# Chunk1486 is done!
# Chunk1485 is done!
# Chunk1484 is done!
# Chunk1487 is done!
# Chunk1488 is done!
# Chunk1489 is done!
# Chunk1491 is done!
# Chunk1490 is done!
# Chunk1493 is done!
# Chunk1492 is done!
# Chunk1494 is done!
# Chunk1495 is done!
# Chunk1496 is done!
# Chunk1497 is done!
# Chunk1500 is done!
# Chunk1498 is done!
# Chunk1499 is done!
# Chunk1501 is done!
# Chunk1503 is done!
# Chunk1502 is done!
# Chunk1504 is done!
# Chunk1505 is done!
# Chunk1506 is done!
# Chunk1508 is done!
# Chunk1509 is done!
# Chunk1507 is done!
# Chunk1510 is done!
# Chunk1511 is done!
# Chunk1512 is done!
# Chunk1514 is done!
# Chunk1513 is done!
# Chunk1515 is done!
# Chunk1516 is done!
# Chunk1518 is done!
# Chunk1519 is done!
# Chunk1517 is done!
# Chunk1520 is done!
# Chunk1521 is done!
# Chunk1522 is done!
# Chunk1524 is done!
# Chunk1523 is done!
# Chunk1526 is done!
# Chunk1527 is done!
# Chunk1525 is done!
# Chunk1528 is done!
# Chunk1529 is done!
# Chunk1530 is done!
# Chunk1532 is done!
# Chunk1531 is done!
# Chunk1533 is done!
# Chunk1534 is done!
# Chunk1535 is done!
# Chunk1536 is done!
# Chunk1538 is done!
# Chunk1537 is done!
# Chunk1540 is done!
# Chunk1539 is done!
# Chunk1541 is done!
# Chunk1542 is done!
# Chunk1543 is done!
# Chunk1544 is done!
# Chunk1545 is done!
# Chunk1549 is done!
# Chunk1547 is done!Chunk1546 is done!
#
# Chunk1548 is done!
# Chunk1551 is done!
# Chunk1550 is done!
# Chunk1552 is done!
# Chunk1554 is done!
# Chunk1553 is done!
# Chunk1555 is done!
# Chunk1559 is done!
# Chunk1556 is done!
# Chunk1557 is done!
# Chunk1558 is done!
# Chunk1560 is done!
# Chunk1561 is done!
# Chunk1562 is done!
# Chunk1563 is done!
# Chunk1564 is done!
# Chunk1565 is done!
# Chunk1566 is done!
# Chunk1567 is done!
# Chunk1568 is done!
# Chunk1571 is done!
# Chunk1570 is done!
# Chunk1572 is done!
# Chunk1569 is done!
# Chunk1573 is done!
# Chunk1574 is done!
# Chunk1575 is done!
# Chunk1577 is done!
# Chunk1576 is done!
# Chunk1579 is done!
# Chunk1578 is done!
# Chunk1580 is done!
# Chunk1581 is done!
# Chunk1583 is done!
# Chunk1582 is done!
# Chunk1584 is done!
# Chunk1585 is done!
# Chunk1586 is done!
# Chunk1588 is done!
# Chunk1587 is done!
# Chunk1589 is done!
# Chunk1590 is done!
# Chunk1592 is done!
# Chunk1593 is done!
# Chunk1591 is done!
# Chunk1594 is done!
# Chunk1595 is done!
# Chunk1597 is done!
# Chunk1596 is done!
# Chunk1598 is done!
# Chunk1600 is done!
# Chunk1599 is done!
# Chunk1601 is done!
# Chunk1602 is done!
# Chunk1603 is done!
# Chunk1604 is done!
# Chunk1605 is done!
# Chunk1606 is done!
# Chunk1609 is done!
# Chunk1607 is done!
# Chunk1608 is done!
# Chunk1610 is done!
# Chunk1611 is done!
# Chunk1612 is done!
# Chunk1613 is done!
# Chunk1614 is done!
# Chunk1615 is done!
# Chunk1616 is done!
# Chunk1617 is done!
# Chunk1619 is done!
# Chunk1618 is done!
# Chunk1620 is done!
# Chunk1621 is done!
# Chunk1623 is done!
# Chunk1622 is done!
# Chunk1625 is done!
# Chunk1626 is done!
# Chunk1624 is done!
# Chunk1628 is done!
# Chunk1627 is done!
# Chunk1629 is done!
# Chunk1630 is done!
# Chunk1631 is done!
# Chunk1632 is done!
# Chunk1633 is done!
# Chunk1634 is done!
# Chunk1636 is done!
# Chunk1635 is done!
# Chunk1637 is done!
# Chunk1638 is done!
# Chunk1640 is done!
# Chunk1639 is done!
# Chunk1641 is done!
# Chunk1642 is done!
# Chunk1643 is done!
# Chunk1644 is done!
# Chunk1645 is done!
# Chunk1646 is done!
# Chunk1649 is done!
# Chunk1647 is done!
# Chunk1648 is done!
# Chunk1650 is done!
# Chunk1651 is done!
# Chunk1653 is done!
# Chunk1652 is done!
# Chunk1654 is done!
# Chunk1655 is done!
# Chunk1656 is done!
# Chunk1657 is done!
# Chunk1661 is done!
# Chunk1660 is done!
# Chunk1658 is done!
# Chunk1659 is done!
# Chunk1664 is done!
# Chunk1663 is done!
# Chunk1662 is done!
# Chunk1666 is done!
# Chunk1665 is done!
# Chunk1667 is done!
# Chunk1668 is done!
# Chunk1669 is done!
# Chunk1670 is done!
# Chunk1671 is done!
# Chunk1672 is done!
# Chunk1673 is done!
# Chunk1674 is done!
# Chunk1675 is done!
# Chunk1676 is done!
# Chunk1677 is done!
# Chunk1679 is done!
# Chunk1681 is done!
# Chunk1678 is done!
# Chunk1680 is done!
# Chunk1682 is done!
# Chunk1684 is done!
# Chunk1683 is done!
# Chunk1685 is done!
# Chunk1686 is done!
# Chunk1688 is done!
# Chunk1687 is done!
# Chunk1689 is done!
# Chunk1690 is done!
# Chunk1691 is done!
# Chunk1692 is done!
# Chunk1693 is done!
# Chunk1694 is done!
# Chunk1695 is done!
# Chunk1696 is done!
# Chunk1697 is done!
# Chunk1701 is done!
# Chunk1698 is done!
# Chunk1700 is done!
# Chunk1699 is done!
# Chunk1702 is done!
# Chunk1703 is done!
# Chunk1704 is done!
# Chunk1705 is done!
# Chunk1709 is done!
# Chunk1706 is done!
# Chunk1708 is done!
# Chunk1707 is done!
# Chunk1711 is done!
# Chunk1710 is done!
# Chunk1713 is done!
# Chunk1712 is done!
# Chunk1714 is done!
# Chunk1715 is done!
# Chunk1716 is done!
# Chunk1717 is done!
# Chunk1718 is done!
# Chunk1721 is done!
# Chunk1719 is done!
# Chunk1720 is done!
# Chunk1723 is done!
# Chunk1722 is done!
# Chunk1724 is done!
# Chunk1727 is done!
# Chunk1725 is done!
# Chunk1726 is done!
# Chunk1728 is done!
# Chunk1729 is done!
# Chunk1731 is done!
# Chunk1732 is done!
# Chunk1730 is done!
# Chunk1733 is done!
# Chunk1734 is done!
# Chunk1735 is done!
# Chunk1736 is done!
# Chunk1737 is done!
# Chunk1739 is done!
# Chunk1738 is done!
# Chunk1742 is done!
# Chunk1740 is done!
# Chunk1741 is done!
# Chunk1743 is done!
# Chunk1744 is done!
# Chunk1746 is done!
# Chunk1747 is done!
# Chunk1745 is done!
# Chunk1748 is done!
# Chunk1749 is done!
# Chunk1750 is done!
# Chunk1751 is done!
# Chunk1753 is done!
# Chunk1752 is done!
# Chunk1754 is done!
# Chunk1755 is done!
# Chunk1756 is done!
# Chunk1758 is done!
# Chunk1757 is done!
# Chunk1761 is done!
# Chunk1759 is done!
# Chunk1762 is done!
# Chunk1760 is done!
# Chunk1764 is done!
# Chunk1763 is done!
# Chunk1765 is done!
# Chunk1766 is done!
# Chunk1767 is done!
# Chunk1768 is done!
# Chunk1771 is done!
# Chunk1769 is done!
# Chunk1770 is done!
# Chunk1773 is done!
# Chunk1772 is done!
# Chunk1774 is done!
# Chunk1776 is done!
# Chunk1775 is done!
# Chunk1777 is done!
# Chunk1778 is done!
# Chunk1779 is done!
# Chunk1781 is done!
# Chunk1780 is done!
# Chunk1782 is done!
# Chunk1785 is done!
# Chunk1784 is done!
# Chunk1783 is done!
# Chunk1788 is done!
# Chunk1786 is done!
# Chunk1787 is done!
# Chunk1790 is done!
# Chunk1789 is done!
# Chunk1791 is done!
# Chunk1792 is done!
# Chunk1793 is done!
# Chunk1794 is done!
# Chunk1795 is done!
# Chunk1796 is done!
# Chunk1797 is done!
# Chunk1798 is done!
# Chunk1799 is done!
# Chunk1802 is done!
# Chunk1801 is done!
# Chunk1800 is done!
# Chunk1804 is done!
# Chunk1805 is done!
# Chunk1803 is done!
# Chunk1807 is done!
# Chunk1806 is done!
# Chunk1808 is done!
# Chunk1809 is done!
# Chunk1810 is done!
# Chunk1812 is done!
# Chunk1811 is done!
# Chunk1814 is done!
# Chunk1813 is done!
# Chunk1816 is done!
# Chunk1815 is done!
# Chunk1817 is done!
# Chunk1818 is done!
# Chunk1819 is done!
# Chunk1820 is done!
# Chunk1822 is done!
# Chunk1821 is done!
# Chunk1825 is done!
# Chunk1823 is done!
# Chunk1824 is done!
# Chunk1827 is done!
# Chunk1826 is done!
# Chunk1830 is done!
# Chunk1828 is done!
# Chunk1829 is done!
# Chunk1831 is done!
# Chunk1832 is done!
# Chunk1834 is done!
# Chunk1833 is done!
# Chunk1835 is done!
# Chunk1836 is done!
# Chunk1837 is done!
# Chunk1839 is done!
# Chunk1838 is done!
# Chunk1840 is done!
# Chunk1842 is done!
# Chunk1841 is done!
# Chunk1844 is done!
# Chunk1843 is done!
# Chunk1845 is done!
# Chunk1847 is done!
# Chunk1846 is done!
# Chunk1848 is done!
# Chunk1849 is done!
# Chunk1850 is done!
# Chunk1851 is done!
# Chunk1852 is done!
# Chunk1853 is done!
# Chunk1854 is done!
# Chunk1855 is done!
# Chunk1856 is done!
# Chunk1857 is done!
# Chunk1858 is done!
# Chunk1860 is done!
# Chunk1859 is done!
# Chunk1861 is done!
# Chunk1862 is done!
# Chunk1863 is done!
# Chunk1864 is done!
# Chunk1865 is done!
# Chunk1866 is done!
# Chunk1867 is done!
# Chunk1868 is done!
# Chunk1869 is done!
# Chunk1870 is done!
# Chunk1871 is done!
# Chunk1873 is done!
# Chunk1872 is done!
# Chunk1874 is done!
# Chunk1876 is done!
# Chunk1875 is done!
# Chunk1877 is done!
# Chunk1878 is done!
# Chunk1880 is done!
# Chunk1879 is done!
# Chunk1882 is done!
# Chunk1881 is done!
# Chunk1885 is done!
# Chunk1884 is done!
# Chunk1883 is done!
# Chunk1886 is done!
# Chunk1889 is done!
# Chunk1887 is done!
# Chunk1888 is done!
# Chunk1890 is done!
# Chunk1891 is done!
# Chunk1894 is done!
# Chunk1892 is done!
# Chunk1893 is done!
# Chunk1895 is done!
# Chunk1896 is done!
# Chunk1897 is done!
# Chunk1898 is done!
# Chunk1899 is done!
# Chunk1902 is done!
# Chunk1901 is done!
# Chunk1900 is done!
# Chunk1904 is done!
# Chunk1903 is done!
# Chunk1906 is done!
# Chunk1905 is done!
# Chunk1907 is done!
# Chunk1908 is done!
# Chunk1909 is done!
# Chunk1911 is done!
# Chunk1910 is done!
# Chunk1913 is done!
# Chunk1914 is done!
# Chunk1912 is done!
# Chunk1915 is done!
# Chunk1916 is done!
# Chunk1919 is done!Chunk1917 is done!
#
# Chunk1918 is done!
# Chunk1920 is done!
# Chunk1921 is done!
# Chunk1923 is done!
# Chunk1922 is done!
# Chunk1926 is done!
# Chunk1924 is done!
# Chunk1925 is done!
# Chunk1927 is done!
# Chunk1928 is done!
# Chunk1930 is done!
# Chunk1929 is done!
# Chunk1931 is done!
# Chunk1932 is done!
# Chunk1934 is done!
# Chunk1933 is done!
# Chunk1935 is done!
# Chunk1936 is done!
# Chunk1938 is done!
# Chunk1939 is done!
# Chunk1937 is done!
# Chunk1941 is done!
# Chunk1942 is done!
# Chunk1940 is done!
# Chunk1943 is done!
# Chunk1947 is done!
# Chunk1946 is done!
# Chunk1945 is done!
# Chunk1944 is done!
# Chunk1949 is done!
# Chunk1948 is done!
# Chunk1950 is done!
# Chunk1952 is done!
# Chunk1951 is done!
# Chunk1954 is done!
# Chunk1953 is done!
# Chunk1955 is done!
# Chunk1956 is done!
# Chunk1957 is done!
# Chunk1960 is done!
# Chunk1959 is done!
# Chunk1958 is done!
# Chunk1961 is done!
# Chunk1963 is done!
# Chunk1962 is done!
# Chunk1964 is done!
# Chunk1967 is done!
# Chunk1965 is done!
# Chunk1966 is done!
# Chunk1968 is done!
# Chunk1969 is done!
# Chunk1970 is done!
# Chunk1972 is done!
# Chunk1971 is done!
# Chunk1973 is done!
# Chunk1974 is done!
# Chunk1975 is done!
# Chunk1976 is done!
# Chunk1977 is done!
# Chunk1978 is done!
# Chunk1979 is done!
# Chunk1981 is done!
# Chunk1980 is done!
# Chunk1983 is done!
# Chunk1982 is done!
# Chunk1985 is done!
# Chunk1987 is done!
# Chunk1984 is done!
# Chunk1986 is done!
# Chunk1989 is done!
# Chunk1988 is done!
# Chunk1990 is done!
# Chunk1991 is done!
# Chunk1992 is done!
# Chunk1993 is done!
# Chunk1995 is done!
# Chunk1994 is done!
# Chunk1996 is done!
# Chunk1997 is done!
# Chunk1999 is done!
# Chunk2000 is done!
# Chunk1998 is done!
# Chunk2001 is done!
# Chunk2002 is done!
# Chunk2003 is done!
# Chunk2004 is done!
# Chunk2005 is done!
# Chunk2006 is done!
# Chunk2007 is done!
# Chunk2008 is done!
# Chunk2009 is done!
# Chunk2010 is done!
# Chunk2011 is done!
# Chunk2012 is done!
# Chunk2013 is done!
# Chunk2014 is done!
# Chunk2015 is done!
# Chunk2016 is done!
# Chunk2017 is done!
# Chunk2018 is done!
# Chunk2020 is done!
# Chunk2019 is done!
# Chunk2021 is done!
# Chunk2022 is done!
# Chunk2023 is done!
# Chunk2024 is done!
# Chunk2025 is done!
# Chunk2026 is done!
# Chunk2029 is done!
# Chunk2027 is done!
# Chunk2028 is done!
# Chunk2030 is done!
# Chunk2031 is done!
# Chunk2033 is done!
# Chunk2032 is done!
# Chunk2034 is done!
# Chunk2035 is done!
# Chunk2036 is done!
# Chunk2038 is done!
# Chunk2037 is done!
# Chunk2040 is done!
# Chunk2039 is done!
# Chunk2041 is done!
# Chunk2042 is done!
# Chunk2043 is done!
# Chunk2044 is done!
# Chunk2049 is done!
# Chunk2046 is done!
# Chunk2047 is done!
# Chunk2045 is done!
# Chunk2048 is done!
# Chunk2050 is done!
# Chunk2051 is done!
# Chunk2053 is done!
# Chunk2054 is done!
# Chunk2052 is done!
# Chunk2055 is done!
# Chunk2057 is done!
# Chunk2056 is done!
# Chunk2058 is done!
# Chunk2059 is done!
# Chunk2060 is done!
# Chunk2061 is done!
# Chunk2062 is done!
# Chunk2063 is done!
# Chunk2064 is done!
# Chunk2066 is done!
# Chunk2065 is done!
# Chunk2069 is done!
# Chunk2068 is done!
# Chunk2067 is done!
# Chunk2070 is done!
# Chunk2071 is done!
# Chunk2073 is done!
# Chunk2075 is done!
# Chunk2074 is done!
# Chunk2072 is done!
# Chunk2077 is done!
# Chunk2076 is done!
# Chunk2078 is done!
# Chunk2079 is done!
# Chunk2081 is done!
# Chunk2080 is done!
# Chunk2082 is done!
# Chunk2083 is done!
# Chunk2084 is done!
# Chunk2087 is done!
# Chunk2085 is done!
# Chunk2086 is done!
# Chunk2088 is done!
# Chunk2089 is done!
# Chunk2090 is done!
# Chunk2091 is done!
# Chunk2095 is done!
# Chunk2092 is done!
# Chunk2093 is done!
# Chunk2094 is done!
# Chunk2096 is done!
# Chunk2098 is done!
# Chunk2097 is done!
# Chunk2099 is done!
# Chunk2100 is done!
# Chunk2101 is done!
# Chunk2102 is done!
# Chunk2103 is done!
# Chunk2104 is done!
# Chunk2106 is done!
# Chunk2105 is done!
# Chunk2109 is done!
# Chunk2107 is done!
# Chunk2108 is done!
# Chunk2110 is done!
# Chunk2112 is done!
# Chunk2111 is done!
# Chunk2114 is done!
# Chunk2113 is done!
# Chunk2115 is done!
# Chunk2116 is done!
# Chunk2119 is done!
# Chunk2117 is done!
# Chunk2118 is done!
# Chunk2122 is done!
# Chunk2121 is done!
# Chunk2120 is done!
# Chunk2123 is done!
# Chunk2125 is done!
# Chunk2127 is done!
# Chunk2126 is done!
# Chunk2124 is done!
# Chunk2129 is done!
# Chunk2128 is done!
# Chunk2132 is done!
# Chunk2130 is done!
# Chunk2131 is done!
# Chunk2133 is done!
# Chunk2134 is done!
# Chunk2135 is done!
# Chunk2136 is done!
# Chunk2139 is done!
# Chunk2137 is done!
# Chunk2140 is done!
# Chunk2138 is done!
# Chunk2141 is done!
# Chunk2142 is done!
# Chunk2144 is done!
# Chunk2143 is done!
# Chunk2145 is done!
# Chunk2147 is done!
# Chunk2146 is done!
# Chunk2148 is done!
# Chunk2149 is done!
# Chunk2150 is done!
# Chunk2151 is done!
# Chunk2152 is done!
# Chunk2153 is done!
# Chunk2154 is done!
# Chunk2155 is done!
# Chunk2156 is done!
# Chunk2157 is done!
# Chunk2158 is done!
# Chunk2159 is done!
# Chunk2160 is done!
# Chunk2161 is done!
# Chunk2162 is done!
# Chunk2164 is done!
# Chunk2163 is done!
# Chunk2165 is done!
# Chunk2167 is done!
# Chunk2166 is done!
# Chunk2168 is done!
# Chunk2169 is done!
# Chunk2170 is done!
# Chunk2171 is done!
# Chunk2172 is done!
# Chunk2173 is done!
# Chunk2175 is done!
# Chunk2174 is done!
# Chunk2177 is done!
# Chunk2176 is done!
# Chunk2178 is done!
# Chunk2179 is done!
# Chunk2180 is done!
# Chunk2181 is done!
# Chunk2182 is done!
# Chunk2184 is done!
# Chunk2186 is done!
# Chunk2183 is done!
# Chunk2185 is done!
# Chunk2187 is done!
# Chunk2188 is done!
# Chunk2189 is done!
# Chunk2192 is done!
# Chunk2191 is done!
# Chunk2190 is done!
# Chunk2193 is done!
# Chunk2195 is done!
# Chunk2194 is done!
# Chunk2196 is done!
# Chunk2197 is done!
# Chunk2198 is done!
# Chunk2201 is done!
# Chunk2200 is done!
# Chunk2202 is done!
# Chunk2199 is done!
# Chunk2205 is done!
# Chunk2203 is done!
# Chunk2204 is done!
# Chunk2207 is done!
# Chunk2206 is done!
# Chunk2208 is done!
# Chunk2209 is done!
# Chunk2210 is done!
# Chunk2211 is done!
# Chunk2212 is done!
# Chunk2213 is done!
# Chunk2214 is done!
# Chunk2215 is done!
# Chunk2216 is done!
# Chunk2217 is done!
# Chunk2219 is done!
# Chunk2221 is done!
# Chunk2218 is done!
# Chunk2220 is done!
# Chunk2222 is done!
# Chunk2223 is done!
# Chunk2224 is done!
# Chunk2225 is done!
# Chunk2226 is done!
# Chunk2227 is done!
# Chunk2228 is done!
# Chunk2231 is done!
# Chunk2229 is done!
# Chunk2230 is done!
# Chunk2232 is done!
# Chunk2233 is done!
# Chunk2234 is done!
# Chunk2235 is done!
# Chunk2236 is done!
# Chunk2239 is done!
# Chunk2237 is done!
# Chunk2238 is done!
# Chunk2240 is done!
# Chunk2241 is done!
# Chunk2243 is done!
# Chunk2242 is done!
# Chunk2244 is done!
# Chunk2245 is done!
# Chunk2246 is done!
# Chunk2248 is done!
# Chunk2247 is done!
# Chunk2249 is done!
# Chunk2250 is done!
# Chunk2252 is done!
# Chunk2251 is done!
# Chunk2253 is done!
# Chunk2254 is done!
# Chunk2255 is done!
# Chunk2256 is done!
# Chunk2257 is done!
# Chunk2258 is done!
# Chunk2261 is done!
# Chunk2259 is done!
# Chunk2260 is done!
# Chunk2262 is done!
# Chunk2263 is done!
# Chunk2264 is done!
# Chunk2265 is done!
# Chunk2268 is done!
# Chunk2266 is done!
# Chunk2267 is done!
# Chunk2271 is done!
# Chunk2270 is done!
# Chunk2269 is done!
# Chunk2272 is done!
# Chunk2273 is done!
# Chunk2274 is done!
# Chunk2275 is done!
# Chunk2276 is done!
# Chunk2277 is done!
# Chunk2280 is done!
# Chunk2278 is done!
# Chunk2279 is done!
# Chunk2281 is done!
# Chunk2283 is done!
# Chunk2282 is done!
# Chunk2285 is done!
# Chunk2284 is done!
# Chunk2286 is done!
# Chunk2288 is done!
# Chunk2287 is done!
# Chunk2291 is done!
# Chunk2289 is done!
# Chunk2290 is done!
# Chunk2292 is done!
# Chunk2294 is done!
# Chunk2293 is done!
# Chunk2295 is done!
# Chunk2297 is done!
# Chunk2296 is done!
# Chunk2298 is done!
# Chunk2300 is done!
# Chunk2299 is done!
# Chunk2301 is done!
# Chunk2302 is done!
# Chunk2303 is done!
# Chunk2304 is done!
# Chunk2306 is done!
# Chunk2307 is done!
# Chunk2305 is done!
# Chunk2308 is done!
# Chunk2309 is done!
# Chunk2312 is done!
# Chunk2313 is done!
# Chunk2310 is done!
# Chunk2311 is done!
# Chunk2314 is done!
# Chunk2315 is done!
# Chunk2317 is done!
# Chunk2316 is done!
# Chunk2318 is done!
# Chunk2319 is done!
# Chunk2320 is done!
# Chunk2321 is done!
# Chunk2322 is done!
# Chunk2323 is done!
# Chunk2324 is done!
# Chunk2327 is done!
# Chunk2325 is done!
# Chunk2326 is done!
# Chunk2328 is done!
# Chunk2330 is done!
# Chunk2329 is done!
# Chunk2331 is done!
# Chunk2332 is done!
# Chunk2333 is done!
# Chunk2334 is done!
# Chunk2335 is done!
# Chunk2336 is done!
# Chunk2337 is done!
# Chunk2338 is done!
# Chunk2339 is done!
# Chunk2342 is done!
# Chunk2340 is done!
# Chunk2341 is done!
# Chunk2343 is done!
# Chunk2344 is done!
# Chunk2346 is done!
# Chunk2345 is done!
# Chunk2347 is done!
# Chunk2348 is done!
# Chunk2349 is done!
# Chunk2350 is done!
# Chunk2351 is done!
# Chunk2352 is done!
# Chunk2353 is done!
# Chunk2355 is done!
# Chunk2354 is done!
# Chunk2356 is done!
# Chunk2357 is done!
# Chunk2358 is done!
# Chunk2359 is done!
# Chunk2361 is done!
# Chunk2360 is done!
# Chunk2364 is done!
# Chunk2363 is done!
# Chunk2366 is done!
# Chunk2365 is done!
# Chunk2362 is done!
# Chunk2367 is done!
# Chunk2368 is done!
# Chunk2370 is done!
# Chunk2369 is done!
# Chunk2371 is done!
# Chunk2372 is done!
# Chunk2375 is done!
# Chunk2373 is done!
# Chunk2374 is done!
# Chunk2376 is done!
# Chunk2377 is done!
# Chunk2378 is done!
# Chunk2380 is done!
# Chunk2379 is done!
# Chunk2381 is done!
# Chunk2385 is done!
# Chunk2383 is done!
# Chunk2382 is done!
# Chunk2384 is done!
# Chunk2387 is done!
# Chunk2389 is done!
# Chunk2386 is done!
# Chunk2388 is done!
# Chunk2391 is done!
# Chunk2390 is done!
# Chunk2392 is done!
# Chunk2393 is done!
# Chunk2394 is done!
# Chunk2395 is done!
# Chunk2396 is done!
# Chunk2398 is done!
# Chunk2397 is done!
# Chunk2400 is done!
# Chunk2399 is done!
# Chunk2401 is done!
# Chunk2402 is done!
# Chunk2403 is done!
# Chunk2407 is done!
# Chunk2404 is done!
# Chunk2405 is done!
# Chunk2406 is done!
# Chunk2409 is done!
# Chunk2408 is done!
# Chunk2410 is done!
# Chunk2411 is done!
# Chunk2414 is done!
# Chunk2412 is done!
# Chunk2413 is done!
# Chunk2415 is done!
# Chunk2418 is done!
# Chunk2416 is done!
# Chunk2417 is done!
# Chunk2419 is done!
# Chunk2420 is done!
# Chunk2422 is done!
# Chunk2421 is done!
# Chunk2423 is done!
# Chunk2426 is done!
# Chunk2425 is done!
# Chunk2424 is done!
# Chunk2427 is done!
# Chunk2429 is done!
# Chunk2428 is done!
# Chunk2431 is done!
# Chunk2432 is done!
# Chunk2430 is done!
# Chunk2433 is done!
# Chunk2435 is done!
# Chunk2434 is done!
# Chunk2438 is done!
# Chunk2436 is done!
# Chunk2439 is done!
# Chunk2437 is done!
# Chunk2440 is done!
# Chunk2442 is done!
# Chunk2441 is done!
# Chunk2446 is done!
# Chunk2445 is done!
# Chunk2443 is done!
# Chunk2444 is done!
# Chunk2448 is done!
# Chunk2449 is done!
# Chunk2447 is done!
# Chunk2452 is done!
# Chunk2450 is done!
# Chunk2453 is done!
# Chunk2451 is done!
# Chunk2454 is done!
# Chunk2455 is done!
# Chunk2457 is done!
# Chunk2456 is done!
# Chunk2458 is done!
# Chunk2459 is done!
# Chunk2460 is done!
# Chunk2461 is done!
# Chunk2462 is done!
# Chunk2465 is done!
# Chunk2463 is done!
# Chunk2464 is done!
# Chunk2466 is done!
# Chunk2467 is done!
# Chunk2468 is done!
# Chunk2469 is done!
# Chunk2471 is done!
# Chunk2470 is done!
# Chunk2473 is done!
# Chunk2472 is done!
# Chunk2476 is done!
# Chunk2475 is done!
# Chunk2474 is done!
# Chunk2477 is done!
# Chunk2478 is done!
# Chunk2479 is done!
# Chunk2480 is done!
# Chunk2481 is done!
# Chunk2482 is done!
