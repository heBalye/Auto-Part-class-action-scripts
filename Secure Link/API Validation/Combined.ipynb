# %%
import pandas as pd

# %%
df1 = pd.read_excel(r'C:\Users\FFR0103\Desktop\My files\WORK\Auto part\Secure Link\Output\result_1.xlsx', index_col=[0])
df2 = pd.read_excel(r'C:\Users\FFR0103\Desktop\My files\WORK\Auto part\Secure Link\Output\result_2.xlsx', index_col=[0])
df3 = pd.read_excel(r'C:\Users\FFR0103\Desktop\My files\WORK\Auto part\Secure Link\Output\result_3.xlsx', index_col=[0])
df4 = pd.read_excel(r'C:\Users\FFR0103\Desktop\My files\WORK\Auto part\Secure Link\Output\result_4.xlsx', index_col=[0])
df5 = pd.read_excel(r'C:\Users\FFR0103\Desktop\My files\WORK\Auto part\Secure Link\Output\result_5.xlsx', index_col=[0])

# %%
combined = pd.concat([df1,df2,df3,df4,df5])
combined
# Out:
#              OriginalVIN                VIN  \
# 0      1FDSE37F6WHB46480  1FDSE37F6WHB46480
# 1      1HVBBAAN9TH295537  1HVBBAAN9TH295537
# 2      1GNFG154X81173240  1GNFG154X81173240
# 3      1HVBBABN2WH568336  1HVBBABN2WH568336
# 0      1GBJG31K491142168  1GBJG31K491142168
# 1      1HVBBAAN44H673734  1HVBBAAN44H673734
# 2      1GB3GRBG0G1305627  1GB3GRBG0G1305627
# 3      1BAKGCSA8JF345393  1BAKGCSA8JF345393
# 0      1GBJG31F821189664  1GBJG31F821189664
# 1      4UZABRFC1JCJT6587  4UZABRFC1JCJT6587
# 2      1FTNS24263HA11260  1FTNS24263HA11260
# 3      1BAKDCKH05F226071  1BAKDCKH05F226071
# 0      4DRBVAAP25A986852  4DRBVAAP25A986852
# 1      1GB6G5BL9F1278784  1GB6G5BL9F1278784
# 2      1FD2E35L18DB33252  1FD2E35L18DB33252
# 3      2C7WDGBG4JR303729  2C7WDGBG4JR303729
# 0           SSL000273000       SSL000273000
# 1      1GBHG31Y8SF226554  1GBHG31Y8SF226554
# 2      1BAKGCKA69F257650  1BAKGCKA69F257650
# 3      4DRBUSKN0AB236232  4DRBUSKN0AB236232
# ...

# %%
combined.to_excel(r'C:\Users\FFR0103\Desktop\My files\WORK\Auto part\Secure Link\Output\combined.xlsx',index=False)
