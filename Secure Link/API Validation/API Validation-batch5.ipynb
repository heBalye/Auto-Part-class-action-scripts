# %%
from CleanVIN import ValidationProcess, Col_to_str
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\FFR0103\Desktop\My files\WORK\Auto part\Secure Link\Source\API\VINs to validate.xlsx')
df
# Out:
#                         VIN  RowID
# 0         1FDSE37F6WHB46480      1
# 1         1HVBBAAN9TH295537      2
# 2         1GNFG154X81173240      3
# 3         1HVBBABN2WH568336      4
# 4         1GBJG31K491142168      5
# 5         1HVBBAAN44H673734      6
# 6         1GB3GRBG0G1305627      7
# 7         1BAKGCSA8JF345393      8
# 8         1GBJG31F821189664      9
# 9         4UZABRFC1JCJT6587     10
# 10        1FTNS24263HA11260     11
# 11        1BAKDCKH05F226071     12
# 12        4DRBVAAP25A986852     13
# 13        1GB6G5BL9F1278784     14
# 14        1FD2E35L18DB33252     15
# 15        2C7WDGBG4JR303729     16
# 16             SSL000273000     17
# 17        1GBHG31Y8SF226554     18
# 18        1BAKGCKA69F257650     19
# 19        4DRBUSKN0AB236232     20
# 20        4UZABRDT6CCBP2493     21
# 21        1FTWF3BR1AEA75252     22
# 22        4DRBRAAN74B968133     23
# 23        4UZABRFC5JCJT6656     24
# 24             HF0000063000     25
# 25        1FDWE35F13HB13869     26
# 26        1GDHG31Y3SF552818     27
# 27        4UZABRDU5BCAU5032     28
# 28        1HVBBABP4XH201540     29
# 29        1T75L3B2XS1139050     30
# ...                     ...    ...
# 46867     4UZABRDT08CZ63901  46869
# 46868     4DRBUAFP16A988220  46870
# 46869     1GB6GUBGXH1194747  46871
# 46870     4UZABRDT8HCHS4924  46872
# 46871               L3BNR0N  46873
# 46872     1BAAHCPA02F205065  46874
# 46873            CAC84301S7  46875
# 46874     1T88P4E22B1138568  46876
# 46875  4UZABRDT0ACAR2149ADJ  46877
# 46876     1T7YU4E27B1135713  46878
# 46877     JTDZN3EU3HJ072126  46879
# 46878     4UZABRDT5DCBZ7449  46880
# 46879     1D4GP25R57B187511  46881
# 46880     2C4RDGBG2GR139996  46882
# 46881     1GBHG31C191155175  46883
# 46882     1T88N3B27X1068772  46884
# 46883     4DRBUAAP5AB142313  46885
# 46884     4DRBUC8P2GB221657  46886
# 46885     4UZAAXAK82CJ43236  46887
# 46886     1GB6G5BL8D1172162  46888
# 46887     1BAKFCKH75F228863  46889
# 46888     1FDSE37F3WHA40620  46890
# 46889     4DRBUSKN6AB229026  46891
# 46890     4UZAAXDG06CV69693  46892
# 46891     1N9MLACL7AC084161  46893
# 46892     4UZABRDU6BCAU5007  46894
# 46893     4UZABRDU1BCAU5058  46895
# 46894  1BABHCKA75F219447ADJ  46896
# 46895     4DRBUC8N2KB685538  46897
# 46896     1GDL7T1B7YJ525553  46898
#
# [46897 rows x 2 columns]

# %%
df[df.VIN.str.contains(";")]
# Out:
# Empty DataFrame
# Columns: [VIN, RowID]
# Index: []

# %%
df[df.VIN.str.contains(",")]
# Out:
#                                VIN  RowID
# 10300                   2CH,25WATT  10302
# 20256      SV-B-B-C20,SV-B-DECOY-C  20258
# 22332   GTX,10SYS/8GRP,15W,LTR,800  22334
# 22467                 LS,35W,10CHA  22469
# 29371                 SM50,40W,2CH  29373
# 31734  MXM8290034, SCNK82601DS,DW,  31736
# 32794       MXM81103W9, CNU82514MJ  32796
# 41574      MXM829003J, SCNK82601DX  41576
# 44005   450-490MHZ,40W,LTR/CONV,MB  44007
# 45577                 LS,35W,10CHB  45579

# %%
df_1 = df.iloc[:10000,:]
df_2 = df.iloc[10000:20000,:]
df_3 = df.iloc[20000:30000,:]
df_4 = df.iloc[30000:40000,:]
df_5 = df.iloc[40000:,:]

# %%
QC = pd.concat([df_1,df_2,df_3,df_4,df_5]) == df
QC[(QC['VIN'] == False)|(QC['RowID'] == False)]

# %% [markdown]
# ## 5th Batch

# %%
data_5 = Col_to_str(df_5[5000:],'VIN',';')
data_5.count(';')
# Out:
# 1896

# %%
import glob
glob.glob(r'C:\Users\FFR0103\Desktop\My files\WORK\Auto part\Secure Link\Output\*')

# %%
process_5 = ValidationProcess(Col_to_str(df_5[5000:],'VIN',';'),4)
process_5.split_to_Chunk(4)['Chunk144']
# Out:
# '2C3HD46R62H103186;LS,35W,10CHB;4UZABRFC1JCJT6606;3GKGC26F7XG546060'

# %%
Col_to_str(df_5,'VIN',';').count(';')
# Out:
# 9999

# %%
df_5 = df_2
temp = pd.DataFrame()
for i in range(Col_to_str(df_5,'VIN',';').count(';') // 1000 + 1):
    print(f'|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||current range:{i*1000} ~ {(i+1)*1000}\n\n')
    if (i + 1) * 1000 < Col_to_str(df_5,'VIN',';').count(';'):
        print(i*1000,(i+1)*1000)
        process_temp = ValidationProcess(Col_to_str(df_5[i*1000:(i+1)*1000],'VIN',';'),4)
        result_temp = process_temp.getAll()
        temp = pd.concat([temp,result_temp])
    else:
        print(i*1000 ,Col_to_str(df_5,'VIN',';').count(';'),'\n')
        process_temp = ValidationProcess(Col_to_str(df_5[i*1000:],'VIN',';'),4)
        result_temp = process_temp.getAll()
        temp = pd.concat([temp,result_temp])
    

temp
# process_5 = ValidationProcess(data_5,4)
# result_5 = process_5.getAll()





# filename = 'result_5'
# result_5.to_excel(rf'C:\Users\FFR0103\Desktop\My files\WORK\Auto part\Secure Link\Output\{filename}.xlsx')
# Out:
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||current range:0 ~ 1000
#
#
# 0 1000
# 200
# 200
# Chunk2 is done! Total: 251
# Chunk5 is done! Total: 251
# 200
# Chunk1 is done! Total: 251
# 200
# Chunk4 is done! Total: 251
# 200
# Chunk6 is done! Total: 251
# 200200
#
# 200
# 200Chunk10 is done! Total: 251
# Chunk9 is done! Total: 251
#
# 200Chunk0 is done! Total: 251200Chunk7 is done! Total: 251200
# 200
#
#
#
# 200
#
# 200
# Chunk13 is done! Total: 251
# 200
# Chunk11 is done! Total: 251
# 200200
#
# 200200
#
# Chunk12 is done! Total: 251
# Chunk18 is done! Total: 251
# 200
# Chunk16 is done! Total: 251
# Chunk8 is done! Total: 251
# Chunk15 is done! Total: 251
# Chunk17 is done! Total: 251200
#
# Chunk19 is done! Total: 251
# Chunk21 is done! Total: 251
# Chunk20 is done! Total: 251
# Chunk14 is done! Total: 251
# Chunk3 is done! Total: 251
# 200
# Chunk22 is done! Total: 251
# 200
# Chunk24 is done! Total: 251
# 200
# 200200
#
# Chunk30 is done! Total: 251
# Chunk23 is done! Total: 251200
# Chunk28 is done! Total: 251
#
# Chunk29 is done! Total: 251
# 200
# Chunk25 is done! Total: 251
# 200
# Chunk33 is done! Total: 251200
#
# 200
# 200Chunk27 is done! Total: 251
#
# 200Chunk41 is done! Total: 251
#
# Chunk40 is done! Total: 251
# Chunk26 is done! Total: 251
# 200
# Chunk34 is done! Total: 251
# 200
# 200200
# 200200
#
# 200Chunk31 is done! Total: 251
#
# 200
#
# Chunk38 is done! Total: 251
# Chunk36 is done! Total: 251
# Chunk35 is done! Total: 251
# Chunk37 is done! Total: 251Chunk42 is done! Total: 251
#
# Chunk32 is done! Total: 251
# 200
# Chunk39 is done! Total: 251
# 200
# 200
# Chunk47 is done! Total: 251
# Chunk43 is done! Total: 251
# 200
# Chunk53 is done! Total: 251
# 200
# Chunk46 is done! Total: 251
# 200
# 200
# Chunk48 is done! Total: 251
# Chunk50 is done! Total: 251
# 200
# Chunk51 is done! Total: 251
# 200
# 200200
#
# Chunk45 is done! Total: 251
# Chunk44 is done! Total: 251
# 200
# 200
# Chunk60 is done! Total: 251
# Chunk55 is done! Total: 251
# Chunk59 is done! Total: 251
# 200
# Chunk62 is done! Total: 251
# 200
# 200
# Chunk49 is done! Total: 251Chunk57 is done! Total: 251
#
# 200
# Chunk58 is done! Total: 251
# 200
# Chunk61 is done! Total: 251
# 200
# Chunk52 is done! Total: 251
# 200
# Chunk63 is done! Total: 251
# 200
# Chunk66 is done! Total: 251
# 200
# Chunk67 is done! Total: 251
# 200
# 200
# Chunk64 is done! Total: 251200
# Chunk65 is done! Total: 251
#
# Chunk68 is done! Total: 251
# 200
# Chunk74 is done! Total: 251
# 200200
#
# Chunk56 is done! Total: 251
# Chunk54 is done! Total: 251
# 200
# Chunk75 is done! Total: 251
# 200
# Chunk69 is done! Total: 251
# 200
# Chunk70 is done! Total: 251
# 200
# Chunk73 is done! Total: 251200
#
# Chunk80 is done! Total: 251
# 200
# Chunk71 is done! Total: 251
# 200
# Chunk72 is done! Total: 251
# 200
# Chunk78 is done! Total: 251
# 200
# Chunk81 is done! Total: 251
# 200
# Chunk84 is done! Total: 251
# 200200
#
# 200
# Chunk77 is done! Total: 251
# Chunk82 is done! Total: 251
# 200
# Chunk76 is done! Total: 251
# Chunk79 is done! Total: 251
# 200
# 200200
#
# Chunk83 is done! Total: 251
# Chunk89 is done! Total: 251
# Chunk87 is done! Total: 251
# 200
# Chunk90 is done! Total: 251
# 200
# Chunk85 is done! Total: 251
# 200
# Chunk88 is done! Total: 251
# 200
# Chunk93 is done! Total: 251
# 200
# 200200
#
# Chunk95 is done! Total: 251
# Chunk94 is done! Total: 251Chunk99 is done! Total: 251
#
# 200
# 200Chunk92 is done! Total: 251
#
# Chunk86 is done! Total: 251
# 200
# Chunk98 is done! Total: 251
# 200
# Chunk97 is done! Total: 251
# 200
# Chunk91 is done! Total: 251
# 200
# Chunk101 is done! Total: 251
# 200
# Chunk100 is done! Total: 251
# 200
# Chunk102 is done! Total: 251
# 200
# 200
# Chunk96 is done! Total: 251
# Chunk107 is done! Total: 251
# 200
# 200
# Chunk103 is done! Total: 251
# Chunk105 is done! Total: 251
# 200
# Chunk109 is done! Total: 251200
#
# 200
# Chunk104 is done! Total: 251Chunk108 is done! Total: 251
# 200
#
# Chunk115 is done! Total: 251
# 200
# 200
# 200200
#
# Chunk113 is done! Total: 251
# 200200
#
# 200
# 200
# 200
# Chunk114 is done! Total: 251
# Chunk110 is done! Total: 251
# Chunk116 is done! Total: 251
# Chunk117 is done! Total: 251Chunk106 is done! Total: 251
#
# Chunk111 is done! Total: 251200
#
# 200Chunk120 is done! Total: 251
# 200
#
# 200200
#
# Chunk122 is done! Total: 251Chunk118 is done! Total: 251
#
# Chunk112 is done! Total: 251Chunk119 is done! Total: 251
#
# Chunk121 is done! Total: 251Chunk123 is done! Total: 251
#
# 200
# Chunk128 is done! Total: 251
# 200
# Chunk125 is done! Total: 251
# 200
# Chunk126 is done! Total: 251
# 200
# Chunk124 is done! Total: 251
# 200
# 200
# Chunk137 is done! Total: 251
# Chunk127 is done! Total: 251
# 200
# Chunk130 is done! Total: 251
# 200
# Chunk143 is done! Total: 251
# 200
# Chunk131 is done! Total: 251
# 200
# 200
# Chunk135 is done! Total: 251
# 200
# 200
# 200
# 200
# Chunk134 is done! Total: 251
# 200200
#
# 200
# Chunk145 is done! Total: 251
# Chunk129 is done! Total: 251
# Chunk140 is done! Total: 251
# Chunk142 is done! Total: 251200
#
# 200
# 200
# 200
# 200
# 200Chunk136 is done! Total: 251
#
# 200Chunk139 is done! Total: 251
#
# Chunk144 is done! Total: 251
# Chunk138 is done! Total: 251
# Chunk141 is done! Total: 251
# 200
# Chunk132 is done! Total: 251Chunk147 is done! Total: 251
# Chunk148 is done! Total: 251
#
# Chunk133 is done! Total: 251
# Chunk149 is done! Total: 251Chunk146 is done! Total: 251
#
# 200200
#
# Chunk150 is done! Total: 251
# Chunk151 is done! Total: 251
# 200
# Chunk153 is done! Total: 251
# 200
# Chunk156 is done! Total: 251
# 200
# Chunk154 is done! Total: 251
# 200
# Chunk152 is done! Total: 251
# 200
# Chunk164 is done! Total: 251
# 200
# Chunk163 is done! Total: 251
# 200
# Chunk157 is done! Total: 251
# 200
# 200
# 200200
#
# 200Chunk167 is done! Total: 251
#
# 200200
# 200
# 200
#
# 200
# 200
# 200Chunk170 is done! Total: 251
# 200
#
# Chunk161 is done! Total: 251
# Chunk158 is done! Total: 251
# Chunk155 is done! Total: 251
# Chunk168 is done! Total: 251
# Chunk160 is done! Total: 251
# Chunk159 is done! Total: 251200
#
# Chunk162 is done! Total: 251
# Chunk171 is done! Total: 251
# 200
# 200
# Chunk166 is done! Total: 251
# Chunk165 is done! Total: 251
# Chunk177 is done! Total: 251
# Chunk175 is done! Total: 251
# Chunk169 is done! Total: 251
# Chunk174 is done! Total: 251
# 200
# 200
# Chunk172 is done! Total: 251
# Chunk173 is done! Total: 251
# 200
# Chunk176 is done! Total: 251200
#
# Chunk188 is done! Total: 251
# 200
# Chunk184 is done! Total: 251
# 200
# Chunk182 is done! Total: 251
# 200
# Chunk178 is done! Total: 251
# 200
# Chunk179 is done! Total: 251
# 200
# 200
# 200200
# Chunk180 is done! Total: 251200
#
#
# 200200
#
# 200
# Chunk183 is done! Total: 251
# Chunk190 is done! Total: 251Chunk187 is done! Total: 251
# Chunk191 is done! Total: 251
#
# Chunk194 is done! Total: 251
# 200
# 200
# 200
# Chunk185 is done! Total: 251Chunk181 is done! Total: 251
#
# Chunk196 is done! Total: 251
# Chunk192 is done! Total: 251
# 200Chunk197 is done! Total: 251
#
# 200
# Chunk186 is done! Total: 251
# 200
# 200Chunk189 is done! Total: 251
#
# Chunk193 is done! Total: 251
# 200
# Chunk198 is done! Total: 251200
#
# Chunk195 is done! Total: 251
# 200
# Chunk199 is done! Total: 251
# Chunk200 is done! Total: 251
# 200
# Chunk201 is done! Total: 251
# 200
# Chunk202 is done! Total: 251
# 200
# Chunk203 is done! Total: 251
# 200
# 200
# Chunk210 is done! Total: 251
# Chunk212 is done! Total: 251
# 200
# Chunk206 is done! Total: 251
# 200
# Chunk208 is done! Total: 251
# 200
# Chunk211 is done! Total: 251
# 200
# Chunk204 is done! Total: 251200
#
# 200
# Chunk209 is done! Total: 251
# 200
# 200
# Chunk221 is done! Total: 251
# Chunk217 is done! Total: 251
# 200200
# 200
#
# Chunk215 is done! Total: 251200
#
# Chunk220 is done! Total: 251
# 200
# 200200
#
# Chunk214 is done! Total: 251
# Chunk205 is done! Total: 251
# 200
# 200
# Chunk207 is done! Total: 251
# Chunk219 is done! Total: 251
# 200
# Chunk218 is done! Total: 251
# 200
# Chunk216 is done! Total: 251
# Chunk213 is done! Total: 251
# Chunk223 is done! Total: 251
# Chunk224 is done! Total: 251Chunk222 is done! Total: 251
#
# 200
# Chunk226 is done! Total: 251
# 200
# Chunk228 is done! Total: 251
# 200
# Chunk225 is done! Total: 251
# 200
# Chunk227 is done! Total: 251
# 200
# Chunk232 is done! Total: 251
# 200
# Chunk230 is done! Total: 251
# 200
# Chunk229 is done! Total: 251
# 200
# Chunk231 is done! Total: 251
# 200
# Chunk233 is done! Total: 251
# 200
# Chunk235 is done! Total: 251
# 200
# Chunk239 is done! Total: 251
# 200200
#
# 200
# Chunk240 is done! Total: 251
# 200Chunk237 is done! Total: 251200200
#
#
#
# 200
# 200
# Chunk244 is done! Total: 251
# Chunk236 is done! Total: 251
# Chunk238 is done! Total: 251
# 200
# Chunk245 is done! Total: 251200
# 200
#
# Chunk243 is done! Total: 251
# Chunk234 is done! Total: 251
# Chunk242 is done! Total: 251
# 200
# Chunk241 is done! Total: 251
# Chunk248 is done! Total: 251Chunk246 is done! Total: 251
#
# 200
# Chunk247 is done! Total: 251200
#
# Chunk249 is done! Total: 251
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||current range:1000 ~ 2000
#
#
# 1000 2000
# 200
# Chunk2 is done! Total: 251
# 200
# Chunk1 is done! Total: 251
# 200
# Chunk12 is done! Total: 251
# 200200
# 200
#
# 200
# 200
# 200
# 200200
#
# 200200
# 200
#
# Chunk16 is done! Total: 251
# 200
# 200Chunk7 is done! Total: 251
#
# 200Chunk5 is done! Total: 251
#
# 200
# Chunk18 is done! Total: 251
# Chunk13 is done! Total: 251Chunk14 is done! Total: 251
#
# Chunk8 is done! Total: 251
# Chunk6 is done! Total: 251
# Chunk10 is done! Total: 251
# Chunk19 is done! Total: 251
# Chunk11 is done! Total: 251
# Chunk4 is done! Total: 251
# Chunk20 is done! Total: 251
# Chunk9 is done! Total: 251
# Chunk17 is done! Total: 251
# 200
# Chunk21 is done! Total: 251
# 200
# Chunk15 is done! Total: 251
# 200
# Chunk22 is done! Total: 251
# 200
# Chunk0 is done! Total: 251
# 200
# Chunk3 is done! Total: 251
# 200
# Chunk25 is done! Total: 251
# 200
# Chunk23 is done! Total: 251
# 200
# Chunk36 is done! Total: 251
# 200
# Chunk30 is done! Total: 251
# 200
# Chunk29 is done! Total: 251
# 200
# Chunk24 is done! Total: 251
# 200
# Chunk37 is done! Total: 251
# 200
# Chunk27 is done! Total: 251
# 200200
#
# 200
# 200Chunk26 is done! Total: 251
#
# Chunk28 is done! Total: 251
# Chunk39 is done! Total: 251
# Chunk34 is done! Total: 251200
#
# 200Chunk40 is done! Total: 251
#
# 200200
#
# 200Chunk32 is done! Total: 251Chunk33 is done! Total: 251
#
#
# Chunk42 is done! Total: 251
# Chunk35 is done! Total: 251
# 200
# 200
# Chunk41 is done! Total: 251
# Chunk44 is done! Total: 251
# 200
# Chunk38 is done! Total: 251
# 200
# Chunk45 is done! Total: 251
# 200
# Chunk46 is done! Total: 251
# 200
# Chunk43 is done! Total: 251200
#
# Chunk48 is done! Total: 251
# 200
# Chunk54 is done! Total: 251
# 200
# Chunk53 is done! Total: 251
# 200200
#
# Chunk47 is done! Total: 251
# Chunk49 is done! Total: 251
# 200
# 200
# 200
# Chunk62 is done! Total: 251
# 200Chunk58 is done! Total: 251
#
# 200
# Chunk61 is done! Total: 251
# Chunk63 is done! Total: 251200
#
# Chunk50 is done! Total: 251
# 200
# Chunk52 is done! Total: 251
# Chunk51 is done! Total: 251
# 200
# 200
# Chunk57 is done! Total: 251
# Chunk59 is done! Total: 251
# 200
# 200
# Chunk65 is done! Total: 251
# Chunk67 is done! Total: 251
# 200
# 200
# Chunk31 is done! Total: 251
# 200Chunk56 is done! Total: 251
# 200
#
# 200
# Chunk55 is done! Total: 251
# Chunk64 is done! Total: 251
# Chunk60 is done! Total: 251
# 200
# Chunk66 is done! Total: 251
# 200
# Chunk70 is done! Total: 251
# 200
# Chunk73 is done! Total: 251
# 200
# Chunk69 is done! Total: 251
# 200
# Chunk68 is done! Total: 251
# 200
# Chunk75 is done! Total: 251
# 200
# Chunk71 is done! Total: 251
# 200
# 200
# 200
# Chunk84 is done! Total: 251
# 200200
#
# 200
# 200
# 200
# Chunk74 is done! Total: 251
# Chunk76 is done! Total: 251
# 200Chunk77 is done! Total: 251
# Chunk86 is done! Total: 251
#
# Chunk72 is done! Total: 251
# 200
# 200
# Chunk79 is done! Total: 251
# Chunk90 is done! Total: 251
# Chunk80 is done! Total: 251Chunk81 is done! Total: 251
# Chunk85 is done! Total: 251
# 200
#
# 200
# Chunk78 is done! Total: 251
# Chunk82 is done! Total: 251
# 200
# 200
# Chunk91 is done! Total: 251
# 200Chunk87 is done! Total: 251
#
# 200Chunk88 is done! Total: 251
# 200
#
# 200
# Chunk89 is done! Total: 251
# Chunk93 is done! Total: 251
# 200
# Chunk83 is done! Total: 251
# Chunk92 is done! Total: 251
# 200
# Chunk97 is done! Total: 251
# 200
# 200
# Chunk95 is done! Total: 251
# Chunk94 is done! Total: 251
# 200
# 200Chunk96 is done! Total: 251
#
# Chunk104 is done! Total: 251
# 200
# 200
# Chunk99 is done! Total: 251
# Chunk113 is done! Total: 251
# 200
# Chunk112 is done! Total: 251
# 200
# Chunk106 is done! Total: 251
# 200200
#
# 200
# 200
# 200
# Chunk100 is done! Total: 251200
#
# 200200
#
# Chunk110 is done! Total: 251200
#
# 200
# Chunk105 is done! Total: 251
# Chunk107 is done! Total: 251200
#
# Chunk103 is done! Total: 251
# Chunk101 is done! Total: 251
# Chunk98 is done! Total: 251
# 200
# Chunk108 is done! Total: 251
# Chunk102 is done! Total: 251
# Chunk109 is done! Total: 251
# Chunk114 is done! Total: 251
# Chunk111 is done! Total: 251
# 200
# Chunk116 is done! Total: 251
# 200
# Chunk118 is done! Total: 251
# 200
# Chunk117 is done! Total: 251
# 200
# Chunk121 is done! Total: 251200
#
# Chunk115 is done! Total: 251
# 200
# Chunk120 is done! Total: 251
# 200
# Chunk130 is done! Total: 251
# 200
# 200
# Chunk124 is done! Total: 251
# Chunk126 is done! Total: 251
# 200
# Chunk128 is done! Total: 251
# 200
# Chunk119 is done! Total: 251
# 200
# Chunk122 is done! Total: 251
# 200
# 200
# Chunk134 is done! Total: 251
# Chunk132 is done! Total: 251
# 200
# 200
# Chunk138 is done! Total: 251
# Chunk136 is done! Total: 251
# 200
# Chunk131 is done! Total: 251
# 200
# Chunk125 is done! Total: 251
# 200
# 200
# Chunk135 is done! Total: 251
# Chunk139 is done! Total: 251
# 200
# 200
# 200
# 200
# Chunk129 is done! Total: 251
# Chunk123 is done! Total: 251
# Chunk133 is done! Total: 251
# Chunk127 is done! Total: 251
# 200
# Chunk137 is done! Total: 251
# 200
# Chunk145 is done! Total: 251
# 200
# Chunk146 is done! Total: 251
# 200
# 200
# 200
# Chunk141 is done! Total: 251Chunk140 is done! Total: 251
#
# Chunk142 is done! Total: 251
# 200
# Chunk148 is done! Total: 251
# 200
# 200
# Chunk151 is done! Total: 251
# Chunk149 is done! Total: 251
# 200
# 200
# Chunk144 is done! Total: 251
# Chunk152 is done! Total: 251
# 200
# Chunk143 is done! Total: 251
# 200
# Chunk147 is done! Total: 251
# 200
# Chunk153 is done! Total: 251200
#
# 200
# Chunk154 is done! Total: 251
# Chunk150 is done! Total: 251200
#
# 200
# 200Chunk164 is done! Total: 251200
#
#
# 200
# 200
# Chunk156 is done! Total: 251Chunk155 is done! Total: 251
#
# 200
# Chunk159 is done! Total: 251
# Chunk158 is done! Total: 251Chunk161 is done! Total: 251
#
# Chunk157 is done! Total: 251
# 200
# Chunk165 is done! Total: 251
# 200
# Chunk162 is done! Total: 251
# 200
# Chunk160 is done! Total: 251
# 200
# Chunk163 is done! Total: 251
# 200
# Chunk167 is done! Total: 251
# 200
# 200
# 200
# Chunk169 is done! Total: 251
# Chunk168 is done! Total: 251
# 200
# Chunk170 is done! Total: 251
# Chunk171 is done! Total: 251
# 200
# Chunk166 is done! Total: 251
# 200
# 200Chunk172 is done! Total: 251
#
# Chunk174 is done! Total: 251
# 200
# Chunk177 is done! Total: 251
# 200
# Chunk175 is done! Total: 251
# 200
# 200
# Chunk180 is done! Total: 251
# Chunk181 is done! Total: 251
# 200
# Chunk176 is done! Total: 251
# 200
# 200
# Chunk173 is done! Total: 251
# Chunk184 is done! Total: 251
# 200
# Chunk183 is done! Total: 251
# 200
# Chunk179 is done! Total: 251
# 200
# Chunk185 is done! Total: 251
# 200
# Chunk189 is done! Total: 251
# 200
# Chunk178 is done! Total: 251
# 200
# 200
# Chunk182 is done! Total: 251
# Chunk188 is done! Total: 251
# 200
# Chunk186 is done! Total: 251
# 200
# Chunk195 is done! Total: 251
# 200
# Chunk193 is done! Total: 251
# 200
# Chunk194 is done! Total: 251
# 200
# Chunk187 is done! Total: 251200
#
# 200
# 200
# Chunk190 is done! Total: 251
# Chunk191 is done! Total: 251
# 200Chunk197 is done! Total: 251
#
# Chunk192 is done! Total: 251
# 200
# Chunk200 is done! Total: 251
# 200
# 200200
#
# Chunk205 is done! Total: 251
# Chunk199 is done! Total: 251Chunk203 is done! Total: 251200
#
#
# Chunk204 is done! Total: 251
# 200
# Chunk196 is done! Total: 251
# 200
# Chunk202 is done! Total: 251
# 200
# Chunk210 is done! Total: 251
# 200
# Chunk198 is done! Total: 251
# 200
# Chunk201 is done! Total: 251
# 200
# 200
# Chunk206 is done! Total: 251
# Chunk207 is done! Total: 251
# 200
# Chunk215 is done! Total: 251
# 200
# Chunk211 is done! Total: 251
# 200
# 200
# Chunk208 is done! Total: 251200
#
# Chunk217 is done! Total: 251
# Chunk209 is done! Total: 251
# 200
# 200
# Chunk221 is done! Total: 251
# 200
# Chunk212 is done! Total: 251
# Chunk213 is done! Total: 251
# 200
# 200Chunk224 is done! Total: 251
#
# 200
# 200Chunk219 is done! Total: 251Chunk218 is done! Total: 251
#
#
# Chunk216 is done! Total: 251
# 200
# Chunk226 is done! Total: 251
# 200
# Chunk214 is done! Total: 251
# 200
# Chunk228 is done! Total: 251
# 200200
#
# Chunk222 is done! Total: 251
# Chunk223 is done! Total: 251
# 200
# 200Chunk229 is done! Total: 251
#
# Chunk227 is done! Total: 251
# 200
# Chunk220 is done! Total: 251
# 200
# Chunk225 is done! Total: 251
# 200
# Chunk230 is done! Total: 251
# 200
# Chunk232 is done! Total: 251
# 200
# Chunk238 is done! Total: 251
# 200
# 200200
#
# Chunk244 is done! Total: 251
# Chunk241 is done! Total: 251
# 200
# Chunk234 is done! Total: 251
# 200Chunk233 is done! Total: 251
#
# Chunk236 is done! Total: 251
# 200
# Chunk239 is done! Total: 251
# 200
# Chunk242 is done! Total: 251
# 200
# 200Chunk249 is done! Total: 251
#
# 200
# 200200
#
# Chunk240 is done! Total: 251200
#
# Chunk237 is done! Total: 251
# Chunk231 is done! Total: 251
# Chunk235 is done! Total: 251
# Chunk245 is done! Total: 251
# 200
# Chunk243 is done! Total: 251
# 200
# Chunk248 is done! Total: 251
# 200
# 200
# Chunk246 is done! Total: 251
# Chunk247 is done! Total: 251
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||current range:2000 ~ 3000
#
#
# 2000 3000
# 200
# Chunk14 is done! Total: 251
# 200
# Chunk17 is done! Total: 251
# 200
# Chunk10 is done! Total: 251
# 200
# 200
# 200
# Chunk6 is done! Total: 251
# 200200200
#
# 200
# 200
#
# 200200
# 200200
#
#
# 200200200
#
# 200
#
# 200
# Chunk18 is done! Total: 251
# 200
# Chunk2 is done! Total: 251
# Chunk0 is done! Total: 251
# Chunk5 is done! Total: 251
# Chunk4 is done! Total: 251
# Chunk13 is done! Total: 251
# Chunk15 is done! Total: 251
# Chunk1 is done! Total: 251
# Chunk3 is done! Total: 251
# Chunk19 is done! Total: 251Chunk12 is done! Total: 251
#
# Chunk20 is done! Total: 251
# Chunk11 is done! Total: 251Chunk16 is done! Total: 251
#
# Chunk9 is done! Total: 251Chunk8 is done! Total: 251
#
# Chunk7 is done! Total: 251200
#
# Chunk21 is done! Total: 251
# 200
# Chunk22 is done! Total: 251
# 200
# Chunk23 is done! Total: 251
# 200
# Chunk42 is done! Total: 251
# 200
# 200
# Chunk26 is done! Total: 251
# Chunk40 is done! Total: 251200
#
# 200
# 200200
# Chunk31 is done! Total: 251
# Chunk33 is done! Total: 251200
#
#
# 200
# 200200Chunk24 is done! Total: 251Chunk25 is done! Total: 251
#
#
# 200
#
# 200200
# 200
# 200
# 200
#
# Chunk28 is done! Total: 251
# 200
# Chunk41 is done! Total: 251200
#
# 200
# Chunk27 is done! Total: 251
# 200
# Chunk30 is done! Total: 251
# Chunk32 is done! Total: 251
# Chunk44 is done! Total: 251Chunk37 is done! Total: 251
#
# Chunk39 is done! Total: 251
# Chunk34 is done! Total: 251
# Chunk35 is done! Total: 251
# Chunk43 is done! Total: 251
# Chunk36 is done! Total: 251
# Chunk29 is done! Total: 251Chunk38 is done! Total: 251
#
# 200
# Chunk45 is done! Total: 251
# 200
# Chunk51 is done! Total: 251200
#
# Chunk46 is done! Total: 251
# 200
# 200
# 200200
#
# Chunk54 is done! Total: 251
# Chunk55 is done! Total: 251200
#
# 200
# Chunk48 is done! Total: 251
# Chunk65 is done! Total: 251
# 200
# Chunk50 is done! Total: 251
# 200
# Chunk52 is done! Total: 251
# Chunk63 is done! Total: 251
# Chunk49 is done! Total: 251
# 200
# 200
# 200Chunk47 is done! Total: 251
# Chunk53 is done! Total: 251
#
# 200200
#
# 200
# Chunk57 is done! Total: 251
# Chunk58 is done! Total: 251
# Chunk62 is done! Total: 251
# Chunk59 is done! Total: 251
# 200
# Chunk56 is done! Total: 251
# 200
# Chunk60 is done! Total: 251
# 200
# 200
# Chunk64 is done! Total: 251
# Chunk61 is done! Total: 251
# 200
# Chunk67 is done! Total: 251
# 200
# Chunk66 is done! Total: 251
# 200
# Chunk68 is done! Total: 251
# 200
# Chunk71 is done! Total: 251
# 200
# Chunk78 is done! Total: 251
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# Chunk84 is done! Total: 251
# Chunk69 is done! Total: 251
# Chunk76 is done! Total: 251
# 200
# Chunk72 is done! Total: 251200
#
# 200200
#
# 200
# 200200
#
# 200
# Chunk75 is done! Total: 251200
# 200
#
# Chunk81 is done! Total: 251
# Chunk80 is done! Total: 251
# Chunk79 is done! Total: 251
# Chunk70 is done! Total: 251
# Chunk85 is done! Total: 251
# 200
# Chunk74 is done! Total: 251
# Chunk82 is done! Total: 251
# Chunk86 is done! Total: 251200
#
# Chunk87 is done! Total: 251
# 200
# Chunk83 is done! Total: 251
# Chunk77 is done! Total: 251
# Chunk88 is done! Total: 251Chunk89 is done! Total: 251
#
# Chunk90 is done! Total: 251
# Chunk73 is done! Total: 251
# 200
# Chunk91 is done! Total: 251
# 200
# 200
# Chunk94 is done! Total: 251
# Chunk96 is done! Total: 251
# 200
# 200
# Chunk92 is done! Total: 251
# Chunk95 is done! Total: 251200
#
# Chunk110 is done! Total: 251
# 200
# Chunk103 is done! Total: 251
# 200
# 200
# 200200
#
# Chunk93 is done! Total: 251
# Chunk101 is done! Total: 251
# 200
# 200Chunk108 is done! Total: 251200
#
#
# Chunk98 is done! Total: 251200
# Chunk105 is done! Total: 251
#
# 200
# 200200200
#
#
# 200
# Chunk109 is done! Total: 251Chunk99 is done! Total: 251
#
# Chunk106 is done! Total: 251
# 200
# 200200
#
# Chunk102 is done! Total: 251
# Chunk104 is done! Total: 251
# Chunk112 is done! Total: 251
# Chunk111 is done! Total: 251Chunk113 is done! Total: 251
#
# Chunk107 is done! Total: 251
# Chunk97 is done! Total: 251
# Chunk100 is done! Total: 251
# 200
# Chunk116 is done! Total: 251
# 200
# Chunk117 is done! Total: 251
# 200
# Chunk114 is done! Total: 251
# 200
# 200Chunk115 is done! Total: 251
#
# Chunk121 is done! Total: 251
# 200
# 200Chunk118 is done! Total: 251
#
# Chunk119 is done! Total: 251
# 200
# 200
# Chunk120 is done! Total: 251
# Chunk122 is done! Total: 251
# 200
# 200
# Chunk128 is done! Total: 251
# Chunk133 is done! Total: 251200
#
# 200
# 200
# 200
# Chunk123 is done! Total: 251
# Chunk126 is done! Total: 251
# Chunk125 is done! Total: 251
# Chunk129 is done! Total: 251
# 200
# 200
# 200
# 200
# 200200
# Chunk134 is done! Total: 251
#
# Chunk127 is done! Total: 251Chunk131 is done! Total: 251
#
# 200
# Chunk135 is done! Total: 251
# Chunk132 is done! Total: 251
# Chunk130 is done! Total: 251
# Chunk124 is done! Total: 251
# 200
# Chunk136 is done! Total: 251
# 200
# 200
# Chunk153 is done! Total: 251
# Chunk142 is done! Total: 251
# 200
# Chunk155 is done! Total: 251
# 200
# Chunk138 is done! Total: 251
# 200
# Chunk140 is done! Total: 251
# 200
# Chunk137 is done! Total: 251
# 200200
#
# Chunk141 is done! Total: 251200
#
# 200
# Chunk146 is done! Total: 251
# Chunk139 is done! Total: 251
# Chunk149 is done! Total: 251
# 200
# Chunk148 is done! Total: 251
# 200
# 200200
#
# 200
# Chunk150 is done! Total: 251Chunk145 is done! Total: 251
#
# 200
# Chunk154 is done! Total: 251
# Chunk144 is done! Total: 251
# 200Chunk156 is done! Total: 251
#
# Chunk151 is done! Total: 251200
#
# 200
# 200
# Chunk152 is done! Total: 251Chunk143 is done! Total: 251
#
# Chunk147 is done! Total: 251
# 200
# Chunk159 is done! Total: 251
# 200
# Chunk160 is done! Total: 251
# 200
# Chunk158 is done! Total: 251
# 200
# 200
# Chunk162 is done! Total: 251
# Chunk157 is done! Total: 251
# 200
# Chunk161 is done! Total: 251
# 200
# Chunk166 is done! Total: 251
# 200
# Chunk163 is done! Total: 251
# 200
# Chunk164 is done! Total: 251
# 200
# 200200
#
# 200Chunk167 is done! Total: 251
#
# 200
# Chunk178 is done! Total: 251Chunk165 is done! Total: 251
#
# Chunk177 is done! Total: 251Chunk172 is done! Total: 251
# 200
#
# 200
# Chunk169 is done! Total: 251200
# Chunk174 is done! Total: 251
#
# 200
# 200
# 200Chunk179 is done! Total: 251Chunk176 is done! Total: 251
# 200200
#
#
#
# 200200
#
# 200Chunk183 is done! Total: 251
#
# Chunk171 is done! Total: 251
# 200
# Chunk180 is done! Total: 251
# Chunk175 is done! Total: 251
# 200Chunk170 is done! Total: 251
#
# Chunk173 is done! Total: 251200
#
# Chunk168 is done! Total: 251Chunk182 is done! Total: 251
#
# Chunk184 is done! Total: 251
# Chunk181 is done! Total: 251
# 200
# Chunk186 is done! Total: 251
# 200
# Chunk190 is done! Total: 251
# 200
# Chunk187 is done! Total: 251
# 200
# Chunk193 is done! Total: 251
# 200
# Chunk192 is done! Total: 251
# 200
# Chunk185 is done! Total: 251
# 200
# Chunk188 is done! Total: 251
# 200
# Chunk201 is done! Total: 251
# 200
# Chunk203 is done! Total: 251200
#
# 200
# 200
# 200
# Chunk204 is done! Total: 251
# Chunk191 is done! Total: 251
# Chunk194 is done! Total: 251
# 200
# 200Chunk202 is done! Total: 251200
#
#
# 200
# 200200
#
# 200
# 200Chunk189 is done! Total: 251
#
# 200
# Chunk197 is done! Total: 251Chunk200 is done! Total: 251
#
# 200
# Chunk205 is done! Total: 251
# 200
# Chunk206 is done! Total: 251
# Chunk199 is done! Total: 251
# Chunk195 is done! Total: 251
# Chunk198 is done! Total: 251
# Chunk196 is done! Total: 251
# 200
# Chunk208 is done! Total: 251
# Chunk207 is done! Total: 251
# Chunk210 is done! Total: 251
# 200
# Chunk209 is done! Total: 251
# 200
# Chunk212 is done! Total: 251
# 200
# Chunk211 is done! Total: 251
# 200
# Chunk214 is done! Total: 251
# 200
# Chunk216 is done! Total: 251
# 200
# Chunk215 is done! Total: 251
# 200
# Chunk221 is done! Total: 251
# 200
# 200Chunk218 is done! Total: 251
#
# Chunk213 is done! Total: 251
# 200
# Chunk217 is done! Total: 251
# 200
# 200
# Chunk223 is done! Total: 251
# Chunk220 is done! Total: 251
# 200
# Chunk226 is done! Total: 251
# 200
# 200Chunk227 is done! Total: 251
#
# Chunk229 is done! Total: 251
# 200
# Chunk219 is done! Total: 251
# 200
# Chunk228 is done! Total: 251
# 200200
#
# 200
# Chunk224 is done! Total: 251
# 200
# Chunk231 is done! Total: 251
# Chunk222 is done! Total: 251
# 200Chunk225 is done! Total: 251
#
# 200
# 200
# Chunk230 is done! Total: 251
# Chunk232 is done! Total: 251
# Chunk235 is done! Total: 251
# 200
# Chunk234 is done! Total: 251
# 200200
#
# Chunk237 is done! Total: 251
# Chunk233 is done! Total: 251
# 200
# 200
# Chunk241 is done! Total: 251
# Chunk238 is done! Total: 251
# 200
# Chunk239 is done! Total: 251
# 200
# Chunk244 is done! Total: 251
# 200
# Chunk240 is done! Total: 251200
#
# 200
# 200200
#
# Chunk236 is done! Total: 251
# 200
# Chunk242 is done! Total: 251
# Chunk246 is done! Total: 251
# Chunk245 is done! Total: 251
# Chunk243 is done! Total: 251
# 200
# Chunk249 is done! Total: 251
# 200
# 200
# Chunk248 is done! Total: 251
# Chunk247 is done! Total: 251
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||current range:3000 ~ 4000
#
#
# 3000 4000
# 200
# Chunk16 is done! Total: 251
# 200
# 200Chunk4 is done! Total: 251
#
# 200Chunk3 is done! Total: 251
#
# Chunk10 is done! Total: 251
# 200200
#
# 200200
#
# 200
# 200Chunk18 is done! Total: 251
# 200200200
#
#
# 200
# 200200
#
# Chunk1 is done! Total: 251
#
# 200
# 200200
# 200
#
# Chunk12 is done! Total: 251
# 200
# Chunk11 is done! Total: 251
# Chunk2 is done! Total: 251
# Chunk5 is done! Total: 251Chunk19 is done! Total: 251
#
# Chunk20 is done! Total: 251
# Chunk17 is done! Total: 251
# Chunk0 is done! Total: 251
# Chunk13 is done! Total: 251
# Chunk14 is done! Total: 251
# 200
# Chunk7 is done! Total: 251
# Chunk8 is done! Total: 251
# Chunk6 is done! Total: 251
# Chunk9 is done! Total: 251
# Chunk15 is done! Total: 251
# Chunk21 is done! Total: 251
# 200
# Chunk23 is done! Total: 251
# 200
# Chunk22 is done! Total: 251
# 200
# Chunk24 is done! Total: 251
# 200
# Chunk36 is done! Total: 251
# 200
# Chunk28 is done! Total: 251
# 200
# Chunk32 is done! Total: 251
# 200
# 200
# Chunk33 is done! Total: 251
# 200Chunk25 is done! Total: 251
#
# Chunk41 is done! Total: 251
# 200
# Chunk38 is done! Total: 251
# 200
# 200Chunk29 is done! Total: 251
#
# Chunk30 is done! Total: 251
# 200
# 200200
#
# 200200
# 200
# 200Chunk26 is done! Total: 251
#
#
# 200200
#
# Chunk40 is done! Total: 251
# 200
# 200
# 200Chunk45 is done! Total: 251
#
# Chunk44 is done! Total: 251
# Chunk43 is done! Total: 251
# Chunk35 is done! Total: 251
# Chunk31 is done! Total: 251
# Chunk27 is done! Total: 251Chunk34 is done! Total: 251
#
# Chunk39 is done! Total: 251
# Chunk37 is done! Total: 251
# Chunk42 is done! Total: 251
# 200
# Chunk52 is done! Total: 251
# 200
# 200
# Chunk51 is done! Total: 251
# Chunk49 is done! Total: 251
# 200
# Chunk47 is done! Total: 251
# 200
# Chunk46 is done! Total: 251
# 200
# Chunk50 is done! Total: 251
# 200
# Chunk57 is done! Total: 251
# 200
# Chunk60 is done! Total: 251
# 200
# Chunk62 is done! Total: 251
# 200
# Chunk56 is done! Total: 251200
#
# 200Chunk48 is done! Total: 251
#
# 200
# 200Chunk65 is done! Total: 251
#
# Chunk59 is done! Total: 251200
#
# Chunk55 is done! Total: 251Chunk53 is done! Total: 251
#
# 200
# Chunk58 is done! Total: 251
# 200
# Chunk63 is done! Total: 251
# 200
# 200
# Chunk66 is done! Total: 251
# Chunk61 is done! Total: 251
# 200
# Chunk70 is done! Total: 251
# 200
# Chunk64 is done! Total: 251
# 200
# Chunk69 is done! Total: 251
# 200
# Chunk54 is done! Total: 251
# 200
# Chunk67 is done! Total: 251
# 200
# Chunk74 is done! Total: 251
# 200
# Chunk72 is done! Total: 251
# 200
# Chunk71 is done! Total: 251
# 200
# Chunk68 is done! Total: 251
# 200
# Chunk77 is done! Total: 251
# 200
# 200
# Chunk76 is done! Total: 251
# Chunk75 is done! Total: 251
# 200
# 200Chunk78 is done! Total: 251
#
# 200
# Chunk81 is done! Total: 251
# Chunk84 is done! Total: 251
# 200200
#
# 200
# 200
# Chunk85 is done! Total: 251
# Chunk88 is done! Total: 251
# Chunk73 is done! Total: 251
# Chunk80 is done! Total: 251
# 200
# Chunk86 is done! Total: 251
# 200
# Chunk79 is done! Total: 251
# 200
# 200
# Chunk93 is done! Total: 251
# 200
# Chunk89 is done! Total: 251
# 200
# Chunk92 is done! Total: 251
# Chunk87 is done! Total: 251
# 200
# 200Chunk82 is done! Total: 251
#
# Chunk95 is done! Total: 251
# 200
# Chunk96 is done! Total: 251
# 200
# Chunk91 is done! Total: 251
# 200
# Chunk90 is done! Total: 251
# 200
# Chunk83 is done! Total: 251
# 200
# Chunk94 is done! Total: 251
# 200
# Chunk102 is done! Total: 251
# 200
# 200Chunk97 is done! Total: 251
#
# 200200
#
# 200
# 200
# Chunk101 is done! Total: 251
# Chunk105 is done! Total: 251Chunk107 is done! Total: 251
#
# Chunk100 is done! Total: 251
# Chunk98 is done! Total: 251
# 200
# Chunk108 is done! Total: 251
# 200
# 200
# Chunk103 is done! Total: 251
# Chunk99 is done! Total: 251
# 200
# Chunk104 is done! Total: 251
# 200
# Chunk112 is done! Total: 251
# 200
# Chunk106 is done! Total: 251
# 200
# Chunk116 is done! Total: 251
# 200
# Chunk114 is done! Total: 251
# 200
# Chunk111 is done! Total: 251
# 200
# Chunk110 is done! Total: 251
# 200
# Chunk115 is done! Total: 251
# 200
# Chunk113 is done! Total: 251
# 200
# Chunk109 is done! Total: 251
# 200
# Chunk117 is done! Total: 251
# 200
# Chunk121 is done! Total: 251
# 200
# Chunk126 is done! Total: 251
# 200
# Chunk119 is done! Total: 251
# 200
# 200
# 200
# Chunk120 is done! Total: 251
# Chunk125 is done! Total: 251
# Chunk123 is done! Total: 251
# 200
# 200
# Chunk128 is done! Total: 251
# Chunk118 is done! Total: 251
# 200
# Chunk124 is done! Total: 251
# 200
# Chunk129 is done! Total: 251
# 200
# 200
# 200
# 200200
#
# 200
# Chunk136 is done! Total: 251
# 200
# Chunk127 is done! Total: 251
# 200
# Chunk122 is done! Total: 251Chunk130 is done! Total: 251
#
# Chunk134 is done! Total: 251
# Chunk131 is done! Total: 251Chunk133 is done! Total: 251
#
# Chunk132 is done! Total: 251
# 200
# Chunk135 is done! Total: 251
# 200
# Chunk142 is done! Total: 251
# 200
# Chunk139 is done! Total: 251
# 200
# Chunk147 is done! Total: 251
# 200
# Chunk143 is done! Total: 251
# 200
# Chunk144 is done! Total: 251
# 200
# Chunk146 is done! Total: 251
# 200
# Chunk137 is done! Total: 251
# 200
# Chunk140 is done! Total: 251
# 200
# Chunk145 is done! Total: 251
# 200
# Chunk138 is done! Total: 251
# 200
# Chunk141 is done! Total: 251
# 200
# Chunk155 is done! Total: 251
# 200
# Chunk158 is done! Total: 251
# 200
# Chunk148 is done! Total: 251
# 200
# Chunk152 is done! Total: 251200
#
# 200
# Chunk157 is done! Total: 251200
#
# 200
# 200Chunk150 is done! Total: 251Chunk159 is done! Total: 251
#
#
# Chunk149 is done! Total: 251
# Chunk156 is done! Total: 251
# 200
# 200
# 200200
#
# 200200
#
# Chunk154 is done! Total: 251Chunk151 is done! Total: 251
# 200
#
# 200
# Chunk161 is done! Total: 251
# Chunk162 is done! Total: 251
# Chunk168 is done! Total: 251
# 200Chunk167 is done! Total: 251
# 200
# Chunk160 is done! Total: 251
#
# 200
# Chunk153 is done! Total: 251
# Chunk166 is done! Total: 251
# Chunk163 is done! Total: 251Chunk165 is done! Total: 251
#
# 200
# Chunk170 is done! Total: 251
# 200
# Chunk164 is done! Total: 251
# 200
# Chunk169 is done! Total: 251
# 200
# Chunk171 is done! Total: 251
# 200
# Chunk172 is done! Total: 251
# 200
# Chunk175 is done! Total: 251
# 200
# 200Chunk182 is done! Total: 251
#
# Chunk187 is done! Total: 251
# 200200
#
# 200
# Chunk178 is done! Total: 251
# 200200Chunk180 is done! Total: 251
#
# 200Chunk174 is done! Total: 251
#
#
# 200
# Chunk179 is done! Total: 251
# 200
# 200
# 200
# Chunk176 is done! Total: 251Chunk184 is done! Total: 251Chunk181 is done! Total: 251
#
#
# 200
# 200
# 200
# Chunk173 is done! Total: 251200
#
# 200200
#
# Chunk185 is done! Total: 251
# 200
# Chunk191 is done! Total: 251
# Chunk177 is done! Total: 251Chunk189 is done! Total: 251
# Chunk183 is done! Total: 251
#
# Chunk188 is done! Total: 251
# Chunk190 is done! Total: 251
# Chunk186 is done! Total: 251Chunk192 is done! Total: 251
#
# 200
# Chunk193 is done! Total: 251
# 200
# 200Chunk195 is done! Total: 251
#
# Chunk194 is done! Total: 251
# 200
# Chunk197 is done! Total: 251
# 200
# Chunk196 is done! Total: 251
# 200
# 200
# Chunk204 is done! Total: 251200
#
# Chunk205 is done! Total: 251Chunk207 is done! Total: 251
#
# 200
# Chunk208 is done! Total: 251
# 200
# Chunk213 is done! Total: 251
# 200
# Chunk200 is done! Total: 251
# 200200
#
# Chunk201 is done! Total: 251
# 200
# 200
# Chunk211 is done! Total: 251
# Chunk206 is done! Total: 251
# Chunk198 is done! Total: 251
# 200
# 200
# Chunk215 is done! Total: 251
# Chunk210 is done! Total: 251
# 200
# Chunk199 is done! Total: 251
# 200
# 200
# Chunk214 is done! Total: 251
# 200
# 200
# Chunk209 is done! Total: 251Chunk202 is done! Total: 251
#
# Chunk212 is done! Total: 251
# 200
# Chunk217 is done! Total: 251
# 200
# Chunk203 is done! Total: 251
# 200
# Chunk216 is done! Total: 251
# 200
# Chunk222 is done! Total: 251
# 200
# Chunk220 is done! Total: 251
# 200
# Chunk221 is done! Total: 251
# 200
# Chunk218 is done! Total: 251
# 200
# Chunk234 is done! Total: 251
# 200
# Chunk227 is done! Total: 251
# 200
# Chunk219 is done! Total: 251
# 200
# Chunk224 is done! Total: 251
# 200
# Chunk226 is done! Total: 251200
#
# Chunk231 is done! Total: 251
# 200
# Chunk235 is done! Total: 251
# 200200
#
# 200
# Chunk223 is done! Total: 251
# Chunk228 is done! Total: 251
# 200
# 200
# 200
# 200
# Chunk225 is done! Total: 251200Chunk233 is done! Total: 251
#
#
# Chunk232 is done! Total: 251
# Chunk230 is done! Total: 251
# 200
# 200
# Chunk239 is done! Total: 251
# Chunk237 is done! Total: 251
# 200
# Chunk236 is done! Total: 251Chunk229 is done! Total: 251
#
# Chunk238 is done! Total: 251
# 200
# Chunk242 is done! Total: 251
# 200
# 200
# Chunk245 is done! Total: 251
# 200
# Chunk240 is done! Total: 251
# Chunk243 is done! Total: 251200
#
# Chunk244 is done! Total: 251
# 200
# Chunk241 is done! Total: 251
# 200
# Chunk247 is done! Total: 251
# 200
# Chunk249 is done! Total: 251
# 200
# Chunk246 is done! Total: 251200
#
# Chunk248 is done! Total: 251
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||current range:4000 ~ 5000
#
#
# 4000 5000
# 200
# Chunk0 is done! Total: 251
# 200
# Chunk16 is done! Total: 251
# 200
# 200200
#
# 200200200
# 200
#
#
# 200200
# 200200200
# Chunk11 is done! Total: 251
#
#
# 200200
#
#
# 200200200200
#
#
#
# 200
# Chunk8 is done! Total: 251
# Chunk17 is done! Total: 251
# Chunk3 is done! Total: 251
# 200
# Chunk9 is done! Total: 251
# Chunk14 is done! Total: 251
# Chunk12 is done! Total: 251
# Chunk6 is done! Total: 251
# Chunk2 is done! Total: 251
# Chunk7 is done! Total: 251
# Chunk18 is done! Total: 251
# Chunk19 is done! Total: 251
# Chunk21 is done! Total: 251
# Chunk4 is done! Total: 251
# Chunk1 is done! Total: 251
# Chunk15 is done! Total: 251Chunk10 is done! Total: 251Chunk5 is done! Total: 251
#
#
# Chunk20 is done! Total: 251
# Chunk13 is done! Total: 251
# 200
# Chunk22 is done! Total: 251
# 200
# Chunk25 is done! Total: 251
# 200
# Chunk26 is done! Total: 251
# 200
# Chunk24 is done! Total: 251
# 200
# Chunk34 is done! Total: 251
# 200
# Chunk37 is done! Total: 251
# 200
# Chunk28 is done! Total: 251
# 200
# 200
# 200Chunk30 is done! Total: 251
#
# Chunk23 is done! Total: 251200
#
# 200
# 200
# 200200
# 200
#
# 200
# 200Chunk33 is done! Total: 251
# 200
#
# 200
# 200
# 200
# 200
# Chunk32 is done! Total: 251
# 200
# 200
# 200Chunk40 is done! Total: 251
#
# Chunk29 is done! Total: 251
# Chunk42 is done! Total: 251
# Chunk39 is done! Total: 251
# Chunk46 is done! Total: 251Chunk38 is done! Total: 251
#
# Chunk27 is done! Total: 251
# Chunk44 is done! Total: 251Chunk31 is done! Total: 251
#
# Chunk35 is done! Total: 251
# Chunk43 is done! Total: 251Chunk36 is done! Total: 251
#
# Chunk41 is done! Total: 251
# Chunk45 is done! Total: 251
# Chunk47 is done! Total: 251
# 200
# Chunk48 is done! Total: 251
# 200
# Chunk51 is done! Total: 251
# 200
# Chunk50 is done! Total: 251
# 200
# Chunk58 is done! Total: 251
# 200
# Chunk56 is done! Total: 251
# 200
# Chunk49 is done! Total: 251
# 200
# Chunk57 is done! Total: 251
# 200200
#
# 200
# 200
# Chunk53 is done! Total: 251
# Chunk60 is done! Total: 251
# Chunk62 is done! Total: 251
# Chunk59 is done! Total: 251
# 200
# 200
# 200
# 200200
#
# 200
# 200Chunk65 is done! Total: 251
#
# 200200
#
# Chunk54 is done! Total: 251200
#
# Chunk67 is done! Total: 251
# Chunk69 is done! Total: 251200
#
# Chunk52 is done! Total: 251
# Chunk61 is done! Total: 251Chunk63 is done! Total: 251
#
# Chunk64 is done! Total: 251Chunk70 is done! Total: 251
#
# Chunk55 is done! Total: 251
# 200
# Chunk68 is done! Total: 251
# Chunk66 is done! Total: 251
# 200200
#
# Chunk73 is done! Total: 251
# Chunk72 is done! Total: 251
# 200
# Chunk71 is done! Total: 251
# 200
# Chunk78 is done! Total: 251
# 200
# Chunk74 is done! Total: 251
# 200200
#
# 200
# Chunk77 is done! Total: 251
# 200Chunk76 is done! Total: 251
#
# Chunk85 is done! Total: 251
# Chunk75 is done! Total: 251
# 200
# Chunk86 is done! Total: 251
# 200
# 200
# 200
# Chunk82 is done! Total: 251
# Chunk79 is done! Total: 251
# 200
# Chunk80 is done! Total: 251
# 200
# 200
# 200
# Chunk91 is done! Total: 251
# 200
# 200
# 200Chunk90 is done! Total: 251
# Chunk92 is done! Total: 251
# 200
#
# Chunk93 is done! Total: 251
# Chunk81 is done! Total: 251200
# 200
#
# Chunk87 is done! Total: 251
# 200
# 200
# Chunk83 is done! Total: 251Chunk88 is done! Total: 251
# Chunk94 is done! Total: 251
#
# Chunk89 is done! Total: 251
# Chunk95 is done! Total: 251
# Chunk84 is done! Total: 251
# 200
# Chunk96 is done! Total: 251
# 200
# Chunk99 is done! Total: 251
# 200
# Chunk112 is done! Total: 251
# 200
# Chunk98 is done! Total: 251
# 200
# Chunk101 is done! Total: 251
# 200
# 200
# 200
# Chunk106 is done! Total: 251200
#
# Chunk108 is done! Total: 251Chunk97 is done! Total: 251
# 200
#
# Chunk103 is done! Total: 251
# Chunk105 is done! Total: 251
# 200200
#
# Chunk100 is done! Total: 251Chunk104 is done! Total: 251
#
# 200
# 200
# Chunk111 is done! Total: 251
# 200
# Chunk102 is done! Total: 251
# 200
# Chunk116 is done! Total: 251
# 200200
#
# Chunk107 is done! Total: 251Chunk110 is done! Total: 251
#
# 200
# Chunk109 is done! Total: 251
# Chunk113 is done! Total: 251
# 200
# 200
# Chunk117 is done! Total: 251
# 200Chunk114 is done! Total: 251
#
# Chunk115 is done! Total: 251
# 200
# Chunk118 is done! Total: 251200
#
# Chunk119 is done! Total: 251
# 200
# 200200
#
# 200
# Chunk123 is done! Total: 251
# 200200
# 200
#
# Chunk120 is done! Total: 251
# 200Chunk121 is done! Total: 251
# Chunk125 is done! Total: 251
#
# 200
# 200Chunk122 is done! Total: 251
#
# 200
# 200200
# 200200
#
#
# Chunk130 is done! Total: 251200
#
# 200
# 200200
#
# Chunk132 is done! Total: 251
# Chunk127 is done! Total: 251
# Chunk126 is done! Total: 251200
#
# Chunk138 is done! Total: 251
# Chunk124 is done! Total: 251
# Chunk133 is done! Total: 251Chunk134 is done! Total: 251
#
# Chunk128 is done! Total: 251
# Chunk129 is done! Total: 251
# Chunk139 is done! Total: 251
# Chunk136 is done! Total: 251
# Chunk135 is done! Total: 251
# Chunk137 is done! Total: 251
# Chunk131 is done! Total: 251
# 200
# Chunk145 is done! Total: 251
# 200
# Chunk141 is done! Total: 251
# 200
# Chunk142 is done! Total: 251
# 200
# 200
# 200200
#
# 200
# 200
# Chunk148 is done! Total: 251
# Chunk147 is done! Total: 251
# Chunk151 is done! Total: 251
# 200
# Chunk140 is done! Total: 251
# 200Chunk156 is done! Total: 251
#
# 200Chunk150 is done! Total: 251
#
# Chunk155 is done! Total: 251
# Chunk143 is done! Total: 251
# Chunk153 is done! Total: 251
# 200
# Chunk157 is done! Total: 251
# 200
# 200
# 200200
#
# 200
# Chunk146 is done! Total: 251
# Chunk154 is done! Total: 251
# Chunk144 is done! Total: 251
# Chunk158 is done! Total: 251
# Chunk149 is done! Total: 251
# 200
# 200
# Chunk152 is done! Total: 251
# Chunk159 is done! Total: 251
# 200
# 200
# Chunk160 is done! Total: 251
# Chunk162 is done! Total: 251
# 200
# Chunk161 is done! Total: 251
# 200
# Chunk167 is done! Total: 251
# 200
# Chunk165 is done! Total: 251
# 200
# Chunk166 is done! Total: 251
# 200
# Chunk169 is done! Total: 251
# 200
# Chunk164 is done! Total: 251
# 200
# Chunk171 is done! Total: 251
# 200
# Chunk163 is done! Total: 251
# 200
# Chunk174 is done! Total: 251
# 200
# Chunk170 is done! Total: 251
# 200200
#
# 200
# Chunk176 is done! Total: 251
# Chunk168 is done! Total: 251
# Chunk180 is done! Total: 251
# 200
# Chunk177 is done! Total: 251
# 200
# Chunk175 is done! Total: 251
# 200
# Chunk172 is done! Total: 251
# 200
# 200
# 200200
#
# Chunk185 is done! Total: 251
# Chunk182 is done! Total: 251
# Chunk173 is done! Total: 251
# 200
# 200
# Chunk183 is done! Total: 251
# Chunk181 is done! Total: 251
# 200Chunk178 is done! Total: 251
#
# Chunk186 is done! Total: 251200
# 200
#
# Chunk187 is done! Total: 251Chunk179 is done! Total: 251
#
# 200
# Chunk188 is done! Total: 251
# 200
# Chunk184 is done! Total: 251
# 200
# 200
# Chunk190 is done! Total: 251
# Chunk191 is done! Total: 251
# 200
# 200
# Chunk194 is done! Total: 251
# 200Chunk192 is done! Total: 251
#
# Chunk189 is done! Total: 251
# 200
# Chunk197 is done! Total: 251
# 200
# Chunk196 is done! Total: 251
# 200
# Chunk205 is done! Total: 251
# 200
# Chunk195 is done! Total: 251
# 200
# Chunk193 is done! Total: 251
# 200
# 200Chunk210 is done! Total: 251
#
# Chunk199 is done! Total: 251
# 200
# Chunk201 is done! Total: 251
# 200
# 200200Chunk200 is done! Total: 251
#
#
# Chunk207 is done! Total: 251
# 200Chunk202 is done! Total: 251
#
# 200
# 200
# 200
# Chunk208 is done! Total: 251
# Chunk204 is done! Total: 251Chunk209 is done! Total: 251
#
# 200200
# Chunk206 is done! Total: 251
#
# Chunk198 is done! Total: 251200
# Chunk203 is done! Total: 251200
#
#
# 200
# Chunk212 is done! Total: 251Chunk218 is done! Total: 251
# Chunk213 is done! Total: 251
#
# 200
# Chunk211 is done! Total: 251
# 200
# Chunk220 is done! Total: 251
# 200
# 200
# 200
# Chunk217 is done! Total: 251
# 200Chunk216 is done! Total: 251
#
# Chunk219 is done! Total: 251
# Chunk215 is done! Total: 251
# 200
# Chunk214 is done! Total: 251
# 200
# Chunk221 is done! Total: 251
# 200
# Chunk224 is done! Total: 251
# 200
# 200200
#
# 200
# 200
# 200
# 200200
#
# 200
# 200
# 200
# Chunk227 is done! Total: 251200
#
# Chunk229 is done! Total: 251
# 200Chunk226 is done! Total: 251
#
# 200200
#
# 200200
#
# Chunk234 is done! Total: 251
# 200Chunk231 is done! Total: 251
#
# 200
# Chunk235 is done! Total: 251
# 200
# Chunk240 is done! Total: 251
# Chunk242 is done! Total: 251
# Chunk232 is done! Total: 251Chunk230 is done! Total: 251
# Chunk236 is done! Total: 251
#
# Chunk222 is done! Total: 251
# Chunk237 is done! Total: 251
# Chunk223 is done! Total: 251
# Chunk239 is done! Total: 251
# Chunk233 is done! Total: 251
# Chunk228 is done! Total: 251
# Chunk241 is done! Total: 251
# Chunk225 is done! Total: 251
# Chunk238 is done! Total: 251
# 200
# 200
# 200
# 200200
#
# Chunk244 is done! Total: 251
# Chunk249 is done! Total: 251
# Chunk245 is done! Total: 251
# Chunk243 is done! Total: 251
# Chunk248 is done! Total: 251
# 200
# Chunk246 is done! Total: 251
# 200
# Chunk247 is done! Total: 251
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||current range:5000 ~ 6000
#
#
# 5000 6000
# 200
# 200
# 200
# Chunk6 is done! Total: 251
# Chunk4 is done! Total: 251
# Chunk0 is done! Total: 251
# 200
# Chunk9 is done! Total: 251
# 200
# 200200200
#
#
# Chunk10 is done! Total: 251
# 200200
#
# 200
# 200Chunk5 is done! Total: 251
#
# 200200200Chunk2 is done! Total: 251200
#
#
#
# 200
#
# 200200
#
# 200
# Chunk1 is done! Total: 251Chunk3 is done! Total: 251
#
# Chunk16 is done! Total: 251
# Chunk18 is done! Total: 251
# 200
# Chunk7 is done! Total: 251
# 200
# Chunk14 is done! Total: 251
# Chunk22 is done! Total: 251
# Chunk15 is done! Total: 251Chunk19 is done! Total: 251
#
# Chunk20 is done! Total: 251
# Chunk12 is done! Total: 251Chunk13 is done! Total: 251
# 200
#
# Chunk8 is done! Total: 251Chunk11 is done! Total: 251
#
# Chunk17 is done! Total: 251
# Chunk21 is done! Total: 251
# 200
# Chunk23 is done! Total: 251
# 200
# Chunk24 is done! Total: 251
# 200
# Chunk27 is done! Total: 251
# 200
# Chunk26 is done! Total: 251
# 200
# Chunk36 is done! Total: 251
# 200
# Chunk25 is done! Total: 251
# 200
# 200
# 200
# 200200200
#
#
# 200
# 200
# 200
# Chunk32 is done! Total: 251
# 200
# 200
# 200
# 200
# 200
# 200Chunk38 is done! Total: 251
# 200200
#
#
# 200
# Chunk44 is done! Total: 251
# Chunk29 is done! Total: 251
# Chunk41 is done! Total: 251
# Chunk43 is done! Total: 251
# Chunk42 is done! Total: 251
# Chunk30 is done! Total: 251Chunk28 is done! Total: 251
#
# Chunk34 is done! Total: 251Chunk35 is done! Total: 251Chunk33 is done! Total: 251
#
#
# 200
# Chunk31 is done! Total: 251
# Chunk48 is done! Total: 251200
#
# Chunk39 is done! Total: 251Chunk37 is done! Total: 251Chunk47 is done! Total: 251
#
# Chunk40 is done! Total: 251
#
# Chunk45 is done! Total: 251Chunk46 is done! Total: 251
#
# 200
# Chunk50 is done! Total: 251
# 200
# Chunk49 is done! Total: 251
# 200
# Chunk51 is done! Total: 251
# 200
# Chunk52 is done! Total: 251
# 200
# Chunk53 is done! Total: 251
# 200
# Chunk56 is done! Total: 251
# 200
# Chunk59 is done! Total: 251
# 200
# 200
# 200200
# Chunk58 is done! Total: 251
#
# 200
# 200200200
# 200
#
# Chunk68 is done! Total: 251
#
# 200200
#
# 200
# 200
# 200Chunk66 is done! Total: 251
#
# 200
# Chunk55 is done! Total: 251
# Chunk64 is done! Total: 251
# Chunk60 is done! Total: 251
# Chunk67 is done! Total: 251
# Chunk62 is done! Total: 251
# 200
# Chunk54 is done! Total: 251
# 200
# Chunk70 is done! Total: 251
# Chunk69 is done! Total: 251Chunk57 is done! Total: 251
#
# Chunk71 is done! Total: 251
# Chunk61 is done! Total: 251
# Chunk73 is done! Total: 251
# Chunk65 is done! Total: 251Chunk63 is done! Total: 251
#
# 200
# Chunk72 is done! Total: 251
# 200
# Chunk74 is done! Total: 251200
#
# Chunk76 is done! Total: 251
# 200
# Chunk75 is done! Total: 251
# 200
# Chunk79 is done! Total: 251
# 200
# Chunk77 is done! Total: 251
# 200
# 200
# Chunk81 is done! Total: 251
# Chunk80 is done! Total: 251
# 200
# Chunk93 is done! Total: 251
# 200
# Chunk88 is done! Total: 251
# 200
# Chunk85 is done! Total: 251
# 200200
#
# 200
# 200200
#
# 200
# 200200
#
# Chunk78 is done! Total: 251
# Chunk91 is done! Total: 251
# 200Chunk86 is done! Total: 251
#
# Chunk90 is done! Total: 251Chunk82 is done! Total: 251
#
# Chunk92 is done! Total: 251
# Chunk89 is done! Total: 251
# Chunk87 is done! Total: 251200
#
# 200
# 200
# Chunk83 is done! Total: 251
# 200
# 200
# 200Chunk101 is done! Total: 251
#
# Chunk84 is done! Total: 251
# Chunk99 is done! Total: 251
# Chunk94 is done! Total: 251Chunk95 is done! Total: 251
#
# Chunk100 is done! Total: 251
# 200
# 200
# Chunk96 is done! Total: 251
# Chunk97 is done! Total: 251
# 200
# Chunk103 is done! Total: 251
# 200
# Chunk98 is done! Total: 251
# 200
# Chunk102 is done! Total: 251
# 200
# Chunk111 is done! Total: 251
# 200
# Chunk109 is done! Total: 251
# 200
# Chunk104 is done! Total: 251
# 200
# 200
# Chunk114 is done! Total: 251
# Chunk105 is done! Total: 251
# 200
# 200
# Chunk115 is done! Total: 251200200
#
#
# 200
# Chunk112 is done! Total: 251Chunk118 is done! Total: 251
#
# Chunk113 is done! Total: 251
# Chunk110 is done! Total: 251
# 200
# Chunk119 is done! Total: 251
# 200
# 200
# Chunk121 is done! Total: 251
# 200
# Chunk107 is done! Total: 251200200
#
#
# 200
# Chunk116 is done! Total: 251
# Chunk106 is done! Total: 251
# Chunk108 is done! Total: 251Chunk120 is done! Total: 251
#
# 200200
#
# Chunk123 is done! Total: 251Chunk117 is done! Total: 251
# 200
#
# Chunk122 is done! Total: 251
# 200
# Chunk128 is done! Total: 251
# 200
# Chunk124 is done! Total: 251
# 200200
#
# Chunk125 is done! Total: 251
# Chunk126 is done! Total: 251
# 200
# Chunk127 is done! Total: 251
# 200
# Chunk130 is done! Total: 251
# 200
# Chunk133 is done! Total: 251
# 200
# Chunk131 is done! Total: 251
# 200
# 200
# Chunk129 is done! Total: 251
# Chunk141 is done! Total: 251
# 200
# Chunk140 is done! Total: 251
# 200
# Chunk135 is done! Total: 251200
#
# 200
# Chunk137 is done! Total: 251
# 200
# Chunk142 is done! Total: 251Chunk139 is done! Total: 251
#
# 200
# Chunk134 is done! Total: 251
# 200
# Chunk143 is done! Total: 251200
#
# 200
# 200200Chunk138 is done! Total: 251
# 200
#
#
# 200
# Chunk136 is done! Total: 251200
#
# 200
# 200
# Chunk132 is done! Total: 251
# Chunk145 is done! Total: 251
# Chunk147 is done! Total: 251
# Chunk144 is done! Total: 251
# 200
# Chunk146 is done! Total: 251Chunk148 is done! Total: 251
#
# Chunk151 is done! Total: 251
# Chunk149 is done! Total: 251
# 200
# 200
# Chunk152 is done! Total: 251
# Chunk150 is done! Total: 251
# 200
# Chunk154 is done! Total: 251
# 200
# Chunk153 is done! Total: 251
# 200
# Chunk155 is done! Total: 251
# 200
# Chunk158 is done! Total: 251
# 200
# Chunk162 is done! Total: 251
# 200
# Chunk156 is done! Total: 251
# 200
# 200Chunk166 is done! Total: 251
#
# Chunk160 is done! Total: 251
# 200
# Chunk159 is done! Total: 251
# 200
# 200
# Chunk165 is done! Total: 251
# Chunk157 is done! Total: 251200
#
# Chunk161 is done! Total: 251
# 200
# 200
# Chunk167 is done! Total: 251
# 200
# Chunk172 is done! Total: 251
# Chunk163 is done! Total: 251
# 200
# 200
# Chunk170 is done! Total: 251200
#
# Chunk169 is done! Total: 251
# 200
# Chunk164 is done! Total: 251
# 200
# 200Chunk174 is done! Total: 251
#
# 200
# Chunk171 is done! Total: 251200Chunk168 is done! Total: 251
#
#
# Chunk176 is done! Total: 251
# 200Chunk173 is done! Total: 251
#
# Chunk181 is done! Total: 251
# 200
# Chunk177 is done! Total: 251
# 200
# Chunk179 is done! Total: 251200
#
# Chunk175 is done! Total: 251
# 200
# Chunk178 is done! Total: 251
# 200
# Chunk180 is done! Total: 251
# 200
# Chunk184 is done! Total: 251
# 200
# Chunk183 is done! Total: 251
# 200
# Chunk182 is done! Total: 251
# 200
# Chunk188 is done! Total: 251
# 200
# Chunk195 is done! Total: 251
# 200
# 200
# Chunk192 is done! Total: 251
# Chunk193 is done! Total: 251
# 200
# 200200Chunk191 is done! Total: 251
#
#
# 200
# 200
# Chunk186 is done! Total: 251
# Chunk187 is done! Total: 251
# 200
# Chunk189 is done! Total: 251
# 200
# Chunk185 is done! Total: 251
# 200
# 200
# Chunk190 is done! Total: 251
# 200
# Chunk194 is done! Total: 251
# Chunk197 is done! Total: 251200
#
# 200
# Chunk199 is done! Total: 251
# Chunk200 is done! Total: 251
# 200
# Chunk196 is done! Total: 251
# Chunk198 is done! Total: 251
# 200Chunk202 is done! Total: 251
#
# Chunk205 is done! Total: 251
# 200
# 200
# 200Chunk203 is done! Total: 251
#
# Chunk204 is done! Total: 251
# Chunk201 is done! Total: 251
# 200
# Chunk208 is done! Total: 251
# 200
# Chunk218 is done! Total: 251
# 200
# Chunk210 is done! Total: 251
# 200
# Chunk209 is done! Total: 251200
#
# Chunk212 is done! Total: 251
# 200
# Chunk207 is done! Total: 251
# 200
# Chunk206 is done! Total: 251
# 200
# 200
# Chunk214 is done! Total: 251Chunk213 is done! Total: 251
#
# 200200
#
# 200
# 200
# 200
# 200
# 200
# 200200
#
# Chunk220 is done! Total: 251
# Chunk221 is done! Total: 251
# 200200Chunk225 is done! Total: 251
# Chunk216 is done! Total: 251
#
#
# Chunk211 is done! Total: 251
# Chunk222 is done! Total: 251Chunk223 is done! Total: 251
#
# 200
# Chunk217 is done! Total: 251
# Chunk224 is done! Total: 251
# Chunk219 is done! Total: 251
# Chunk215 is done! Total: 251
# 200
# 200Chunk227 is done! Total: 251
#
# Chunk226 is done! Total: 251
# 200200
#
# Chunk229 is done! Total: 251
# Chunk231 is done! Total: 251
# Chunk228 is done! Total: 251
# 200
# Chunk232 is done! Total: 251
# 200
# 200
# Chunk234 is done! Total: 251
# Chunk233 is done! Total: 251
# 200
# Chunk230 is done! Total: 251
# 200
# Chunk248 is done! Total: 251
# 200
# Chunk246 is done! Total: 251
# 200200
#
# 200
# 200
# 200
# Chunk241 is done! Total: 251200
#
# 200
# 200
# 200
# Chunk239 is done! Total: 251
# 200
# 200200
#
# Chunk249 is done! Total: 251
# Chunk243 is done! Total: 251
# Chunk244 is done! Total: 251
# Chunk242 is done! Total: 251
# Chunk235 is done! Total: 251
# Chunk237 is done! Total: 251
# Chunk236 is done! Total: 251
# Chunk240 is done! Total: 251Chunk245 is done! Total: 251
#
# 200Chunk247 is done! Total: 251
#
# Chunk238 is done! Total: 251
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||current range:6000 ~ 7000
#
#
# 6000 7000
# 200
# 200Chunk0 is done! Total: 251
#
# Chunk7 is done! Total: 251
# 200
# Chunk1 is done! Total: 251
# 200
# Chunk4 is done! Total: 251
# 200
# Chunk10 is done! Total: 251
# 200
# 200Chunk6 is done! Total: 251
# 200
#
# 200
# 200200200Chunk5 is done! Total: 251200200200
#
#
#
# 200200
#
#
#
# 200
#
# 200
# 200
# 200
# Chunk17 is done! Total: 251
# Chunk19 is done! Total: 251Chunk3 is done! Total: 251
#
# 200
# Chunk12 is done! Total: 251
# Chunk13 is done! Total: 251
# Chunk11 is done! Total: 251
# Chunk20 is done! Total: 251
# Chunk15 is done! Total: 251
# Chunk16 is done! Total: 251Chunk2 is done! Total: 251
#
# Chunk14 is done! Total: 251
# 200
# Chunk9 is done! Total: 251
# Chunk22 is done! Total: 251
# Chunk8 is done! Total: 251Chunk21 is done! Total: 251
#
# Chunk18 is done! Total: 251
# 200

# %%
temp.to_excel(rf'C:\Users\FFR0103\Desktop\My files\WORK\Auto part\Secure Link\Output\result_2.xlsx')
# Out:
#              OriginalVIN                VIN  \
# 0      1GDL7T1JXWJ502644  1GDL7T1JXWJ502644
# 1      1T88N4C2341141378  1T88N4C2341141378
# 2      1GNEC16Z46J119298  1GNEC16Z46J119298
# 3      1FDSE35P16HA04016  1FDSE35P16HA04016
# 0      4UZABRCS38CZ24941  4UZABRCS38CZ24941
# 1      4DRBUAFP96B212587  4DRBUAFP96B212587
# 2      4UZABRDT4CCBM9262  4UZABRDT4CCBM9262
# 3      1BAAHCPA02F204434  1BAAHCPA02F204434
# 0      1BAKGCPA2DF294972  1BAKGCPA2DF294972
# 1      1BAKGCPH2EF300882  1BAKGCPH2EF300882
# 2      4UZABRFCXKCKD2635  4UZABRFCXKCKD2635
# 3           SSL000158000       SSL000158000
# 0      1GDHG35U561207168  1GDHG35U561207168
# 1      1GNFC16058J233416  1GNFC16058J233416
# 2      1BAKGCKH76F234693  1BAKGCKH76F234693
# 3      4DRBUSKN2DB306818  4DRBUSKN2DB306818
# 0      1FDSE35P64HA88279  1FDSE35P64HA88279
# 1      4DRBWAANXHB470894  4DRBWAANXHB470894
# 2      1GB6G3AG1A1156938  1GB6G3AG1A1156938
# 3      1GB9G5AG6A1165238  1GB9G5AG6A1165238
# 0      4DRBUC8P9GB218772  4DRBUC8P9GB218772
# 1      4DRBUC8N1LB853574  4DRBUC8N1LB853574
# 2      1T88U4E23D1155388  1T88U4E23D1155388
# 3      4DRBUAFPX6B261216  4DRBUAFPX6B261216
# 0      1M8PDMPA43P055623  1M8PDMPA43P055623
# 1      4UZ6CJAA1WC961370  4UZ6CJAA1WC961370
# 2      1GBHG31F5W1065310  1GBHG31F5W1065310
# 3      1BAKGCPA1DF294753  1BAKGCPA1DF294753
# 0   4UZABRDT6ACAN9723ADJ  4UZABRDT6ACAN9723
# 1      4UZABRCS88CZ30850  4UZABRCS88CZ30850
# ..                   ...                ...
# 2      1GB6G5BL7E1213611  1GB6G5BL7E1213611
# 3          1DW1913L0174C      1DW1913L0174C
# 0      1HVBBABN2YH305430  1HVBBABN2YH305430
# 1      1BAKGCBA7FF314739  1BAKGCBA7FF314739
# 2      4UZABRDT79CAH1225  4UZABRDT79CAH1225
# 3      4DRBUC8NXHB500290  4DRBUC8NXHB500290
# 0      4UZAAXBV01CJ18970  4UZAAXBV01CJ18970
# 1      1FTDS3ELXCDA43632  1FTDS3ELXCDA43632
# 2      2G1WT57N691137759  2G1WT57N691137759
# 3      4UZABRFC4JCJT6633  4UZABRFC4JCJT6633
# 0      1HVBBAAP3TH288178  1HVBBAAP3TH288178
# 1      4UZAAXAK33CL68214  4UZAAXAK33CL68214
# 2      1GNDV23WX8D105736  1GNDV23WX8D105736
# 3      4DRBUC8P9JB096194  4DRBUC8P9JB096194
# 0      4DRBUAAN6EB486804  4DRBUAAN6EB486804
# 1      4UZABRDT6BCAU4205  4UZABRDT6BCAU4205
# 2      1T88P4E2XB1138558  1T88P4E2XB1138558
# 3      1FMNE31L91HA14320  1FMNE31L91HA14320
# 0      1GBHG31C391153606  1GBHG31C391153606
# 1      4DRBUP1N6HB793770  4DRBUP1N6HB793770
# 2      1HVBBNMPONH419234  1HVBBNMPONH419234
# 3      1BABFCPA6EF296300  1BABFCPA6EF296300
# 0      4UZAAXALX1CH63872  4UZAAXALX1CH63872
# 1      4UZABRCS68CZ41622  4UZABRCS68CZ41622
# 2      4DRBUC8NXLB856859  4DRBUC8NXLB856859
# 3      1T88P4E23B1138580  1T88P4E23B1138580
# 0      4DRBRABM84B965473  4DRBRABM84B965473
# 1      4UZAAXDC45CU85257  4UZAAXDC45CU85257
# 2      4UZABRDT5ACAN9731  4UZABRDT5ACAN9731
# 3      1GB3G3BG5E1147022  1GB3G3BG5E1147022
#
#                                             BodyClass                    Make  \
# 0                 Incomplete - Commercial Bus Chassis                     GMC
# 1                                    Bus - School Bus            THOMAS BUILT
# 2   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...               CHEVROLET
# 3                                Incomplete - Cutaway                    FORD
# 0                     Incomplete - School Bus Chassis            FREIGHTLINER
# 1                                    Bus - School Bus                      IC
# 2                     Incomplete - School Bus Chassis            FREIGHTLINER
# 3                                                                   BLUE BIRD
# 0                     Incomplete - School Bus Chassis               BLUE BIRD
# 1                     Incomplete - School Bus Chassis               BLUE BIRD
# 2                     Incomplete - School Bus Chassis            FREIGHTLINER
# 3
# 0                                                 Van                     GMC
# 1   Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...               CHEVROLET
# 2                     Incomplete - School Bus Chassis               BLUE BIRD
# 3                                    Bus - School Bus                      IC
# 0                                Incomplete - Cutaway                    FORD
# 1                                    Bus - School Bus                      IC
# 2                                Incomplete - Cutaway               CHEVROLET
# 3                                Incomplete - Cutaway               CHEVROLET
# 0                                    Bus - School Bus                      IC
# 1                                    Bus - School Bus                      IC
# 2                                    Bus - School Bus            THOMAS BUILT
# 3                                    Bus - School Bus                      IC
# 0                                                 Bus  MOTOR COACH INDUSTRIES
# 1                                    Bus - School Bus            FREIGHTLINER
# 2                                Incomplete - Cutaway               CHEVROLET
# 3                     Incomplete - School Bus Chassis               BLUE BIRD
# 0                     Incomplete - School Bus Chassis            FREIGHTLINER
# 1                     Incomplete - School Bus Chassis            FREIGHTLINER
# ..                                                ...                     ...
# 2                                Incomplete - Cutaway               CHEVROLET
# 3                                             Trailer      STOUGHTON TRAILERS
# 0                     Incomplete - School Bus Chassis           INTERNATIONAL
# 1                     Incomplete - School Bus Chassis               BLUE BIRD
# 2                     Incomplete - School Bus Chassis            FREIGHTLINER
# 3                                    Bus - School Bus                      IC
# 0                     Incomplete - School Bus Chassis            FREIGHTLINER
# 1                                                 Van                    FORD
# 2                                        Sedan/Saloon               CHEVROLET
# 3                     Incomplete - School Bus Chassis            FREIGHTLINER
# 0                     Incomplete - School Bus Chassis           INTERNATIONAL
# 1                     Incomplete - School Bus Chassis            FREIGHTLINER
# 2                                                 Van               CHEVROLET
# 3                                    Bus - School Bus                      IC
# 0                                    Bus - School Bus                      IC
# 1                     Incomplete - School Bus Chassis            FREIGHTLINER
# 2                                    Bus - School Bus            THOMAS BUILT
# 3                                                 Van                    FORD
# 0                                Incomplete - Cutaway               CHEVROLET
# 1                                    Bus - School Bus                      IC
# 2                     Incomplete - School Bus Chassis           INTERNATIONAL
# 3                                                 Bus               BLUE BIRD
# 0                     Incomplete - School Bus Chassis            FREIGHTLINER
# 1                     Incomplete - School Bus Chassis            FREIGHTLINER
# 2                                    Bus - School Bus                      IC
# 3                                    Bus - School Bus            THOMAS BUILT
# 0                                    Bus - School Bus           INTERNATIONAL
# 1                     Incomplete - School Bus Chassis            FREIGHTLINER
# 2                     Incomplete - School Bus Chassis            FREIGHTLINER
# 3                                Incomplete - Cutaway               CHEVROLET
#
#                          Manufacturer                      Model ModelYear  \
# 0                  GENERAL MOTORS LLC                         B7      1998
# 1             THOMAS BUILT BUSES, INC      MVP-EF (Engine Front)      2004
# 2                  GENERAL MOTORS LLC                   Suburban      2006
# 3             FORD MOTOR COMPANY, USA                      E-350      2006
# 0   FREIGHTLINER CUSTOM CHASSIS CORP.            B2 Bus Chassis       2008
# 1                         IC BUS, LLC                      PB105      2006
# 2   FREIGHTLINER CUSTOM CHASSIS CORP.            B2 Bus Chassis       2012
# 3              BLUE BIRD BODY COMPANY                                 2002
# 0              BLUE BIRD BODY COMPANY            BB Conventional      2013
# 1              BLUE BIRD BODY COMPANY            BB Conventional      2014
# 2   FREIGHTLINER CUSTOM CHASSIS CORP.            B2 Bus Chassis       2019
# 3
# 0                  GENERAL MOTORS LLC                     Savana      2006
# 1                  GENERAL MOTORS LLC                   Suburban      2008
# 2              BLUE BIRD BODY COMPANY            BB Conventional      2006
# 3                         IC BUS, LLC                      PB105      2013
# 0             FORD MOTOR COMPANY, USA                      E-350      2004
# 1                         IC BUS, LLC                      PB305      2017
# 2                  GENERAL MOTORS LLC                    Express      2010
# 3                  GENERAL MOTORS LLC                    Express      2010
# 0                         IC BUS, LLC                      PB105      2016
# 1                         IC BUS, LLC                      PB105      2020
# 2             THOMAS BUILT BUSES, INC      MVP-EF (Engine Front)      2013
# 3                         IC BUS, LLC                      PB105      2006
# 0        MOTOR COACH INDUSTRIES, INC.     102DL3 Intercity/D4500      2003
# 1   FREIGHTLINER CUSTOM CHASSIS CORP.              FS 65 Chassis      1998
# 2                  GENERAL MOTORS LLC                    Express      1998
# 3              BLUE BIRD BODY COMPANY            BB Conventional      2013
# 0   FREIGHTLINER CUSTOM CHASSIS CORP.            B2 Bus Chassis       2010
# 1   FREIGHTLINER CUSTOM CHASSIS CORP.            B2 Bus Chassis       2008
# ..                                ...                        ...       ...
# 2                  GENERAL MOTORS LLC                    Express      2014
# 3            STOUGHTON TRAILERS, INC.         Stoughton trailers      2001
# 0                      NAVISTAR, INC.                       3800      2000
# 1              BLUE BIRD BODY COMPANY            BB Conventional      2015
# 2   FREIGHTLINER CUSTOM CHASSIS CORP.            B2 Bus Chassis       2009
# 3                         IC BUS, LLC                      PB105      2017
# 0   FREIGHTLINER CUSTOM CHASSIS CORP.              FS 65 Chassis      2001
# 1             FORD MOTOR COMPANY, USA                      E-350      2012
# 2                  GENERAL MOTORS LLC                     Impala      2009
# 3   FREIGHTLINER CUSTOM CHASSIS CORP.            B2 Bus Chassis       2018
# 0                      NAVISTAR, INC.                       3800      1996
# 1   FREIGHTLINER CUSTOM CHASSIS CORP.              FS 65 Chassis      2003
# 2                  GENERAL MOTORS LLC                   Uplander      2008
# 3                         IC BUS, LLC                      PB105      2018
# 0                         IC BUS, LLC                      PB105      2014
# 1   FREIGHTLINER CUSTOM CHASSIS CORP.            B2 Bus Chassis       2011
# 2             THOMAS BUILT BUSES, INC      MVP-EF (Engine Front)      2011
# 3             FORD MOTOR COMPANY, USA                      E-350      2001
# 0                  GENERAL MOTORS LLC                    Express      2009
# 1                         IC BUS, LLC                      PB105      2017
# 2                      NAVISTAR, INC.                       3800      1992
# 3              BLUE BIRD BODY COMPANY  All American / All Canada      2014
# 0   FREIGHTLINER CUSTOM CHASSIS CORP.              FS 65 Chassis      2001
# 1   FREIGHTLINER CUSTOM CHASSIS CORP.            B2 Bus Chassis       2008
# 2                         IC BUS, LLC                      PB105      2020
# 3             THOMAS BUILT BUSES, INC      MVP-EF (Engine Front)      2011
# 0                         IC BUS, LLC                     3000IC      2004
# 1   FREIGHTLINER CUSTOM CHASSIS CORP.              FS 65 Chassis      2005
# 2   FREIGHTLINER CUSTOM CHASSIS CORP.            B2 Bus Chassis       2010
# 3                  GENERAL MOTORS LLC                    Express      2014
#
#                          Series              Trim  \
# 0                                    Cowl Chassis
# 1             120 (12 sections)
# 2                  1500 1/2 ton
# 3                     Econoline
# 0
# 1                            CE
# 2
# 3                     3401-3502
# 0                     3109-3400      Front Engine
# 1                     3109-3400      Front Engine
# 2
# 3
# 0                                    3500 (1 ton)
# 1                       1/2 Ton                LS
# 2                     3109-3400      Front Engine
# 3                            CE
# 0                     Econoline
# 1                            RE
# 2                          3500           Cutaway
# 3                          4500           Cutaway
# 0                            CE
# 1                            CE
# 2
# 3                            CE
# 0                           MCI
# 1
# 2                                   1 ton nominal
# 3                     3109-3400      Front Engine
# 0
# 1
# ..                          ...               ...
# 2                          4500           Cutaway
# 3
# 0   FBC Forward control chassis
# 1                     3109-3400      Front Engine
# 2
# 3                            CE
# 0
# 1            Econoline/E-series
# 2                      1LT 3.5L
# 3
# 0   FBC Forward control chassis
# 1
# 2                       1/2 Ton       LS APV, EWB
# 3                            CE
# 0                            CE
# 1
# 2        121 (12 sections +10")
# 3                           XLT  Super Duty Wagon
# 0                          3500
# 1                            CE
# 2   FBC Forward control chassis
# 3                     3007-3108      Front Engine
# 0
# 1
# 2                            CE
# 3        121 (12 sections +10")
# 0
# 1
# 2
# 3                          3500           Cutaway
#
#                              VehicleType       SuggestedVIN  \
# 0                     INCOMPLETE VEHICLE
# 1                                    BUS
# 2   MULTIPURPOSE PASSENGER VEHICLE (MPV)
# 3                     INCOMPLETE VEHICLE
# 0                     INCOMPLETE VEHICLE
# 1                                    BUS
# 2                     INCOMPLETE VEHICLE
# 3                                    BUS  1BA!HCPA02F204434
# 0                                    BUS
# 1                                    BUS
# 2                     INCOMPLETE VEHICLE
# 3
# 0                     INCOMPLETE VEHICLE
# 1   MULTIPURPOSE PASSENGER VEHICLE (MPV)
# 2                                    BUS
# 3                                    BUS
# 0                     INCOMPLETE VEHICLE
# 1                                    BUS
# 2                     INCOMPLETE VEHICLE
# 3                     INCOMPLETE VEHICLE
# 0                                    BUS
# 1                                    BUS
# 2                                    BUS  1T88!4E23D1155388
# 3                                    BUS
# 0                                    BUS
# 1                     INCOMPLETE VEHICLE
# 2                     INCOMPLETE VEHICLE
# 3                                    BUS
# 0                     INCOMPLETE VEHICLE
# 1                     INCOMPLETE VEHICLE
# ..                                   ...                ...
# 2                     INCOMPLETE VEHICLE
# 3                                TRAILER     1DW1!13!01!4C
# 0                     INCOMPLETE VEHICLE
# 1                                    BUS
# 2                     INCOMPLETE VEHICLE
# 3                                    BUS
# 0                     INCOMPLETE VEHICLE
# 1                                 TRUCK
# 2                          PASSENGER CAR
# 3                     INCOMPLETE VEHICLE
# 0                     INCOMPLETE VEHICLE
# 1                     INCOMPLETE VEHICLE
# 2   MULTIPURPOSE PASSENGER VEHICLE (MPV)
# 3                                    BUS
# 0                                    BUS
# 1                     INCOMPLETE VEHICLE
# 2                                    BUS
# 3   MULTIPURPOSE PASSENGER VEHICLE (MPV)  1FMNE31L91HA14320
# 0                     INCOMPLETE VEHICLE
# 1                                    BUS
# 2                     INCOMPLETE VEHICLE
# 3                                    BUS
# 0                     INCOMPLETE VEHICLE
# 1                     INCOMPLETE VEHICLE
# 2                                    BUS
# 3                                    BUS
# 0                                    BUS
# 1                     INCOMPLETE VEHICLE
# 2                     INCOMPLETE VEHICLE
# 3                     INCOMPLETE VEHICLE
#
#                                             ErrorText
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   1 - Check Digit (9th position) does not calcul...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   3 - VIN corrected, error in one position (assu...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   6 - Incomplete VIN; 7 - Manufacturer is not re...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# 2   4 - VIN corrected, error in one position only ...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# ..                                                ...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   5 - VIN has errors in few positions; 6 - Incom...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   1 - Check Digit (9th position) does not calcul...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# 2   1 - Check Digit (9th position) does not calcul...
# 3   1 - Check Digit (9th position) does not calcul...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
#
# [3000 rows x 12 columns]

# %%
data_5

# %%
process_5.split_to_Chunk(4)['Chunk12']

# %%
import requests
import json
for i in range(6000):
    url = "https://vpic.nhtsa.dot.gov/api/vehicles/DecodeVINValuesBatch/"
    post_fields = {
        "format": "json",
        "data": process_5.split_to_Chunk(4)['Chunk144'],
    }
    r = requests.post(url, data=post_fields)
    try:
        result = json.loads(r.text)
    except:
        print('4', '\n', r.text)
    print(i,r.status_code)
# df = pd.DataFrame(result["Results"])[
#     [
#         "VIN",
#         "BodyClass",
#         "Make",
#         "Manufacturer",
#         "Model",
#         "ModelYear",
#         "Series",
#         "Trim",
#         "VehicleType",
#         "SuggestedVIN",
#         "ErrorText",
#     ]
# ]
# df.insert(
#     0,
#     "OriginalVIN",
#     pd.Series(self.split_to_Chunk(4)['Chunk12'].split(";")),
# )


# df = pd.DataFrame(r.text["Results"])[
#     [
#         "VIN",
#         "BodyClass",
#         "Make",
#         "Manufacturer",
#         "Model",
#         "ModelYear",
#         "Series",
#         "Trim",
#         "VehicleType",
#         "SuggestedVIN",
#         "ErrorText",
#     ]
# ]
# df
# Out:
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307194&#46;499feb76
# </BODY>
# </HTML>
#
# 0 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307194&#46;499febc2
# </BODY>
# </HTML>
#
# 1 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307194&#46;499fec0a
# </BODY>
# </HTML>
#
# 2 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307194&#46;499fec51
# </BODY>
# </HTML>
#
# 3 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307194&#46;499feca7
# </BODY>
# </HTML>
#
# 4 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307194&#46;499fed36
# </BODY>
# </HTML>
#
# 5 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307194&#46;499fed7c
# </BODY>
# </HTML>
#
# 6 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307194&#46;499fee35
# </BODY>
# </HTML>
#
# 7 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307194&#46;499fee6d
# </BODY>
# </HTML>
#
# 8 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307194&#46;499feea8
# </BODY>
# </HTML>
#
# 9 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307194&#46;499fef16
# </BODY>
# </HTML>
#
# 10 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307194&#46;499fef57
# </BODY>
# </HTML>
#
# 11 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307194&#46;499fef9a
# </BODY>
# </HTML>
#
# 12 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307194&#46;499fefe5
# </BODY>
# </HTML>
#
# 13 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307194&#46;499ff038
# </BODY>
# </HTML>
#
# 14 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307194&#46;499ff0a6
# </BODY>
# </HTML>
#
# 15 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307195&#46;499ff107
# </BODY>
# </HTML>
#
# 16 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307195&#46;499ff174
# </BODY>
# </HTML>
#
# 17 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307195&#46;499ff1f9
# </BODY>
# </HTML>
#
# 18 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307195&#46;499ff26b
# </BODY>
# </HTML>
#
# 19 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307195&#46;499ff2b0
# </BODY>
# </HTML>
#
# 20 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307195&#46;499ff302
# </BODY>
# </HTML>
#
# 21 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307195&#46;499ff34a
# </BODY>
# </HTML>
#
# 22 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307195&#46;499ff3df
# </BODY>
# </HTML>
#
# 23 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307195&#46;499ff444
# </BODY>
# </HTML>
#
# 24 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307195&#46;499ff48e
# </BODY>
# </HTML>
#
# 25 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307195&#46;499ff508
# </BODY>
# </HTML>
#
# 26 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307195&#46;499ff557
# </BODY>
# </HTML>
#
# 27 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307195&#46;499ff5bf
# </BODY>
# </HTML>
#
# 28 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307195&#46;499ff638
# </BODY>
# </HTML>
#
# 29 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307195&#46;499ff69d
# </BODY>
# </HTML>
#
# 30 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307195&#46;499ff6ea
# </BODY>
# </HTML>
#
# 31 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307196&#46;499ff734
# </BODY>
# </HTML>
#
# 32 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307196&#46;499ff786
# </BODY>
# </HTML>
#
# 33 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307196&#46;499ff7e2
# </BODY>
# </HTML>
#
# 34 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307196&#46;499ff81e
# </BODY>
# </HTML>
#
# 35 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307196&#46;499ff856
# </BODY>
# </HTML>
#
# 36 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307196&#46;499ff89d
# </BODY>
# </HTML>
#
# 37 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307196&#46;499ff8de
# </BODY>
# </HTML>
#
# 38 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307196&#46;499ff92a
# </BODY>
# </HTML>
#
# 39 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307196&#46;499ff979
# </BODY>
# </HTML>
#
# 40 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307196&#46;499ff9c6
# </BODY>
# </HTML>
#
# 41 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307196&#46;499ffa31
# </BODY>
# </HTML>
#
# 42 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307196&#46;499ffa82
# </BODY>
# </HTML>
#
# 43 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307196&#46;499ffad2
# </BODY>
# </HTML>
#
# 44 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307196&#46;499ffb2f
# </BODY>
# </HTML>
#
# 45 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307196&#46;499ffb9e
# </BODY>
# </HTML>
#
# 46 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307196&#46;499ffc12
# </BODY>
# </HTML>
#
# 47 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307196&#46;499ffc52
# </BODY>
# </HTML>
#
# 48 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307196&#46;499ffca5
# </BODY>
# </HTML>
#
# 49 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307197&#46;499ffce1
# </BODY>
# </HTML>
#
# 50 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307197&#46;499ffd2f
# </BODY>
# </HTML>
#
# 51 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307197&#46;499ffd91
# </BODY>
# </HTML>
#
# 52 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307197&#46;499ffde3
# </BODY>
# </HTML>
#
# 53 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307197&#46;499ffe1a
# </BODY>
# </HTML>
#
# 54 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307197&#46;499ffe61
# </BODY>
# </HTML>
#
# 55 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307197&#46;499ffeb4
# </BODY>
# </HTML>
#
# 56 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307197&#46;499fff01
# </BODY>
# </HTML>
#
# 57 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307197&#46;499fff5e
# </BODY>
# </HTML>
#
# 58 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307197&#46;499fff99
# </BODY>
# </HTML>
#
# 59 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307197&#46;499fffde
# </BODY>
# </HTML>
#
# 60 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307197&#46;49a0001a
# </BODY>
# </HTML>
#
# 61 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307197&#46;49a0007f
# </BODY>
# </HTML>
#
# 62 403
# 4
#  <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;vpic&#46;nhtsa&#46;dot&#46;gov&#47;api&#47;vehicles&#47;DecodeVINValuesBatch&#47;" on this server.<P>
# Reference&#32;&#35;18&#46;87e54d17&#46;1579307197&#46;49a000d4
# </BODY>
# </HTML>
#
# 63 403
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-37e8ff16fbb6> in <module>
#       7         "data": process_5.split_to_Chunk(4)['Chunk144'],
#       8     }
# ----> 9     r = requests.post(url, data=post_fields)
#      10     try:
#      11         result = json.loads(r.text)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     114     """
#     115
# --> 116     return request('post', url, data=data, json=json, **kwargs)
#     117
#     118
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     299     def connect(self):
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#     303
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     157         try:
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#     161         except SocketTimeout as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      68             if source_address:
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#      72
#
# KeyboardInterrupt:
