# %%
from CleanVIN import ValidationProcess, Col_to_str
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\FFR0103\Desktop\My files\WORK\Auto part\Secure Link\Source\API\VINs to validate.xlsx')
df
# Out:
#                         VIN  RowID
# 0         1FDSE37F6WHB46480      1
# 1         1HVBBAAN9TH295537      2
# 2         1GNFG154X81173240      3
# 3         1HVBBABN2WH568336      4
# 4         1GBJG31K491142168      5
# 5         1HVBBAAN44H673734      6
# 6         1GB3GRBG0G1305627      7
# 7         1BAKGCSA8JF345393      8
# 8         1GBJG31F821189664      9
# 9         4UZABRFC1JCJT6587     10
# 10        1FTNS24263HA11260     11
# 11        1BAKDCKH05F226071     12
# 12        4DRBVAAP25A986852     13
# 13        1GB6G5BL9F1278784     14
# 14        1FD2E35L18DB33252     15
# 15        2C7WDGBG4JR303729     16
# 16             SSL000273000     17
# 17        1GBHG31Y8SF226554     18
# 18        1BAKGCKA69F257650     19
# 19        4DRBUSKN0AB236232     20
# 20        4UZABRDT6CCBP2493     21
# 21        1FTWF3BR1AEA75252     22
# 22        4DRBRAAN74B968133     23
# 23        4UZABRFC5JCJT6656     24
# 24             HF0000063000     25
# 25        1FDWE35F13HB13869     26
# 26        1GDHG31Y3SF552818     27
# 27        4UZABRDU5BCAU5032     28
# 28        1HVBBABP4XH201540     29
# 29        1T75L3B2XS1139050     30
# ...                     ...    ...
# 46867     4UZABRDT08CZ63901  46869
# 46868     4DRBUAFP16A988220  46870
# 46869     1GB6GUBGXH1194747  46871
# 46870     4UZABRDT8HCHS4924  46872
# 46871               L3BNR0N  46873
# 46872     1BAAHCPA02F205065  46874
# 46873            CAC84301S7  46875
# 46874     1T88P4E22B1138568  46876
# 46875  4UZABRDT0ACAR2149ADJ  46877
# 46876     1T7YU4E27B1135713  46878
# 46877     JTDZN3EU3HJ072126  46879
# 46878     4UZABRDT5DCBZ7449  46880
# 46879     1D4GP25R57B187511  46881
# 46880     2C4RDGBG2GR139996  46882
# 46881     1GBHG31C191155175  46883
# 46882     1T88N3B27X1068772  46884
# 46883     4DRBUAAP5AB142313  46885
# 46884     4DRBUC8P2GB221657  46886
# 46885     4UZAAXAK82CJ43236  46887
# 46886     1GB6G5BL8D1172162  46888
# 46887     1BAKFCKH75F228863  46889
# 46888     1FDSE37F3WHA40620  46890
# 46889     4DRBUSKN6AB229026  46891
# 46890     4UZAAXDG06CV69693  46892
# 46891     1N9MLACL7AC084161  46893
# 46892     4UZABRDU6BCAU5007  46894
# 46893     4UZABRDU1BCAU5058  46895
# 46894  1BABHCKA75F219447ADJ  46896
# 46895     4DRBUC8N2KB685538  46897
# 46896     1GDL7T1B7YJ525553  46898
#
# [46897 rows x 2 columns]

# %%
df[df.VIN.str.contains(";")]

# %%
df[df.VIN.str.contains(",")]

# %%
df_1 = df.iloc[:10000,:]
df_2 = df.iloc[10000:20000,:]
df_3 = df.iloc[20000:30000,:]
df_4 = df.iloc[30000:40000,:]
df_5 = df.iloc[40000:,:]

# %%
QC = pd.concat([df_1,df_2,df_3,df_4,df_5]) == df
QC[(QC['VIN'] == False)|(QC['RowID'] == False)]

# %% [markdown]
# ## 5th Batch

# %%
data_5 = Col_to_str(df_5,'VIN',';')
data_5.count(';')
# Out:
# 6896

# %%
datalen = Col_to_str(df_5,'VIN',';').count(';')
templen = 1000
temp = pd.DataFrame()
for i in range(datalen // templen + 1):
    print(f'|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||current range:{i*templen} ~ {(i+1)*templen}\n\n')
    if (i + 1) * templen < datalen:
        print(i*templen,(i+1)*templen)
        process_temp = ValidationProcess(Col_to_str(df_5[i*templen:(i+1)*templen],'VIN',';'),4)
        result_temp = process_temp.getAll()
        temp = pd.concat([temp,result_temp])
    else:
        print(i*templen ,datalen,'\n')
        process_temp = ValidationProcess(Col_to_str(df_5[i*templen:],'VIN',';'),4)
        result_temp = process_temp.getAll()
        temp = pd.concat([temp,result_temp])
    

temp
# Out:
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||current range:0 ~ 1000
#
#
# 0 1000
# Chunk14 is done! Total: 249
#
# Chunk8 is done! Total: 249
#
# Chunk6 is done! Total: 249
#
# Chunk9 is done! Total: 249
# Chunk13 is done! Total: 249
#
#
# Chunk1 is done! Total: 249
#
# Chunk10 is done! Total: 249
# Chunk12 is done! Total: 249
#
#
# Chunk4 is done! Total: 249
#
# Chunk0 is done! Total: 249
# Chunk5 is done! Total: 249
#
#
# Chunk3 is done! Total: 249
#
# Chunk19 is done! Total: 249
#
# Chunk11 is done! Total: 249
# Chunk18 is done! Total: 249
#
#
# Chunk2 is done! Total: 249
#
# Chunk17 is done! Total: 249
#
# Chunk16 is done! Total: 249
#
# Chunk15 is done! Total: 249
#
# Chunk20 is done! Total: 249
# Chunk7 is done! Total: 249
#
#
# Chunk21 is done! Total: 249
#
# Chunk22 is done! Total: 249
#
# Chunk23 is done! Total: 249
#
# Chunk25 is done! Total: 249
#
# Chunk38 is done! Total: 249
#
# Chunk29 is done! Total: 249
#
# Chunk24 is done! Total: 249
#
# Chunk36 is done! Total: 249
#
# Chunk31 is done! Total: 249
#
# Chunk26 is done! Total: 249
#
# Chunk27 is done! Total: 249
#
# Chunk28 is done! Total: 249
#
# Chunk30 is done! Total: 249
#
# Chunk42 is done! Total: 249
#
# Chunk34 is done! Total: 249
#
# Chunk39 is done! Total: 249
#
# Chunk45 is done! Total: 249
#
# Chunk37 is done! Total: 249
#
# Chunk32 is done! Total: 249
#
# Chunk35 is done! Total: 249
#
# Chunk40 is done! Total: 249
#
# Chunk33 is done! Total: 249
# Chunk43 is done! Total: 249
#
#
# Chunk44 is done! Total: 249
#
# Chunk47 is done! Total: 249
#
# Chunk41 is done! Total: 249
#
# Chunk51 is done! Total: 249
#
# Chunk46 is done! Total: 249
#
# Chunk48 is done! Total: 249
#
# Chunk50 is done! Total: 249
#
# Chunk49 is done! Total: 249
#
# Chunk52 is done! Total: 249
#
# Chunk53 is done! Total: 249
#
# Chunk55 is done! Total: 249
#
# Chunk56 is done! Total: 249
#
# Chunk54 is done! Total: 249
#
# Chunk58 is done! Total: 249
#
# Chunk57 is done! Total: 249
#
# Chunk64 is done! Total: 249
#
# Chunk72 is done! Total: 249
#
# Chunk61 is done! Total: 249
#
# Chunk60 is done! Total: 249
#
# Chunk62 is done! Total: 249
#
# Chunk59 is done! Total: 249
#
# Chunk70 is done! Total: 249
#
# Chunk74 is done! Total: 249
#
# Chunk69 is done! Total: 249
#
# Chunk75 is done! Total: 249
#
# Chunk67 is done! Total: 249
#
# Chunk73 is done! Total: 249
#
# Chunk63 is done! Total: 249
# Chunk65 is done! Total: 249
#
#
# Chunk71 is done! Total: 249
#
# Chunk66 is done! Total: 249
#
# Chunk76 is done! Total: 249
#
# Chunk68 is done! Total: 249
#
# Chunk84 is done! Total: 249
#
# Chunk80 is done! Total: 249
#
# Chunk81 is done! Total: 249
#
# Chunk83 is done! Total: 249
# Chunk78 is done! Total: 249
#
#
# Chunk82 is done! Total: 249
#
# Chunk79 is done! Total: 249
#
# Chunk77 is done! Total: 249
#
# Chunk93 is done! Total: 249
# Chunk86 is done! Total: 249
#
#
# Chunk92 is done! Total: 249
#
# Chunk85 is done! Total: 249
# Chunk91 is done! Total: 249
#
#
# Chunk90 is done! Total: 249
#
# Chunk89 is done! Total: 249
#
# Chunk94 is done! Total: 249
#
# Chunk87 is done! Total: 249
#
# Chunk98 is done! Total: 249
#
# Chunk95 is done! Total: 249
#
# Chunk97 is done! Total: 249
#
# Chunk103 is done! Total: 249
#
# Chunk88 is done! Total: 249
#
# Chunk100 is done! Total: 249
#
# Chunk96 is done! Total: 249
#
# Chunk104 is done! Total: 249
#
# Chunk102 is done! Total: 249
#
# Chunk109 is done! Total: 249
#
# Chunk101 is done! Total: 249
#
# Chunk112 is done! Total: 249
#
# Chunk111 is done! Total: 249
#
# Chunk106 is done! Total: 249
#
# Chunk115 is done! Total: 249
#
# Chunk113 is done! Total: 249
#
# Chunk99 is done! Total: 249
#
# Chunk121 is done! Total: 249
#
# Chunk105 is done! Total: 249
#
# Chunk114 is done! Total: 249
#
# Chunk110 is done! Total: 249
#
# Chunk119 is done! Total: 249
#
# Chunk117 is done! Total: 249
#
# Chunk122 is done! Total: 249
#
# Chunk108 is done! Total: 249
#
# Chunk118 is done! Total: 249
#
# Chunk120 is done! Total: 249
# Chunk107 is done! Total: 249
#
#
# Chunk116 is done! Total: 249
#
# Chunk124 is done! Total: 249
#
# Chunk123 is done! Total: 249
#
# Chunk125 is done! Total: 249
#
# Chunk126 is done! Total: 249
#
# Chunk135 is done! Total: 249
#
# Chunk132 is done! Total: 249
#
# Chunk127 is done! Total: 249
#
# Chunk131 is done! Total: 249
#
# Chunk129 is done! Total: 249
# Chunk130 is done! Total: 249
#
#
# Chunk139 is done! Total: 249
#
# Chunk142 is done! Total: 249
#
# Chunk144 is done! Total: 249
#
# Chunk141 is done! Total: 249
#
# Chunk134 is done! Total: 249
#
# Chunk138 is done! Total: 249
#
# Chunk145 is done! Total: 249
#
# Chunk133 is done! Total: 249
#
# Chunk143 is done! Total: 249
#
# Chunk136 is done! Total: 249
#
# Chunk140 is done! Total: 249
#
# Chunk128 is done! Total: 249
# Chunk146 is done! Total: 249
#
#
# Chunk137 is done! Total: 249
#
# Chunk149 is done! Total: 249
#
# Chunk152 is done! Total: 249
#
# Chunk153 is done! Total: 249
# Chunk147 is done! Total: 249
#
#
# Chunk151 is done! Total: 249
#
# Chunk154 is done! Total: 249
#
# Chunk158 is done! Total: 249
#
# Chunk148 is done! Total: 249
#
# Chunk159 is done! Total: 249
#
# Chunk165 is done! Total: 249
#
# Chunk156 is done! Total: 249
#
# Chunk161 is done! Total: 249
#
# Chunk162 is done! Total: 249
#
# Chunk150 is done! Total: 249
#
# Chunk157 is done! Total: 249
#
# Chunk164 is done! Total: 249
#
# Chunk166 is done! Total: 249
#
# Chunk155 is done! Total: 249
#
# Chunk163 is done! Total: 249
# Chunk160 is done! Total: 249
#
#
# Chunk167 is done! Total: 249
#
# Chunk168 is done! Total: 249
#
# Chunk169 is done! Total: 249
#
# Chunk178 is done! Total: 249
#
# Chunk176 is done! Total: 249
#
# Chunk172 is done! Total: 249
#
# Chunk175 is done! Total: 249
# Chunk181 is done! Total: 249
#
#
# Chunk188 is done! Total: 249
#
# Chunk184 is done! Total: 249
#
# Chunk179 is done! Total: 249
#
# Chunk183 is done! Total: 249
#
# Chunk191 is done! Total: 249
#
# Chunk185 is done! Total: 249
#
# Chunk190 is done! Total: 249
#
# Chunk177 is done! Total: 249
#
# Chunk189 is done! Total: 249
#
# Chunk174 is done! Total: 249
#
# Chunk180 is done! Total: 249
#
# Chunk173 is done! Total: 249
#
# Chunk170 is done! Total: 249
#
# Chunk194 is done! Total: 249
#
# Chunk193 is done! Total: 249
#
# Chunk192 is done! Total: 249
#
# Chunk197 is done! Total: 249
#
# Chunk171 is done! Total: 249
#
# Chunk195 is done! Total: 249
#
# Chunk199 is done! Total: 249
#
# Chunk196 is done! Total: 249
#
# Chunk198 is done! Total: 249
#
# Chunk210 is done! Total: 249
#
# Chunk209 is done! Total: 249
#
# Chunk207 is done! Total: 249
#
# Chunk200 is done! Total: 249
#
# Chunk208 is done! Total: 249
#
# Chunk203 is done! Total: 249
#
# Chunk215 is done! Total: 249
#
# Chunk182 is done! Total: 249
# Chunk214 is done! Total: 249
#
#
# Chunk202 is done! Total: 249
#
# Chunk213 is done! Total: 249
#
# Chunk211 is done! Total: 249
#
# Chunk206 is done! Total: 249
#
# Chunk201 is done! Total: 249
#
# Chunk204 is done! Total: 249
#
# Chunk205 is done! Total: 249
#
# Chunk186 is done! Total: 249
#
# Chunk212 is done! Total: 249
#
# Chunk217 is done! Total: 249
#
# Chunk216 is done! Total: 249
#
# Chunk219 is done! Total: 249
#
# Chunk218 is done! Total: 249
#
# Chunk220 is done! Total: 249
#
# Chunk221 is done! Total: 249
#
# Chunk222 is done! Total: 249
#
# Chunk224 is done! Total: 249
#
# Chunk228 is done! Total: 249
#
# Chunk233 is done! Total: 249
#
# Chunk230 is done! Total: 249
#
# Chunk231 is done! Total: 249
#
# Chunk223 is done! Total: 249
#
# Chunk229 is done! Total: 249
#
# Chunk232 is done! Total: 249
#
# Chunk236 is done! Total: 249
# Chunk227 is done! Total: 249
#
#
# Chunk226 is done! Total: 249
#
# Chunk235 is done! Total: 249
#
# Chunk225 is done! Total: 249
#
# Chunk238 is done! Total: 249
#
# Chunk234 is done! Total: 249
#
# Chunk237 is done! Total: 249
#
# Chunk241 is done! Total: 249
#
# Chunk187 is done! Total: 249
#
# Chunk240 is done! Total: 249
#
# Chunk245 is done! Total: 249
#
# Chunk243 is done! Total: 249
#
# Chunk239 is done! Total: 249
#
# Chunk244 is done! Total: 249
#
# Chunk246 is done! Total: 249
#
# Chunk242 is done! Total: 249
#
# Chunk247 is done! Total: 249
#
# Chunk248 is done! Total: 249
#
# Chunk249 is done! Total: 249
#
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||current range:1000 ~ 2000
#
#
# 1000 2000
# Chunk9 is done! Total: 249
#
# Chunk17 is done! Total: 249
#
# Chunk12 is done! Total: 249
#
# Chunk3 is done! Total: 249
#
# Chunk8 is done! Total: 249
#
# Chunk15 is done! Total: 249
#
# Chunk19 is done! Total: 249
#
# Chunk7 is done! Total: 249
#
# Chunk2 is done! Total: 249
#
# Chunk16 is done! Total: 249
#
# Chunk18 is done! Total: 249
#
# Chunk5 is done! Total: 249
#
# Chunk6 is done! Total: 249
#
# Chunk0 is done! Total: 249
#
# Chunk4 is done! Total: 249
#
# Chunk14 is done! Total: 249
# Chunk1 is done! Total: 249
#
# Chunk11 is done! Total: 249
#
#
# Chunk13 is done! Total: 249
#
# Chunk20 is done! Total: 249
# Chunk10 is done! Total: 249
#
#
# Chunk22 is done! Total: 249
#
# Chunk21 is done! Total: 249
# Chunk23 is done! Total: 249
#
# Chunk24 is done! Total: 249
#
# Chunk28 is done! Total: 249
#
# Chunk26 is done! Total: 249
#
# Chunk32 is done! Total: 249
#
# Chunk41 is done! Total: 249
#
# Chunk25 is done! Total: 249
#
# Chunk34 is done! Total: 249
# Chunk29 is done! Total: 249
#
#
# Chunk36 is done! Total: 249
#
# Chunk39 is done! Total: 249
#
# Chunk35 is done! Total: 249
#
# Chunk37 is done! Total: 249
#
# Chunk38 is done! Total: 249
#
# Chunk27 is done! Total: 249
#
# Chunk31 is done! Total: 249
#
# Chunk44 is done! Total: 249
#
# Chunk40 is done! Total: 249
#
# Chunk33 is done! Total: 249
#
# Chunk42 is done! Total: 249
# Chunk43 is done! Total: 249
#
#
# Chunk30 is done! Total: 249
#
# Chunk47 is done! Total: 249
#
# Chunk50 is done! Total: 249
#
# Chunk55 is done! Total: 249
#
# Chunk48 is done! Total: 249
#
# Chunk45 is done! Total: 249
#
# Chunk46 is done! Total: 249
#
# Chunk57 is done! Total: 249
#
# Chunk56 is done! Total: 249
#
# Chunk61 is done! Total: 249
#
# Chunk51 is done! Total: 249
#
# Chunk63 is done! Total: 249
#
# Chunk59 is done! Total: 249
#
# Chunk64 is done! Total: 249
#
# Chunk60 is done! Total: 249
#
# Chunk49 is done! Total: 249
#
# Chunk66 is done! Total: 249
# Chunk62 is done! Total: 249
#
#
# Chunk53 is done! Total: 249
#
# Chunk70 is done! Total: 249
#
# Chunk52 is done! Total: 249
# Chunk65 is done! Total: 249
#
#
# Chunk54 is done! Total: 249
#
# Chunk58 is done! Total: 249
#
# Chunk67 is done! Total: 249
#
# Chunk72 is done! Total: 249
#
# Chunk69 is done! Total: 249
#
# Chunk68 is done! Total: 249
#
# Chunk74 is done! Total: 249
#
# Chunk73 is done! Total: 249
#
# Chunk75 is done! Total: 249
#
# Chunk71 is done! Total: 249
#
# Chunk79 is done! Total: 249
#
# Chunk80 is done! Total: 249
#
# Chunk76 is done! Total: 249
#
# Chunk88 is done! Total: 249
#
# Chunk87 is done! Total: 249
#
# Chunk89 is done! Total: 249
#
# Chunk84 is done! Total: 249
#
# Chunk91 is done! Total: 249
#
# Chunk78 is done! Total: 249
#
# Chunk86 is done! Total: 249
#
# Chunk82 is done! Total: 249
#
# Chunk90 is done! Total: 249
#
# Chunk83 is done! Total: 249
# Chunk81 is done! Total: 249
#
#
# Chunk77 is done! Total: 249
#
# Chunk85 is done! Total: 249
#
# Chunk101 is done! Total: 249
#
# Chunk96 is done! Total: 249
#
# Chunk102 is done! Total: 249
#
# Chunk97 is done! Total: 249
#
# Chunk94 is done! Total: 249
#
# Chunk92 is done! Total: 249
#
# Chunk99 is done! Total: 249
#
# Chunk98 is done! Total: 249
#
# Chunk93 is done! Total: 249
#
# Chunk107 is done! Total: 249
#
# Chunk112 is done! Total: 249
# Chunk104 is done! Total: 249
#
#
# Chunk100 is done! Total: 249
#
# Chunk105 is done! Total: 249
#
# Chunk95 is done! Total: 249
#
# Chunk110 is done! Total: 249
#
# Chunk106 is done! Total: 249
#
# Chunk103 is done! Total: 249
#
# Chunk111 is done! Total: 249
#
# Chunk115 is done! Total: 249
#
# Chunk108 is done! Total: 249
# Chunk109 is done! Total: 249
#
#
# Chunk118 is done! Total: 249
#
# Chunk114 is done! Total: 249
#
# Chunk116 is done! Total: 249
#
# Chunk117 is done! Total: 249
#
# Chunk113 is done! Total: 249
#
# Chunk121 is done! Total: 249
#
# Chunk119 is done! Total: 249
#
# Chunk120 is done! Total: 249
#
# Chunk133 is done! Total: 249
#
# Chunk131 is done! Total: 249
#
# Chunk125 is done! Total: 249
#
# Chunk122 is done! Total: 249
#
# Chunk136 is done! Total: 249
#
# Chunk127 is done! Total: 249
#
# Chunk126 is done! Total: 249
# Chunk134 is done! Total: 249
#
#
# Chunk128 is done! Total: 249
#
# Chunk123 is done! Total: 249
# Chunk124 is done! Total: 249
#
#
# Chunk129 is done! Total: 249
# Chunk130 is done! Total: 249
#
#
# Chunk132 is done! Total: 249
#
# Chunk139 is done! Total: 249
#
# Chunk138 is done! Total: 249
#
# Chunk135 is done! Total: 249
#
# Chunk142 is done! Total: 249
#
# Chunk137 is done! Total: 249
#
# Chunk143 is done! Total: 249
#
# Chunk144 is done! Total: 249
#
# Chunk140 is done! Total: 249
#
# Chunk141 is done! Total: 249
#
# Chunk150 is done! Total: 249
#
# Chunk147 is done! Total: 249
#
# Chunk145 is done! Total: 249
#
# Chunk146 is done! Total: 249
#
# Chunk152 is done! Total: 249
#
# Chunk148 is done! Total: 249
#
# Chunk151 is done! Total: 249
#
# Chunk149 is done! Total: 249
#
# Chunk157 is done! Total: 249
#
# Chunk155 is done! Total: 249
#
# Chunk153 is done! Total: 249
#
# Chunk163 is done! Total: 249
#
# Chunk158 is done! Total: 249
#
# Chunk160 is done! Total: 249
# Chunk154 is done! Total: 249
#
#
# Chunk168 is done! Total: 249
#
# Chunk161 is done! Total: 249
#
# Chunk162 is done! Total: 249
#
# Chunk156 is done! Total: 249
#
# Chunk159 is done! Total: 249
#
# Chunk164 is done! Total: 249
#
# Chunk169 is done! Total: 249
#
# Chunk170 is done! Total: 249
#
# Chunk165 is done! Total: 249
#
# Chunk167 is done! Total: 249
#
# Chunk174 is done! Total: 249
#
# Chunk166 is done! Total: 249
# Chunk172 is done! Total: 249
#
#
# Chunk171 is done! Total: 249
#
# Chunk173 is done! Total: 249
#
# Chunk183 is done! Total: 249
#
# Chunk175 is done! Total: 249
#
# Chunk186 is done! Total: 249
#
# Chunk180 is done! Total: 249
#
# Chunk181 is done! Total: 249
#
# Chunk176 is done! Total: 249
#
# Chunk184 is done! Total: 249
#
# Chunk190 is done! Total: 249
#
# Chunk179 is done! Total: 249
#
# Chunk191 is done! Total: 249
#
# Chunk192 is done! Total: 249
#
# Chunk195 is done! Total: 249
#
# Chunk178 is done! Total: 249
#
# Chunk185 is done! Total: 249
#
# Chunk187 is done! Total: 249
#
# Chunk193 is done! Total: 249
#
# Chunk194 is done! Total: 249
#
# Chunk182 is done! Total: 249
#
# Chunk188 is done! Total: 249
# Chunk189 is done! Total: 249
#
#
# Chunk200 is done! Total: 249
#
# Chunk198 is done! Total: 249
#
# Chunk196 is done! Total: 249
#
# Chunk197 is done! Total: 249
#
# Chunk201 is done! Total: 249
#
# Chunk203 is done! Total: 249
#
# Chunk205 is done! Total: 249
# Chunk199 is done! Total: 249
#
#
# Chunk206 is done! Total: 249
#
# Chunk211 is done! Total: 249
#
# Chunk216 is done! Total: 249
# Chunk207 is done! Total: 249
#
#
# Chunk202 is done! Total: 249
#
# Chunk204 is done! Total: 249
# Chunk215 is done! Total: 249
#
#
# Chunk209 is done! Total: 249
#
# Chunk217 is done! Total: 249
#
# Chunk213 is done! Total: 249
#
# Chunk214 is done! Total: 249
#
# Chunk218 is done! Total: 249
#
# Chunk212 is done! Total: 249
#
# Chunk208 is done! Total: 249
#
# Chunk210 is done! Total: 249
#
# Chunk219 is done! Total: 249
#
# Chunk220 is done! Total: 249
#
# Chunk223 is done! Total: 249
#
# Chunk228 is done! Total: 249
#
# Chunk224 is done! Total: 249
#
# Chunk229 is done! Total: 249
#
# Chunk232 is done! Total: 249
#
# Chunk233 is done! Total: 249
#
# Chunk222 is done! Total: 249
# Chunk227 is done! Total: 249
#
#
# Chunk225 is done! Total: 249
#
# Chunk226 is done! Total: 249
#
# Chunk234 is done! Total: 249
#
# Chunk221 is done! Total: 249
#
# Chunk237 is done! Total: 249
#
# Chunk235 is done! Total: 249
#
# Chunk231 is done! Total: 249
#
# Chunk240 is done! Total: 249
#
# Chunk177 is done! Total: 249
#
# Chunk230 is done! Total: 249
#
# Chunk236 is done! Total: 249
#
# Chunk239 is done! Total: 249
#
# Chunk242 is done! Total: 249
#
# Chunk241 is done! Total: 249
#
# Chunk238 is done! Total: 249
#
# Chunk243 is done! Total: 249
#
# Chunk246 is done! Total: 249
#
# Chunk245 is done! Total: 249
#
# Chunk249 is done! Total: 249
#
# Chunk248 is done! Total: 249
#
# Chunk244 is done! Total: 249
#
# Chunk247 is done! Total: 249
#
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||current range:2000 ~ 3000
#
#
# 2000 3000
# Chunk19 is done! Total: 249
#
# Chunk7 is done! Total: 249
#
# Chunk5 is done! Total: 249
#
# Chunk3 is done! Total: 249
#
# Chunk0 is done! Total: 249
#
# Chunk9 is done! Total: 249
#
# Chunk16 is done! Total: 249
#
# Chunk8 is done! Total: 249
#
# Chunk12 is done! Total: 249
# Chunk2 is done! Total: 249
#
#
# Chunk10 is done! Total: 249
#
# Chunk11 is done! Total: 249
#
# Chunk1 is done! Total: 249
#
# Chunk4 is done! Total: 249
#
# Chunk6 is done! Total: 249
# Chunk17 is done! Total: 249
# Chunk15 is done! Total: 249
#
#
# Chunk18 is done! Total: 249
#
#
# Chunk20 is done! Total: 249
#
# Chunk21 is done! Total: 249
#
# Chunk13 is done! Total: 249
#
# Chunk32 is done! Total: 249
#
# Chunk14 is done! Total: 249
#
# Chunk37 is done! Total: 249
#
# Chunk40 is done! Total: 249
#
# Chunk22 is done! Total: 249
# Chunk31 is done! Total: 249
#
#
# Chunk25 is done! Total: 249
#
# Chunk26 is done! Total: 249
# Chunk34 is done! Total: 249
#
#
# Chunk27 is done! Total: 249
#
# Chunk39 is done! Total: 249
#
# Chunk35 is done! Total: 249
# Chunk38 is done! Total: 249
#
#
# Chunk23 is done! Total: 249
#
# Chunk29 is done! Total: 249
#
# Chunk30 is done! Total: 249
#
# Chunk28 is done! Total: 249
#
# Chunk42 is done! Total: 249
#
# Chunk24 is done! Total: 249
#
# Chunk36 is done! Total: 249
#
# Chunk41 is done! Total: 249
#
# Chunk33 is done! Total: 249
#
# Chunk45 is done! Total: 249
#
# Chunk46 is done! Total: 249
#
# Chunk44 is done! Total: 249
#
# Chunk47 is done! Total: 249
#
# Chunk48 is done! Total: 249
# Chunk57 is done! Total: 249
#
#
# Chunk51 is done! Total: 249
#
# Chunk55 is done! Total: 249
#
# Chunk56 is done! Total: 249
#
# Chunk54 is done! Total: 249
#
# Chunk52 is done! Total: 249
#
# Chunk53 is done! Total: 249
#
# Chunk62 is done! Total: 249
# Chunk61 is done! Total: 249
#
# Chunk49 is done! Total: 249
#
# Chunk50 is done! Total: 249
#
# Chunk60 is done! Total: 249
#
# Chunk43 is done! Total: 249
#
# Chunk58 is done! Total: 249
#
# Chunk65 is done! Total: 249
#
# Chunk63 is done! Total: 249
#
# Chunk64 is done! Total: 249
#
# Chunk67 is done! Total: 249
#
# Chunk66 is done! Total: 249
#
# Chunk68 is done! Total: 249
#
# Chunk59 is done! Total: 249
#
# Chunk69 is done! Total: 249
#
# Chunk70 is done! Total: 249
# Chunk72 is done! Total: 249
#
#
# Chunk76 is done! Total: 249
#
# Chunk71 is done! Total: 249
#
# Chunk75 is done! Total: 249
#
# Chunk73 is done! Total: 249
#
# Chunk86 is done! Total: 249
#
# Chunk80 is done! Total: 249
#
# Chunk87 is done! Total: 249
#
# Chunk79 is done! Total: 249
# Chunk74 is done! Total: 249
#
#
# Chunk81 is done! Total: 249
#
# Chunk89 is done! Total: 249
#
# Chunk85 is done! Total: 249
#
# Chunk88 is done! Total: 249
#
# Chunk83 is done! Total: 249
#
# Chunk84 is done! Total: 249
#
# Chunk82 is done! Total: 249
#
# Chunk78 is done! Total: 249
#
# Chunk77 is done! Total: 249
#
# Chunk90 is done! Total: 249
#
# Chunk92 is done! Total: 249
#
# Chunk95 is done! Total: 249
#
# Chunk100 is done! Total: 249
#
# Chunk93 is done! Total: 249
#
# Chunk91 is done! Total: 249
#
# Chunk98 is done! Total: 249
#
# Chunk104 is done! Total: 249
#
# Chunk103 is done! Total: 249
#
# Chunk97 is done! Total: 249
#
# Chunk107 is done! Total: 249
#
# Chunk94 is done! Total: 249
#
# Chunk108 is done! Total: 249
#
# Chunk99 is done! Total: 249
#
# Chunk112 is done! Total: 249
#
# Chunk109 is done! Total: 249
#
# Chunk111 is done! Total: 249
#
# Chunk105 is done! Total: 249
#
# Chunk102 is done! Total: 249
#
# Chunk101 is done! Total: 249
#
# Chunk114 is done! Total: 249
#
# Chunk110 is done! Total: 249
#
# Chunk106 is done! Total: 249
#
# Chunk96 is done! Total: 249
#
# Chunk113 is done! Total: 249
# Chunk115 is done! Total: 249
#
#
# Chunk118 is done! Total: 249
#
# Chunk116 is done! Total: 249
#
# Chunk126 is done! Total: 249
#
# Chunk125 is done! Total: 249
#
# Chunk119 is done! Total: 249
#
# Chunk121 is done! Total: 249
#
# Chunk124 is done! Total: 249
#
# Chunk129 is done! Total: 249
#
# Chunk120 is done! Total: 249
#
# Chunk117 is done! Total: 249
#
# Chunk128 is done! Total: 249
#
# Chunk122 is done! Total: 249
#
# Chunk127 is done! Total: 249
#
# Chunk134 is done! Total: 249
#
# Chunk132 is done! Total: 249
#
# Chunk133 is done! Total: 249
#
# Chunk136 is done! Total: 249
#
# Chunk137 is done! Total: 249
#
# Chunk135 is done! Total: 249
#
# Chunk123 is done! Total: 249
#
# Chunk130 is done! Total: 249
#
# Chunk138 is done! Total: 249
#
# Chunk131 is done! Total: 249
#
# Chunk145 is done! Total: 249
#
# Chunk142 is done! Total: 249
#
# Chunk140 is done! Total: 249
#
# Chunk139 is done! Total: 249
#
# Chunk149 is done! Total: 249
#
# Chunk147 is done! Total: 249
#
# Chunk150 is done! Total: 249
#
# Chunk155 is done! Total: 249
#
# Chunk148 is done! Total: 249
#
# Chunk144 is done! Total: 249
#
# Chunk154 is done! Total: 249
#
# Chunk152 is done! Total: 249
#
# Chunk141 is done! Total: 249
#
# Chunk146 is done! Total: 249
#
# Chunk156 is done! Total: 249
#
# Chunk151 is done! Total: 249
#
# Chunk153 is done! Total: 249
#
# Chunk143 is done! Total: 249
#
# Chunk162 is done! Total: 249
#
# Chunk157 is done! Total: 249
#
# Chunk164 is done! Total: 249
#
# Chunk161 is done! Total: 249
#
# Chunk159 is done! Total: 249
#
# Chunk167 is done! Total: 249
#
# Chunk163 is done! Total: 249
#
# Chunk160 is done! Total: 249
#
# Chunk158 is done! Total: 249
#
# Chunk165 is done! Total: 249
#
# Chunk169 is done! Total: 249
#
# Chunk170 is done! Total: 249
#
# Chunk168 is done! Total: 249
#
# Chunk173 is done! Total: 249
#
# Chunk166 is done! Total: 249
#
# Chunk178 is done! Total: 249
#
# Chunk174 is done! Total: 249
# Chunk172 is done! Total: 249
#
#
# Chunk171 is done! Total: 249
#
# Chunk180 is done! Total: 249
#
# Chunk177 is done! Total: 249
#
# Chunk187 is done! Total: 249
#
# Chunk175 is done! Total: 249
#
# Chunk184 is done! Total: 249
#
# Chunk189 is done! Total: 249
#
# Chunk176 is done! Total: 249
#
# Chunk179 is done! Total: 249
#
# Chunk190 is done! Total: 249
#
# Chunk185 is done! Total: 249
#
# Chunk188 is done! Total: 249
#
# Chunk181 is done! Total: 249
#
# Chunk186 is done! Total: 249
#
# Chunk182 is done! Total: 249
#
# Chunk183 is done! Total: 249
#
# Chunk192 is done! Total: 249
#
# Chunk195 is done! Total: 249
#
# Chunk191 is done! Total: 249
#
# Chunk194 is done! Total: 249
#
# Chunk197 is done! Total: 249
#
# Chunk203 is done! Total: 249
#
# Chunk201 is done! Total: 249
#
# Chunk193 is done! Total: 249
#
# Chunk199 is done! Total: 249
#
# Chunk202 is done! Total: 249
#
# Chunk196 is done! Total: 249
#
# Chunk209 is done! Total: 249
#
# Chunk200 is done! Total: 249
#
# Chunk204 is done! Total: 249
#
# Chunk205 is done! Total: 249
#
# Chunk206 is done! Total: 249
#
# Chunk207 is done! Total: 249
#
# Chunk208 is done! Total: 249
#
# Chunk212 is done! Total: 249
#
# Chunk198 is done! Total: 249
#
# Chunk210 is done! Total: 249
#
# Chunk215 is done! Total: 249
#
# Chunk213 is done! Total: 249
#
# Chunk217 is done! Total: 249
#
# Chunk214 is done! Total: 249
#
# Chunk216 is done! Total: 249
#
# Chunk211 is done! Total: 249
#
# Chunk219 is done! Total: 249
#
# Chunk218 is done! Total: 249
#
# Chunk221 is done! Total: 249
#
# Chunk225 is done! Total: 249
#
# Chunk227 is done! Total: 249
#
# Chunk230 is done! Total: 249
#
# Chunk226 is done! Total: 249
#
# Chunk224 is done! Total: 249
#
# Chunk220 is done! Total: 249
#
# Chunk228 is done! Total: 249
#
# Chunk223 is done! Total: 249
#
# Chunk229 is done! Total: 249
#
# Chunk232 is done! Total: 249
#
# Chunk234 is done! Total: 249
#
# Chunk222 is done! Total: 249
#
# Chunk231 is done! Total: 249
#
# Chunk235 is done! Total: 249
#
# Chunk237 is done! Total: 249
#
# Chunk233 is done! Total: 249
#
# Chunk236 is done! Total: 249
#
# Chunk239 is done! Total: 249
#
# Chunk238 is done! Total: 249
#
# Chunk247 is done! Total: 249
#
# Chunk243 is done! Total: 249
#
# Chunk245 is done! Total: 249
#
# Chunk240 is done! Total: 249
#
# Chunk241 is done! Total: 249
#
# Chunk249 is done! Total: 249
#
# Chunk244 is done! Total: 249
#
# Chunk246 is done! Total: 249
#
# Chunk248 is done! Total: 249
#
# Chunk242 is done! Total: 249
#
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||current range:3000 ~ 4000
#
#
# 3000 4000
# Chunk1 is done! Total: 249
#
# Chunk5 is done! Total: 249
#
# Chunk7 is done! Total: 249
#
# Chunk18 is done! Total: 249
#
# Chunk12 is done! Total: 249
#
# Chunk13 is done! Total: 249
#
# Chunk9 is done! Total: 249
#
# Chunk6 is done! Total: 249
#
# Chunk2 is done! Total: 249
#
# Chunk4 is done! Total: 249
#
# Chunk11 is done! Total: 249
#
# Chunk20 is done! Total: 249
#
# Chunk10 is done! Total: 249
#
# Chunk3 is done! Total: 249
#
# Chunk15 is done! Total: 249
#
# Chunk14 is done! Total: 249
#
# Chunk17 is done! Total: 249
#
# Chunk21 is done! Total: 249
#
# Chunk27 is done! Total: 249
#
# Chunk0 is done! Total: 249
#
# Chunk16 is done! Total: 249
#
# Chunk22 is done! Total: 249
#
# Chunk8 is done! Total: 249
# Chunk24 is done! Total: 249
#
#
# Chunk19 is done! Total: 249
#
# Chunk25 is done! Total: 249
#
# Chunk23 is done! Total: 249
#
# Chunk26 is done! Total: 249
#
# Chunk30 is done! Total: 249
#
# Chunk38 is done! Total: 249
#
# Chunk28 is done! Total: 249
#
# Chunk36 is done! Total: 249
#
# Chunk29 is done! Total: 249
#
# Chunk32 is done! Total: 249
#
# Chunk41 is done! Total: 249
#
# Chunk44 is done! Total: 249
#
# Chunk45 is done! Total: 249
#
# Chunk40 is done! Total: 249
#
# Chunk47 is done! Total: 249
#
# Chunk42 is done! Total: 249
#
# Chunk35 is done! Total: 249
#
# Chunk48 is done! Total: 249
#
# Chunk46 is done! Total: 249
#
# Chunk39 is done! Total: 249
#
# Chunk33 is done! Total: 249
# Chunk37 is done! Total: 249
#
#
# Chunk43 is done! Total: 249
#
# Chunk31 is done! Total: 249
#
# Chunk34 is done! Total: 249
#
# Chunk53 is done! Total: 249
#
# Chunk51 is done! Total: 249
#
# Chunk55 is done! Total: 249
#
# Chunk50 is done! Total: 249
#
# Chunk54 is done! Total: 249
#
# Chunk52 is done! Total: 249
#
# Chunk56 is done! Total: 249
#
# Chunk49 is done! Total: 249
#
# Chunk67 is done! Total: 249
#
# Chunk62 is done! Total: 249
#
# Chunk64 is done! Total: 249
#
# Chunk75 is done! Total: 249
#
# Chunk58 is done! Total: 249
#
# Chunk74 is done! Total: 249
# Chunk61 is done! Total: 249
#
#
# Chunk66 is done! Total: 249
#
# Chunk57 is done! Total: 249
#
# Chunk65 is done! Total: 249
#
# Chunk63 is done! Total: 249
# Chunk70 is done! Total: 249
#
#
# Chunk59 is done! Total: 249
# Chunk60 is done! Total: 249
#
#
# Chunk79 is done! Total: 249
#
# Chunk77 is done! Total: 249
#
# Chunk72 is done! Total: 249
#
# Chunk68 is done! Total: 249
#
# Chunk78 is done! Total: 249
#
# Chunk76 is done! Total: 249
#
# Chunk69 is done! Total: 249
#
# Chunk73 is done! Total: 249
#
# Chunk71 is done! Total: 249
#
# Chunk80 is done! Total: 249
# Chunk83 is done! Total: 249
# Chunk81 is done! Total: 249
#
#
# Chunk82 is done! Total: 249
#
# Chunk96 is done! Total: 249
#
# Chunk92 is done! Total: 249
#
# Chunk84 is done! Total: 249
#
# Chunk90 is done! Total: 249
#
# Chunk87 is done! Total: 249
#
# Chunk89 is done! Total: 249
#
# Chunk98 is done! Total: 249
#
# Chunk85 is done! Total: 249
#
# Chunk88 is done! Total: 249
#
# Chunk99 is done! Total: 249
#
# Chunk103 is done! Total: 249
#
# Chunk100 is done! Total: 249
#
# Chunk97 is done! Total: 249
#
# Chunk93 is done! Total: 249
#
# Chunk86 is done! Total: 249
#
# Chunk101 is done! Total: 249
# Chunk94 is done! Total: 249
#
#
# Chunk91 is done! Total: 249
#
# Chunk102 is done! Total: 249
#
# Chunk95 is done! Total: 249
#
# Chunk108 is done! Total: 249
#
# Chunk105 is done! Total: 249
#
# Chunk106 is done! Total: 249
#
# Chunk104 is done! Total: 249
#
# Chunk107 is done! Total: 249
#
# Chunk113 is done! Total: 249
#
# Chunk114 is done! Total: 249
#
# Chunk109 is done! Total: 249
#
# Chunk124 is done! Total: 249
#
# Chunk123 is done! Total: 249
#
# Chunk112 is done! Total: 249
#
# Chunk116 is done! Total: 249
#
# Chunk110 is done! Total: 249
#
# Chunk111 is done! Total: 249
# Chunk119 is done! Total: 249
#
#
# Chunk121 is done! Total: 249
#
# Chunk115 is done! Total: 249
#
# Chunk117 is done! Total: 249
#
# Chunk126 is done! Total: 249
#
# Chunk118 is done! Total: 249
#
# Chunk125 is done! Total: 249
#
# Chunk122 is done! Total: 249
#
# Chunk120 is done! Total: 249
#
# Chunk128 is done! Total: 249
#
# Chunk129 is done! Total: 249
#
# Chunk127 is done! Total: 249
#
# Chunk131 is done! Total: 249
#
# Chunk130 is done! Total: 249
#
# Chunk144 is done! Total: 249
#
# Chunk142 is done! Total: 249
#
# Chunk139 is done! Total: 249
#
# Chunk133 is done! Total: 249
#
# Chunk132 is done! Total: 249
#
# Chunk150 is done! Total: 249
#
# Chunk137 is done! Total: 249
#
# Chunk138 is done! Total: 249
#
# Chunk146 is done! Total: 249
# Chunk136 is done! Total: 249
#
#
# Chunk141 is done! Total: 249
#
# Chunk140 is done! Total: 249
#
# Chunk135 is done! Total: 249
#
# Chunk143 is done! Total: 249
#
# Chunk151 is done! Total: 249
#
# Chunk134 is done! Total: 249
# Chunk145 is done! Total: 249
#
#
# Chunk148 is done! Total: 249
#
# Chunk154 is done! Total: 249
# Chunk149 is done! Total: 249
#
# Chunk147 is done! Total: 249
#
#
# Chunk155 is done! Total: 249
#
# Chunk152 is done! Total: 249
#
# Chunk156 is done! Total: 249
#
# Chunk153 is done! Total: 249
#
# Chunk158 is done! Total: 249
#
# Chunk157 is done! Total: 249
#
# Chunk162 is done! Total: 249
#
# Chunk165 is done! Total: 249
#
# Chunk160 is done! Total: 249
#
# Chunk173 is done! Total: 249
#
# Chunk159 is done! Total: 249
#
# Chunk167 is done! Total: 249
#
# Chunk170 is done! Total: 249
#
# Chunk168 is done! Total: 249
# Chunk174 is done! Total: 249
#
#
# Chunk164 is done! Total: 249
# Chunk180 is done! Total: 249
#
#
# Chunk161 is done! Total: 249
# Chunk171 is done! Total: 249
#
#
# Chunk177 is done! Total: 249
#
# Chunk169 is done! Total: 249
# Chunk179 is done! Total: 249
#
#
# Chunk172 is done! Total: 249
#
# Chunk163 is done! Total: 249
#
# Chunk175 is done! Total: 249
#
# Chunk178 is done! Total: 249
# Chunk176 is done! Total: 249
#
#
# Chunk182 is done! Total: 249
# Chunk166 is done! Total: 249
#
#
# Chunk181 is done! Total: 249
#
# Chunk183 is done! Total: 249
#
# Chunk184 is done! Total: 249
#
# Chunk185 is done! Total: 249
#
# Chunk193 is done! Total: 249
#
# Chunk192 is done! Total: 249
#
# Chunk195 is done! Total: 249
#
# Chunk190 is done! Total: 249
#
# Chunk196 is done! Total: 249
#
# Chunk198 is done! Total: 249
#
# Chunk199 is done! Total: 249
#
# Chunk191 is done! Total: 249
#
# Chunk203 is done! Total: 249
# Chunk189 is done! Total: 249
# Chunk197 is done! Total: 249
#
#
#
# Chunk204 is done! Total: 249
#
# Chunk205 is done! Total: 249
#
# Chunk202 is done! Total: 249
# Chunk186 is done! Total: 249
#
#
# Chunk188 is done! Total: 249
#
# Chunk194 is done! Total: 249
#
# Chunk206 is done! Total: 249
# Chunk187 is done! Total: 249
#
#
# Chunk201 is done! Total: 249
#
# Chunk200 is done! Total: 249
#
# Chunk207 is done! Total: 249
#
# Chunk208 is done! Total: 249
#
# Chunk209 is done! Total: 249
#
# Chunk213 is done! Total: 249
#
# Chunk210 is done! Total: 249
#
# Chunk216 is done! Total: 249
#
# Chunk211 is done! Total: 249
#
# Chunk221 is done! Total: 249
#
# Chunk217 is done! Total: 249
#
# Chunk224 is done! Total: 249
#
# Chunk212 is done! Total: 249
#
# Chunk228 is done! Total: 249
#
# Chunk219 is done! Total: 249
#
# Chunk226 is done! Total: 249
#
# Chunk220 is done! Total: 249
#
# Chunk222 is done! Total: 249
# Chunk225 is done! Total: 249
#
#
# Chunk229 is done! Total: 249
#
# Chunk215 is done! Total: 249
#
# Chunk218 is done! Total: 249
#
# Chunk227 is done! Total: 249
# Chunk223 is done! Total: 249
#
#
# Chunk214 is done! Total: 249
#
# Chunk233 is done! Total: 249
#
# Chunk230 is done! Total: 249
# Chunk234 is done! Total: 249
#
#
# Chunk232 is done! Total: 249
#
# Chunk231 is done! Total: 249
#
# Chunk236 is done! Total: 249
#
# Chunk235 is done! Total: 249
#
# Chunk238 is done! Total: 249
#
# Chunk244 is done! Total: 249
#
# Chunk237 is done! Total: 249
#
# Chunk239 is done! Total: 249
#
# Chunk245 is done! Total: 249
#
# Chunk247 is done! Total: 249
#
# Chunk242 is done! Total: 249
# Chunk240 is done! Total: 249
#
#
# Chunk249 is done! Total: 249
#
# Chunk246 is done! Total: 249
#
# Chunk248 is done! Total: 249
# Chunk241 is done! Total: 249
#
# Chunk243 is done! Total: 249
#
#
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||current range:4000 ~ 5000
#
#
# 4000 5000
# Chunk7 is done! Total: 249
#
# Chunk0 is done! Total: 249
#
# Chunk5 is done! Total: 249
#
# Chunk9 is done! Total: 249
#
# Chunk14 is done! Total: 249
#
# Chunk4 is done! Total: 249
#
# Chunk3 is done! Total: 249
#
# Chunk15 is done! Total: 249
#
# Chunk13 is done! Total: 249
#
# Chunk2 is done! Total: 249
#
# Chunk6 is done! Total: 249
#
# Chunk16 is done! Total: 249
#
# Chunk18 is done! Total: 249
#
# Chunk12 is done! Total: 249
# Chunk19 is done! Total: 249
#
#
# Chunk10 is done! Total: 249
#
# Chunk11 is done! Total: 249
#
# Chunk8 is done! Total: 249
# Chunk17 is done! Total: 249
#
#
# Chunk21 is done! Total: 249
#
# Chunk1 is done! Total: 249
# Chunk20 is done! Total: 249
#
#
# Chunk22 is done! Total: 249
#
# Chunk24 is done! Total: 249
#
# Chunk23 is done! Total: 249
#
# Chunk40 is done! Total: 249
#
# Chunk29 is done! Total: 249
#
# Chunk28 is done! Total: 249
#
# Chunk39 is done! Total: 249
#
# Chunk25 is done! Total: 249
#
# Chunk32 is done! Total: 249
# Chunk27 is done! Total: 249
#
#
# Chunk36 is done! Total: 249
#
# Chunk33 is done! Total: 249
#
# Chunk34 is done! Total: 249
#
# Chunk44 is done! Total: 249
#
# Chunk30 is done! Total: 249
#
# Chunk38 is done! Total: 249
# Chunk31 is done! Total: 249
#
#
# Chunk41 is done! Total: 249
#
# Chunk43 is done! Total: 249
#
# Chunk35 is done! Total: 249
# Chunk37 is done! Total: 249
#
#
# Chunk26 is done! Total: 249
# Chunk42 is done! Total: 249
#
#
# Chunk45 is done! Total: 249
#
# Chunk49 is done! Total: 249
#
# Chunk47 is done! Total: 249
#
# Chunk46 is done! Total: 249
#
# Chunk48 is done! Total: 249
#
# Chunk52 is done! Total: 249
#
# Chunk51 is done! Total: 249
#
# Chunk65 is done! Total: 249
#
# Chunk56 is done! Total: 249
#
# Chunk59 is done! Total: 249
#
# Chunk64 is done! Total: 249
#
# Chunk50 is done! Total: 249
#
# Chunk53 is done! Total: 249
#
# Chunk60 is done! Total: 249
#
# Chunk58 is done! Total: 249
# Chunk62 is done! Total: 249
#
#
# Chunk61 is done! Total: 249
# Chunk55 is done! Total: 249
#
#
# Chunk67 is done! Total: 249
#
# Chunk66 is done! Total: 249
# Chunk57 is done! Total: 249
#
#
# Chunk54 is done! Total: 249
#
# Chunk63 is done! Total: 249
#
# Chunk72 is done! Total: 249
#
# Chunk68 is done! Total: 249
#
# Chunk69 is done! Total: 249
# Chunk70 is done! Total: 249
#
#
# Chunk71 is done! Total: 249
#
# Chunk73 is done! Total: 249
#
# Chunk75 is done! Total: 249
#
# Chunk74 is done! Total: 249
#
# Chunk77 is done! Total: 249
#
# Chunk84 is done! Total: 249
#
# Chunk88 is done! Total: 249
#
# Chunk81 is done! Total: 249
#
# Chunk87 is done! Total: 249
#
# Chunk86 is done! Total: 249
#
# Chunk83 is done! Total: 249
#
# Chunk78 is done! Total: 249
#
# Chunk89 is done! Total: 249
#
# Chunk80 is done! Total: 249
#
# Chunk91 is done! Total: 249
#
# Chunk90 is done! Total: 249
# Chunk92 is done! Total: 249
#
#
# Chunk76 is done! Total: 249
#
# Chunk85 is done! Total: 249
#
# Chunk93 is done! Total: 249
#
# Chunk82 is done! Total: 249
#
# Chunk79 is done! Total: 249
#
# Chunk96 is done! Total: 249
#
# Chunk94 is done! Total: 249
# Chunk95 is done! Total: 249
#
#
# Chunk97 is done! Total: 249
#
# Chunk98 is done! Total: 249
#
# Chunk99 is done! Total: 249
#
# Chunk100 is done! Total: 249
#
# Chunk103 is done! Total: 249
#
# Chunk101 is done! Total: 249
#
# Chunk110 is done! Total: 249
#
# Chunk109 is done! Total: 249
#
# Chunk102 is done! Total: 249
#
# Chunk104 is done! Total: 249
#
# Chunk116 is done! Total: 249
# Chunk114 is done! Total: 249
#
# Chunk105 is done! Total: 249
#
# Chunk115 is done! Total: 249
#
# Chunk106 is done! Total: 249
#
# Chunk122 is done! Total: 249
#
# Chunk118 is done! Total: 249
#
# Chunk111 is done! Total: 249
#
# Chunk120 is done! Total: 249
#
# Chunk119 is done! Total: 249
#
# Chunk117 is done! Total: 249
#
# Chunk113 is done! Total: 249
#
# Chunk107 is done! Total: 249
#
# Chunk123 is done! Total: 249
#
# Chunk108 is done! Total: 249
#
# Chunk112 is done! Total: 249
#
# Chunk124 is done! Total: 249
#
# Chunk121 is done! Total: 249
#
# Chunk127 is done! Total: 249
#
# Chunk125 is done! Total: 249
#
# Chunk126 is done! Total: 249
#
# Chunk129 is done! Total: 249
#
# Chunk141 is done! Total: 249
# Chunk143 is done! Total: 249
#
#
# Chunk136 is done! Total: 249
#
# Chunk128 is done! Total: 249
#
# Chunk133 is done! Total: 249
#
# Chunk130 is done! Total: 249
#
# Chunk137 is done! Total: 249
#
# Chunk134 is done! Total: 249
#
# Chunk135 is done! Total: 249
# Chunk138 is done! Total: 249
#
#
# Chunk132 is done! Total: 249
#
# Chunk139 is done! Total: 249
#
# Chunk146 is done! Total: 249
#
# Chunk140 is done! Total: 249
# Chunk142 is done! Total: 249
#
#
# Chunk131 is done! Total: 249
#
# Chunk148 is done! Total: 249
#
# Chunk145 is done! Total: 249
#
# Chunk144 is done! Total: 249
#
# Chunk147 is done! Total: 249
#
# Chunk149 is done! Total: 249
#
# Chunk152 is done! Total: 249
#
# Chunk151 is done! Total: 249
#
# Chunk150 is done! Total: 249
#
# Chunk159 is done! Total: 249
#
# Chunk160 is done! Total: 249
#
# Chunk157 is done! Total: 249
#
# Chunk154 is done! Total: 249
#
# Chunk169 is done! Total: 249
#
# Chunk155 is done! Total: 249
#
# Chunk153 is done! Total: 249
#
# Chunk163 is done! Total: 249
#
# Chunk168 is done! Total: 249
#
# Chunk173 is done! Total: 249
#
# Chunk156 is done! Total: 249
#
# Chunk162 is done! Total: 249
#
# Chunk172 is done! Total: 249
#
# Chunk171 is done! Total: 249
#
# Chunk165 is done! Total: 249
#
# Chunk158 is done! Total: 249
#
# Chunk167 is done! Total: 249
#
# Chunk166 is done! Total: 249
#
# Chunk164 is done! Total: 249
#
# Chunk175 is done! Total: 249
#
# Chunk180 is done! Total: 249
#
# Chunk182 is done! Total: 249
#
# Chunk178 is done! Total: 249
#
# Chunk191 is done! Total: 249
#
# Chunk192 is done! Total: 249
#
# Chunk177 is done! Total: 249
#
# Chunk179 is done! Total: 249
#
# Chunk176 is done! Total: 249
#
# Chunk181 is done! Total: 249
# Chunk187 is done! Total: 249
#
#
# Chunk185 is done! Total: 249
# Chunk186 is done! Total: 249
#
#
# Chunk190 is done! Total: 249
#
# Chunk161 is done! Total: 249
#
# Chunk189 is done! Total: 249
#
# Chunk193 is done! Total: 249
#
# Chunk183 is done! Total: 249
#
# Chunk170 is done! Total: 249
#
# Chunk184 is done! Total: 249
#
# Chunk174 is done! Total: 249
#
# Chunk194 is done! Total: 249
#
# Chunk188 is done! Total: 249
#
# Chunk196 is done! Total: 249
#
# Chunk195 is done! Total: 249
#
# Chunk197 is done! Total: 249
#
# Chunk200 is done! Total: 249
#
# Chunk201 is done! Total: 249
#
# Chunk198 is done! Total: 249
#
# Chunk205 is done! Total: 249
#
# Chunk204 is done! Total: 249
#
# Chunk209 is done! Total: 249
#
# Chunk202 is done! Total: 249
#
# Chunk215 is done! Total: 249
#
# Chunk211 is done! Total: 249
#
# Chunk212 is done! Total: 249
#
# Chunk207 is done! Total: 249
#
# Chunk199 is done! Total: 249
#
# Chunk203 is done! Total: 249
#
# Chunk206 is done! Total: 249
# Chunk208 is done! Total: 249
#
#
# Chunk217 is done! Total: 249
#
# Chunk214 is done! Total: 249
#
# Chunk213 is done! Total: 249
#
# Chunk216 is done! Total: 249
#
# Chunk225 is done! Total: 249
#
# Chunk210 is done! Total: 249
#
# Chunk218 is done! Total: 249
#
# Chunk220 is done! Total: 249
#
# Chunk228 is done! Total: 249
#
# Chunk226 is done! Total: 249
#
# Chunk219 is done! Total: 249
#
# Chunk229 is done! Total: 249
#
# Chunk227 is done! Total: 249
#
# Chunk223 is done! Total: 249
#
# Chunk221 is done! Total: 249
#
# Chunk230 is done! Total: 249
#
# Chunk224 is done! Total: 249
#
# Chunk233 is done! Total: 249
#
# Chunk236 is done! Total: 249
#
# Chunk235 is done! Total: 249
#
# Chunk232 is done! Total: 249
#
# Chunk231 is done! Total: 249
#
# Chunk234 is done! Total: 249
#
# Chunk222 is done! Total: 249
#
# Chunk239 is done! Total: 249
#
# Chunk238 is done! Total: 249
#
# Chunk237 is done! Total: 249
#
# Chunk240 is done! Total: 249
#
# Chunk241 is done! Total: 249
#
# Chunk243 is done! Total: 249
#
# Chunk244 is done! Total: 249
#
# Chunk246 is done! Total: 249
#
# Chunk245 is done! Total: 249
#
# Chunk242 is done! Total: 249
#
# Chunk247 is done! Total: 249
#
# Chunk248 is done! Total: 249
#
# Chunk249 is done! Total: 249
#
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||current range:5000 ~ 6000
#
#
# 5000 6000
# Chunk6 is done! Total: 249
#
# Chunk4 is done! Total: 249
#
# Chunk11 is done! Total: 249
# Chunk2 is done! Total: 249
# Chunk1 is done! Total: 249
#
#
#
# Chunk7 is done! Total: 249
# Chunk3 is done! Total: 249
#
#
# Chunk0 is done! Total: 249
#
# Chunk5 is done! Total: 249
#
# Chunk13 is done! Total: 249
#
# Chunk16 is done! Total: 249
#
# Chunk20 is done! Total: 249
#
# Chunk17 is done! Total: 249
# Chunk12 is done! Total: 249
#
# Chunk9 is done! Total: 249
#
#
# Chunk19 is done! Total: 249
#
# Chunk15 is done! Total: 249
# Chunk10 is done! Total: 249
#
#
# Chunk22 is done! Total: 249
#
# Chunk28 is done! Total: 249
#
# Chunk8 is done! Total: 249
#
# Chunk32 is done! Total: 249
#
# Chunk21 is done! Total: 249
#
# Chunk14 is done! Total: 249
# Chunk38 is done! Total: 249
#
#
# Chunk30 is done! Total: 249
#
# Chunk31 is done! Total: 249
#
# Chunk36 is done! Total: 249
#
# Chunk27 is done! Total: 249
#
# Chunk33 is done! Total: 249
#
# Chunk29 is done! Total: 249
#
# Chunk35 is done! Total: 249
#
# Chunk37 is done! Total: 249
#
# Chunk34 is done! Total: 249
#
# Chunk25 is done! Total: 249
# Chunk24 is done! Total: 249
#
#
# Chunk23 is done! Total: 249
#
# Chunk42 is done! Total: 249
# Chunk49 is done! Total: 249
#
#
# Chunk47 is done! Total: 249
#
# Chunk48 is done! Total: 249
#
# Chunk52 is done! Total: 249
#
# Chunk39 is done! Total: 249
# Chunk40 is done! Total: 249
#
#
# Chunk51 is done! Total: 249
#
# Chunk55 is done! Total: 249
# Chunk50 is done! Total: 249
#
#
# Chunk26 is done! Total: 249
#
# Chunk45 is done! Total: 249
#
# Chunk54 is done! Total: 249
#
# Chunk46 is done! Total: 249
#
# Chunk56 is done! Total: 249
#
# Chunk44 is done! Total: 249
#
# Chunk53 is done! Total: 249
#
# Chunk43 is done! Total: 249
#
# Chunk41 is done! Total: 249
#
# Chunk58 is done! Total: 249
#
# Chunk18 is done! Total: 249
#
# Chunk57 is done! Total: 249
#
# Chunk59 is done! Total: 249
#
# Chunk64 is done! Total: 249
#
# Chunk61 is done! Total: 249
#
# Chunk65 is done! Total: 249
#
# Chunk73 is done! Total: 249
#
# Chunk74 is done! Total: 249
#
# Chunk69 is done! Total: 249
#
# Chunk71 is done! Total: 249
#
# Chunk70 is done! Total: 249
# Chunk62 is done! Total: 249
#
#
# Chunk77 is done! Total: 249
#
# Chunk75 is done! Total: 249
#
# Chunk76 is done! Total: 249
#
# Chunk72 is done! Total: 249
#
# Chunk68 is done! Total: 249
#
# Chunk78 is done! Total: 249
#
# Chunk81 is done! Total: 249
#
# Chunk79 is done! Total: 249
#
# Chunk80 is done! Total: 249
#
# Chunk60 is done! Total: 249
#
# Chunk67 is done! Total: 249
#
# Chunk97 is done! Total: 249
#
# Chunk86 is done! Total: 249
#
# Chunk89 is done! Total: 249
#
# Chunk92 is done! Total: 249
#
# Chunk88 is done! Total: 249
#
# Chunk83 is done! Total: 249
#
# Chunk85 is done! Total: 249
#
# Chunk90 is done! Total: 249
#
# Chunk87 is done! Total: 249
#
# Chunk94 is done! Total: 249
#
# Chunk82 is done! Total: 249
#
# Chunk93 is done! Total: 249
#
# Chunk95 is done! Total: 249
# Chunk84 is done! Total: 249
# Chunk66 is done! Total: 249
#
#
#
# Chunk91 is done! Total: 249
#
# Chunk96 is done! Total: 249
#
# Chunk98 is done! Total: 249
#
# Chunk63 is done! Total: 249
#
# Chunk99 is done! Total: 249
#
# Chunk100 is done! Total: 249
#
# Chunk101 is done! Total: 249
#
# Chunk107 is done! Total: 249
#
# Chunk105 is done! Total: 249
#
# Chunk117 is done! Total: 249
#
# Chunk102 is done! Total: 249
#
# Chunk104 is done! Total: 249
#
# Chunk116 is done! Total: 249
#
# Chunk111 is done! Total: 249
#
# Chunk108 is done! Total: 249
#
# Chunk110 is done! Total: 249
#
# Chunk118 is done! Total: 249
#
# Chunk103 is done! Total: 249
#
# Chunk119 is done! Total: 249
# Chunk120 is done! Total: 249
#
#
# Chunk115 is done! Total: 249
#
# Chunk113 is done! Total: 249
#
# Chunk106 is done! Total: 249
#
# Chunk112 is done! Total: 249
#
# Chunk114 is done! Total: 249
# Chunk109 is done! Total: 249
#
#
# Chunk122 is done! Total: 249
#
# Chunk121 is done! Total: 249
#
# Chunk123 is done! Total: 249
#
# Chunk124 is done! Total: 249
#
# The Status code: 403, The input data is: 2C3HD46R62H103186;LS,35W,10CHB;4UZABRFC1JCJT6606;3GKGC26F7XG546060, The Chunk name is Chunk144
#  Second attempt: trying to split and run one by one.....
# Chunk129 is done! Total: 249
#
# Chunk126 is done! Total: 249
#
# Chunk131 is done! Total: 249
#
# Chunk128 is done! Total: 249
#
# Chunk133 is done! Total: 249
#
# Chunk136 is done! Total: 249
#
# Chunk135 is done! Total: 249
#
# Chunk140 is done! Total: 249
#
# Chunk142 is done! Total: 249
#
# Chunk139 is done! Total: 249
#
# Chunk137 is done! Total: 249
#
# Chunk127 is done! Total: 249
#
# Successfully get the VIN: 2C3HD46R62H103186
# Chunk138 is done! Total: 249
#
#
# Chunk132 is done! Total: 249
#
# Chunk125 is done! Total: 249
#
# Chunk141 is done! Total: 249
#
# Chunk130 is done! Total: 249
#
# Chunk143 is done! Total: 249
#
# Chunk134 is done! Total: 249
#
# Chunk145 is done! Total: 249
#
# Chunk147 is done! Total: 249
#
# Successfully get the VIN: LS,35W,10CHB
#
# Chunk146 is done! Total: 249
#
# Chunk148 is done! Total: 249
#
# Chunk151 is done! Total: 249
# Chunk150 is done! Total: 249
#
#
# Chunk149 is done! Total: 249
#
# Successfully get the VIN: 4UZABRFC1JCJT6606
#
# Chunk155 is done! Total: 249
#
# Chunk158 is done! Total: 249
#
# Chunk163 is done! Total: 249
#
# Chunk166 is done! Total: 249
#
# Chunk153 is done! Total: 249
#
# Chunk162 is done! Total: 249
# Chunk152 is done! Total: 249
#
#
# Chunk157 is done! Total: 249
#
# Successfully get the VIN: 3GKGC26F7XG546060
#
# Chunk156 is done! Total: 249
#
# Chunk154 is done! Total: 249
#
# Chunk167 is done! Total: 249
# Chunk159 is done! Total: 249
#
#
# Chunk165 is done! Total: 249
#
# Chunk164 is done! Total: 249
#
# Chunk161 is done! Total: 249
#
# Chunk160 is done! Total: 249
#
# Chunk172 is done! Total: 249
#
# Chunk173 is done! Total: 249
#
# Chunk168 is done! Total: 249
#
# Chunk171 is done! Total: 249
#
# Chunk170 is done! Total: 249
#
# Chunk169 is done! Total: 249
#
# Chunk176 is done! Total: 249
#
# Chunk175 is done! Total: 249
#
# Chunk174 is done! Total: 249
#
# Chunk177 is done! Total: 249
# Chunk188 is done! Total: 249
#
# Chunk178 is done! Total: 249
#
#
# Chunk182 is done! Total: 249
# Chunk180 is done! Total: 249
#
#
# Chunk190 is done! Total: 249
#
# Chunk194 is done! Total: 249
#
# Chunk183 is done! Total: 249
#
# Chunk179 is done! Total: 249
#
# Chunk191 is done! Total: 249
#
# Chunk181 is done! Total: 249
#
# Chunk184 is done! Total: 249
#
# Chunk193 is done! Total: 249
#
# Chunk187 is done! Total: 249
#
# Chunk189 is done! Total: 249
# Chunk196 is done! Total: 249
# Chunk186 is done! Total: 249
#
#
#
# Chunk185 is done! Total: 249
#
# Chunk192 is done! Total: 249
#
# Chunk195 is done! Total: 249
#
# Chunk201 is done! Total: 249
#
# Chunk197 is done! Total: 249
#
# Chunk206 is done! Total: 249
#
# Chunk202 is done! Total: 249
#
# Chunk205 is done! Total: 249
#
# Chunk210 is done! Total: 249
#
# Chunk204 is done! Total: 249
#
# Chunk213 is done! Total: 249
#
# Chunk215 is done! Total: 249
#
# Chunk214 is done! Total: 249
#
# Chunk216 is done! Total: 249
#
# Chunk208 is done! Total: 249
# Chunk207 is done! Total: 249
#
#
# Chunk200 is done! Total: 249
#
# Chunk212 is done! Total: 249
# Chunk198 is done! Total: 249
#
#
# Chunk199 is done! Total: 249
#
# Chunk203 is done! Total: 249
#
# Chunk209 is done! Total: 249
#
# Chunk211 is done! Total: 249
#
# Chunk217 is done! Total: 249
#
# Chunk218 is done! Total: 249
#
# Chunk220 is done! Total: 249
#
# Chunk221 is done! Total: 249
#
# Chunk219 is done! Total: 249
#
# Chunk222 is done! Total: 249
#
# Chunk223 is done! Total: 249
#
# Chunk226 is done! Total: 249
#
# Chunk237 is done! Total: 249
#
# Chunk229 is done! Total: 249
# Chunk224 is done! Total: 249
#
#
# Chunk225 is done! Total: 249
#
# Chunk236 is done! Total: 249
#
# Chunk242 is done! Total: 249
#
# Chunk227 is done! Total: 249
#
# Chunk230 is done! Total: 249
#
# Chunk231 is done! Total: 249
# Chunk235 is done! Total: 249
#
#
# Chunk234 is done! Total: 249
#
# Chunk233 is done! Total: 249
#
# Chunk240 is done! Total: 249
#
# Chunk239 is done! Total: 249
#
# Chunk232 is done! Total: 249
#
# Chunk244 is done! Total: 249
# Chunk241 is done! Total: 249
#
#
# Chunk243 is done! Total: 249
# Chunk228 is done! Total: 249
#
# Chunk238 is done! Total: 249
#
#
# Chunk248 is done! Total: 249
#
# Chunk249 is done! Total: 249
#
# Chunk246 is done! Total: 249
#
# Chunk247 is done! Total: 249
#
# Chunk245 is done! Total: 249
#
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||current range:6000 ~ 7000
#
#
# 6000 6896
#
# Chunk4 is done! Total: 223
#
# Chunk6 is done! Total: 223
#
# Chunk14 is done! Total: 223
#
# Chunk7 is done! Total: 223
# Chunk2 is done! Total: 223
#
#
# Chunk16 is done! Total: 223
#
# Chunk19 is done! Total: 223
#
# Chunk15 is done! Total: 223
#
# Chunk10 is done! Total: 223
#
# Chunk17 is done! Total: 223
# Chunk9 is done! Total: 223
#
#
# Chunk20 is done! Total: 223
#
# Chunk11 is done! Total: 223
#
# Chunk5 is done! Total: 223
#
# Chunk1 is done! Total: 223
#
# Chunk18 is done! Total: 223
# Chunk13 is done! Total: 223
#
#
# Chunk3 is done! Total: 223
#
# Chunk21 is done! Total: 223
#
# Chunk8 is done! Total: 223
#
# Chunk12 is done! Total: 223
#
# Chunk0 is done! Total: 223
#
# Chunk24 is done! Total: 223
#
# Chunk23 is done! Total: 223
#
# Chunk22 is done! Total: 223
#
# Chunk29 is done! Total: 223
#
# Chunk26 is done! Total: 223
#
# Chunk32 is done! Total: 223
#
# Chunk37 is done! Total: 223
#
# Chunk30 is done! Total: 223
#
# Chunk35 is done! Total: 223
#
# Chunk36 is done! Total: 223
#
# Chunk38 is done! Total: 223
# Chunk27 is done! Total: 223
#
#
# Chunk25 is done! Total: 223
#
# Chunk31 is done! Total: 223
#
# Chunk41 is done! Total: 223
#
# Chunk39 is done! Total: 223
#
# Chunk33 is done! Total: 223
#
# Chunk28 is done! Total: 223
#
# Chunk43 is done! Total: 223
#
# Chunk40 is done! Total: 223
#
# Chunk44 is done! Total: 223
#
# Chunk34 is done! Total: 223
#
# Chunk42 is done! Total: 223
#
# Chunk45 is done! Total: 223
#
# Chunk56 is done! Total: 223
#
# Chunk51 is done! Total: 223
#
# Chunk57 is done! Total: 223
#
# Chunk47 is done! Total: 223
#
# Chunk46 is done! Total: 223
#
# Chunk55 is done! Total: 223
#
# Chunk63 is done! Total: 223
#
# Chunk49 is done! Total: 223
# Chunk50 is done! Total: 223
#
#
# Chunk62 is done! Total: 223
#
# Chunk60 is done! Total: 223
#
# Chunk52 is done! Total: 223
#
# Chunk61 is done! Total: 223
# Chunk64 is done! Total: 223
# Chunk58 is done! Total: 223
#
#
# Chunk54 is done! Total: 223
#
#
# Chunk59 is done! Total: 223
# Chunk65 is done! Total: 223
#
#
# Chunk53 is done! Total: 223
#
# Chunk48 is done! Total: 223
#
# Chunk66 is done! Total: 223
# Chunk67 is done! Total: 223
#
#
# Chunk68 is done! Total: 223
#
# Chunk69 is done! Total: 223
#
# Chunk74 is done! Total: 223
#
# Chunk71 is done! Total: 223
#
# Chunk78 is done! Total: 223
#
# Chunk77 is done! Total: 223
#
# Chunk84 is done! Total: 223
#
# Chunk86 is done! Total: 223
#
# Chunk80 is done! Total: 223
#
# Chunk83 is done! Total: 223
#
# Chunk75 is done! Total: 223
#
# Chunk82 is done! Total: 223
#
# Chunk81 is done! Total: 223
# Chunk90 is done! Total: 223
#
#
# Chunk76 is done! Total: 223
#
# Chunk72 is done! Total: 223
# Chunk85 is done! Total: 223
#
#
# Chunk70 is done! Total: 223
#
# Chunk87 is done! Total: 223
# Chunk88 is done! Total: 223
#
#
# Chunk79 is done! Total: 223
#
# Chunk92 is done! Total: 223
#
# Chunk91 is done! Total: 223
#
# ...
# 3      FREIGHTLINER CUSTOM CHASSIS CORP.            B2 Bus Chassis       2011
# 0                            IC BUS, LLC                      PB105      2018
# 1                         NAVISTAR, INC.                       3800      2001
# 2                     GENERAL MOTORS LLC                   Uplander      2008
# 3      FREIGHTLINER CUSTOM CHASSIS CORP.              FS 65 Chassis      2007
# 0                        FCA CANADA INC.              Grand Caravan      2017
# 1                 BLUE BIRD BODY COMPANY            BB Conventional      2012
# 2      FREIGHTLINER CUSTOM CHASSIS CORP.              FS 65 Chassis      2005
# 3                         NAVISTAR, INC.                       3800      2002
# 0                FORD MOTOR COMPANY, USA                      E-350      2004
# 1                     GENERAL MOTORS LLC                     Savana      1999
# 2                            IC BUS, LLC                      PB105      2014
# 3                         NAVISTAR, INC.                       3800      1995
# 0      FREIGHTLINER CUSTOM CHASSIS CORP.            B2 Bus Chassis       2007
# 1                            IC BUS, LLC                      PB105      2017
# ..                                   ...                        ...       ...
# 3      FREIGHTLINER CUSTOM CHASSIS CORP.            B2 Bus Chassis       2008
# 0                            IC BUS, LLC                      PB105      2006
# 1                     GENERAL MOTORS LLC                    Express      2017
# 2      FREIGHTLINER CUSTOM CHASSIS CORP.            B2 Bus Chassis       2017
# 3
# 0                 BLUE BIRD BODY COMPANY                                 2002
# 1
# 2                THOMAS BUILT BUSES, INC      MVP-EF (Engine Front)      2011
# 3      FREIGHTLINER CUSTOM CHASSIS CORP.            B2 Bus Chassis       2010
# 0                THOMAS BUILT BUSES, INC                        HDX      2011
# 1        TOYOTA MOTOR NORTH AMERICA, INC                    Prius V      2017
# 2      FREIGHTLINER CUSTOM CHASSIS CORP.            B2 Bus Chassis       2013
# 3                             FCA US LLC      Caravan/Grand Caravan      2007
# 0                        FCA CANADA INC.              Grand Caravan      2016
# 1                     GENERAL MOTORS LLC                    Express      2009
# 2                THOMAS BUILT BUSES, INC      MVP-EF (Engine Front)      1999
# 3                            IC BUS, LLC                      PB105      2010
# 0                            IC BUS, LLC                      PB105      2016
# 1      FREIGHTLINER CUSTOM CHASSIS CORP.              FS 65 Chassis      2002
# 2                     GENERAL MOTORS LLC                    Express      2013
# 3                 BLUE BIRD BODY COMPANY            BB Conventional      2005
# 0                FORD MOTOR COMPANY, USA                      E-350      1998
# 1                            IC BUS, LLC                      PB105      2010
# 2      FREIGHTLINER CUSTOM CHASSIS CORP.              FS 65 Chassis      2006
# 3   ELDORADO NATIONAL (CALIFORNIA), INC.          EZ - Rider II MAX      2010
# 0      FREIGHTLINER CUSTOM CHASSIS CORP.            B2 Bus Chassis       2011
# 1      FREIGHTLINER CUSTOM CHASSIS CORP.            B2 Bus Chassis       2011
# 2                 BLUE BIRD BODY COMPANY  All American / All Canada      2005
# 3                            IC BUS, LLC                      PB105      2019
# 0                     GENERAL MOTORS LLC                         B7      2000
#
#                          Series                                       Trim  \
# 0                          3500                                    Cutaway
# 1
# 2
# 3                          3500                                    Cutaway
# 0
# 1   FBC Forward control chassis
# 2            Econoline/E-series
# 3   FBC Forward control chassis
# 0                            RE
# 1                     2810-3006
# 2
# 3
# 0                          3500
# 1                            CE
# 2
# 3
# 0                            CE
# 1   FBC Forward control chassis
# 2                       1/2 Ton                                LS APV, EWB
# 3
# 0                            RT  SE (US), SE/SXT (Can), Express (Mex), HFE
# 1                     3109-3400                               Front Engine
# 2
# 3   FBC Forward control chassis
# 0                     Econoline
# 1                  3500 (1 ton)
# 2                            CE
# 3   FBC Forward control chassis
# 0
# 1                            CE
# ..                          ...                                        ...
# 3
# 0                            CE
# 1                          4500                     Cutaway 159" Wheelbase
# 2
# 3
# 0                     3401-3502
# 1
# 2        121 (12 sections +10")
# 3
# 0        141 (14 Sections +10")
# 1                        ZVW41L
# 2
# 3                            RS                                  Base, C/V
# 0                            RT                                         SE
# 1                          3500
# 2             120 (12 sections)
# 3                            CE
# 0                            CE
# 1
# 2                                              4500 Cutaway 159" Wheelbase
# 3                     3007-3108                               Front Engine
# 0                            SD
# 1                            CE
# 2
# 3                     Low Rider
# 0
# 1
# 2                     3401-3502                               Front Engine
# 3                            CE
# 0                                                             Cowl Chassis
#
#                              VehicleType       SuggestedVIN  \
# 0                     INCOMPLETE VEHICLE
# 1                     INCOMPLETE VEHICLE
# 2                     INCOMPLETE VEHICLE
# 3                     INCOMPLETE VEHICLE
# 0                     INCOMPLETE VEHICLE
# 1                     INCOMPLETE VEHICLE
# 2                                 TRUCK
# 3                     INCOMPLETE VEHICLE
# 0                                    BUS
# 1                                    BUS  1BA!ECPH61F099869
# 2
# 3                     INCOMPLETE VEHICLE
# 0                     INCOMPLETE VEHICLE
# 1                                    BUS
# 2                     INCOMPLETE VEHICLE
# 3                     INCOMPLETE VEHICLE
# 0                                    BUS
# 1                     INCOMPLETE VEHICLE
# 2   MULTIPURPOSE PASSENGER VEHICLE (MPV)
# 3                     INCOMPLETE VEHICLE
# 0   MULTIPURPOSE PASSENGER VEHICLE (MPV)
# 1                                    BUS
# 2                     INCOMPLETE VEHICLE
# 3                     INCOMPLETE VEHICLE
# 0                     INCOMPLETE VEHICLE
# 1                     INCOMPLETE VEHICLE
# 2                                    BUS
# 3                     INCOMPLETE VEHICLE
# 0                     INCOMPLETE VEHICLE
# 1                                    BUS
# ..                                   ...                ...
# 3                     INCOMPLETE VEHICLE
# 0                                    BUS
# 1                     INCOMPLETE VEHICLE
# 2                     INCOMPLETE VEHICLE
# 3
# 0                                    BUS  1BA!HCPA02F205065
# 1
# 2                                    BUS
# 3                     INCOMPLETE VEHICLE
# 0                                    BUS
# 1                          PASSENGER CAR
# 2                     INCOMPLETE VEHICLE
# 3   MULTIPURPOSE PASSENGER VEHICLE (MPV)
# 0   MULTIPURPOSE PASSENGER VEHICLE (MPV)
# 1                     INCOMPLETE VEHICLE
# 2                                    BUS
# 3                                    BUS
# 0                                    BUS
# 1                     INCOMPLETE VEHICLE
# 2                     INCOMPLETE VEHICLE
# 3                                    BUS
# 0                     INCOMPLETE VEHICLE
# 1                                    BUS
# 2                     INCOMPLETE VEHICLE
# 3                                    BUS
# 0                     INCOMPLETE VEHICLE
# 1                     INCOMPLETE VEHICLE
# 2                                    BUS
# 3                                    BUS
# 0                     INCOMPLETE VEHICLE
#
#                                             ErrorText
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   3 - VIN corrected, error in one position (assu...
# 2   6 - Incomplete VIN; 7 - Manufacturer is not re...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# ..                                                ...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   6 - Incomplete VIN; 7 - Manufacturer is not re...
# 0   3 - VIN corrected, error in one position (assu...
# 1   6 - Incomplete VIN; 7 - Manufacturer is not re...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   1 - Check Digit (9th position) does not calcul...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
# 1   0 - VIN decoded clean. Check Digit (9th positi...
# 2   0 - VIN decoded clean. Check Digit (9th positi...
# 3   0 - VIN decoded clean. Check Digit (9th positi...
# 0   0 - VIN decoded clean. Check Digit (9th positi...
#
# [6897 rows x 12 columns]

# %%
temp.to_excel(rf'C:\Users\FFR0103\Desktop\My files\WORK\Auto part\Secure Link\Output\result_5.xlsx')
